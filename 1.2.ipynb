# %% [markdown]
# # Data structures - Lists

# %%
# list example - same data type

# %%
# list example - different data type

# %%
# membership

# %%
# list indexing

# %%
# list slicing

# %%
# slicing with step

# %% [markdown]
# ## modify list

# %%
# change element

# %%
# change multiple items

# %%
# delete item / multiple items

# %%
# list concatenation

# %%
# list repetition

# %% [markdown]
# ## list methods

# %%
# append

# %%
# insert

# %%
# extend

# %%
# remove

# %%
# pop

# %%
# length of list

# %%
# nested lists

# %% [markdown]
# # Tuples

# %%
# tuple creation

# %%
# length of tuple

# %%
# mixed tuples

# %%
# slicing, indexing, steps

# %%
# difference between list and tuple / immutability

# %% [markdown]
# # Logical Operators

# %%
# logical operators

# %%
# chained comparison operators

# %% [markdown]
# # Conditional Statements

# %%
# if

# %%
# if else

# %%
# if elif else

# %%
# nested conditional statements
