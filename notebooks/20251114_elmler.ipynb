# %% [markdown]
# # tekrar

# %% [markdown]
# - str - tekst, mətn - 'salam', "sagol", "1", "3.14"
# - int - 1, 2, 3, -1, -4, 0
# - float - kesr - 1.3, -0.5, 7.0, 123102398.038023984
# - bool - mentiq - True, False
# - null - None

# %%
x = None
# x = 5
x + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 x = None
#       2 # x = 5
# ----> 3 x + 5
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
"1" + "34"
# Out:
# '134'

# %%
ad = input('adiniz nedir?')
x = f'salam menim adim: {ad}'
x
# Out:
# 'salam menim adim: hesen'

# %% [markdown]
# # collections

# %%
x = ['shahriyar', 'ali', 'hesen']
y = [1.4,3,'4',True,'adam',None]
y
# Out:
# [1.4, 3, '4', True, 'adam', None]

# %%
'lale' not in x
# Out:
# True

# %%
ad = 'shahriyar'
ad[-3]
# Out:
# 'i'

# %%
x = ['shahriyar', 'ali', 'hesen', 'lale', 'gulnar', 'cemil', 'amil']
x
# Out:
# ['shahriyar', 'ali', 'hesen', 'lale', 'gulnar', 'cemil', 'amil']

# %%
x[1:6:2]
# Out:
# ['ali', 'lale', 'cemil']

# %%
x[-1] = 'elton'
x
# Out:
# ['shahriyar', 'ali', 'hesen', 'lale', 'gulnar', 'cemil', 'elton']

# %%
# del x[-2]
x.remove('cemil')
x
# Out:
# ['shahriyar', 'ali', 'hesen', 'lale', 'gulnar', 'elton']

# %%
x = ['shahriyar', 'ali', 'hesen', 'lale', 'gulnar', 'cemil', 'amil']
x.append('zaur')
x
# Out:
# ['shahriyar', 'ali', 'hesen', 'lale', 'gulnar', 'cemil', 'amil', 'zaur']

# %%
x = ['shahriyar', 'ali', 'hesen', 'lale', 'gulnar', 'cemil', 'amil']
x.insert(2,'ehmed')
x
# Out:
# ['shahriyar', 'ali', 'ehmed', 'hesen', 'lale', 'gulnar', 'cemil', 'amil']

# %%
x.insert(2,'ehmed')
x
# Out:
# ['shahriyar',
#  'ali',
#  'ehmed',
#  'zaur',
#  'ehmed',
#  'ehmed',
#  'ehmed',
#  'ehmed',
#  'hesen',
#  'lale',
#  'gulnar',
#  'cemil',
#  'amil']

# %%
x = ['shahriyar', 'ali', 'hesen', 'lale', 'gulnar', 'cemil', 'amil']
x.pop()
# Out:
# 'amil'

# %%
len('shahriyar')
# Out:
# 9

# %%
x.pop?
# Out:
# Signature: x.pop(index=-1, /)
# Docstring:
# Remove and return item at index (default last).
#
# Raises IndexError if list is empty or index is out of range.
# Type:      builtin_function_or_method

# %%
ad = 'shahriyar'
ad.replace('sh', 'kh')
# ad[:2] = 'kh'
ad
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 3
#       1 ad = 'shahriyar'
#       2 # ad.replace('sh', 'kh')
# ----> 3 ad[:2] = 'kh'
#       4 ad
#
# TypeError: 'str' object does not support item assignment

# %%
x = ['shahriyar', 'ali', 'hesen', 'lale', 'gulnar', 'cemil', 'amil']
x[:2] = ['a', 'b']
x
# Out:
# ['a', 'b', 'hesen', 'lale', 'gulnar', 'cemil', 'amil']

# %%
print()

# %%
print('a', 'b',sep=',')
# Out:
# a,b

# %%
my_list = 'a'
my_list.upper()
# Out:
# 'A'

# %%
x = [9,6,5]
y = ['shahriyar', 'ali', 'hesen', 'lale' ,'gulnar']
list(zip(x,y))
# Out:
# [(9, 'shahriyar'), (6, 'ali'), (5, 'hesen')]

# %%
a = [1,3,4] # list
b = (1,3,4) # tuple

# %%
b[0] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 b[0] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
1<=5>=5
# Out:
# False

# %%
1 <= 5 and 5 >= 5 and 7!=8
# Out:
# True

# %%
1 == 5 or 5 > 5 or (not 7==8)
# Out:
# True

# %%
not 1 == 5
# Out:
# True

# %%
adfasdfa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 adfasdfa
#
# NameError: name 'adfasdfa' is not defined

# %%
1+2
# Out:
# 3

# %% [markdown]
# 1+2
