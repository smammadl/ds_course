# %%
9**(1/2)
# Out:
# 3.0

# %%
'a', "a", """a""" # str
1, 100_000, -12312, 0 # int
1.2023, -1231.29 # float
True, False # bool
None # NoneType

# %%
# 1 + 3.0
'1' + '3.0'
'1' * 3
# Out:
# '111'

# %%
123123123

# %%
print("asdfasdf")
(1+2)*3
[1, 2, 3]

# %%
s = 'abcdaldjflasjdflakjsd'
s[0]
# Out:
# 'a'

# %%
text = "apple,banana,cherry"
len(text)
# Out:
# 19

# %%
text.upper()
# Out:
# 31

# %%
text.index('ch')
# Out:
# 13

# %%
text[::-1]
# Out:
# 'yrrehc,ananab,elppa'

# %%
text[-1:-7:-3]
# Out:
# 'ye'

# %%
text[1:7:3]
# Out:
# 'pe'

# %%
text[::-1].index('e')
# Out:
# 'yrrehc,ananab,elppa'

# %%
text = "apple,banana,cherry"
e1_index = text.index('e')
e2_index = text.index('e', e1_index+1)
text[e1_index : e2_index : 2]
# Out:
# 'ebnn,h'

# %%
# Out:
# 15

# %%
s.replace('lasj', 'shahriyar')
# Out:
# 'abcdaldjfshahriyardflakjsd'

# %%
help(s.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
text.endswith('ra')
# Out:
# False

# %%
i = 1231098102381
i.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 2
#       1 i = 1231098102381
# ----> 2 i.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
s
# Out:
# 'abcdaldjflasjdflakjsd'

# %%
n = None

type(n)
# Out:
# NoneType

# %%
type('a')
# Out:
# str

# %%
s = "men mektebe getmek isteyirem"

# %%
1+2
# Out:
# 3

# %%
23+3
# Out:
# 26

# %%
n = None

# %%
type(s) == str
# Out:
# True

# %%
x = 'ad: '
ad = 'shahriyar'

text = x + ad
text
# Out:
# 'ad: shahriyar'

# %%
print(x, ad, x, ad, ad, ad, ad, x, sep='?')
# Out:
# ad: ?shahriyar?ad: ?shahriyar?shahriyar?shahriyar?shahriyar?ad:

# %%
"menim adim" + " " + "sehriyardir"
# Out:
# 'menim adim sehriyardir'

# %%
from datetime import datetime

d = datetime.now()

yeni_str = f"menim adim {d}-dir"
yeni_str
# Out:
# 'menim adim 2026-03-31 20:25:08.920934-dir'

# %%
d = f"menim adim {d}-dir"
print(d)
# Out:
# menim adim 2026-03-31 20:25:08.920934-dir

# %%
d = f"menim adim {d}-dir"
print(d)
# Out:
# menim adim menim adim 2026-03-31 20:25:08.920934-dir-dir

# %%
x = 12312.1291231

f"sizin hesab: {x:.2f}"
# Out:
# 'sizin hesab: 12312.13'

# %%
print(123123, 123123.83939)
# Out:
# 123123 123123.83939

# %%
sayi = input("ureyin isteyen bir sayi yaz:")

sayi = int(sayi)
sayi**2
# Out:
# 225

# %%
int('15')
# Out:
# 15

# %%
l = [12312, 12312, 123]
m = [111]
l[0] = 'a'
l
# Out:
# ['a', 12312, 123]

# %%
(12312, 123, 1231)

# %%
d = {'birinci element': 1, 'ikinci element':2}
d['ikinci element']
# Out:
# 2

# %%
type({12312, 123123, 123, 123})
# Out:
# set
