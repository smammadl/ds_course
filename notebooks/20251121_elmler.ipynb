# %%
adlar = 'hesen lale gulnar ali fuad'
adlar = adlar.split(' ')
adlar
# Out:
# ['hesen', 'lale', 'gulnar', 'ali', 'fuad']

# %%
sait = ['a', 'e', 'o', 'u', 'i']
[(ad[0]*3 if ad[0]=='h' else ad[0]) 
 		for ad in adlar 
 				if (ad[0] not in sait)]
# Out:
# ['hhh', 'l', 'g', 'f']

# %%
('ali', 'hesen') # tuple
['ali', 'hesen'] # list

# %%
adlar
# Out:
# ['hesen', 'lale', 'gulnar', 'ali', 'fuad']

# %%
yashlar = list(range(20, 46, 5))
yashlar
# Out:
# [20, 25, 30, 35, 40, 45]

# %%
list(zip(adlar, yashlar))
# Out:
# [('hesen', 20), ('lale', 25), ('gulnar', 30), ('ali', 35), ('fuad', 40)]

# %%
# dictionary

# %%
adlar_yashlar = {
    'hesen' : 20,
    'huseyn' : 25,
    'ali' : 30,
    'lale' : 35,
}
adlar_yashlar['huseyn']
# Out:
# 25

# %%
adlar_yashlar['ali'] = 90
adlar_yashlar
# Out:
# {'hesen': 20, 'huseyn': 25, 'ali': 90, 'lale': 35}

# %%
del adlar_yashlar['ali']
adlar_yashlar
# Out:
# {'hesen': 20, 'huseyn': 25, 'lale': 35}

# %%
l = [[1,2,3], [4,5,6]]
l[0][0]
# Out:
# 1

# %%
d = {
    'ad':'hesen',
    'yash':30,
    'qeydiyyat':{
        'daimi' : 'zerdab', 
        'faktiki' : 'baki'
	}
}
d.items()
# Out:
# dict_items([('ad', 'hesen'), ('yash', 30), ('qeydiyyat', {'daimi': 'zerdab', 'faktiki': 'baki'})])

# %%
d
# Out:
# {'ad': 'hesen',
#  'yash': 30,
#  'qeydiyyat': {'daimi': 'zerdab', 'faktiki': 'baki'}}

# %%
d['soyad'] = 'aliyev'
d
# Out:
# {'ad': 'hesen',
#  'yash': 30,
#  'qeydiyyat': {'daimi': 'zerdab', 'faktiki': 'baki'},
#  'soyad': 'aliyev'}

# %%
{
    'key' : 'value',
    'asldfjal' : 'adfasdf'
}
# Out:
# {'key': 'value', 'asldfjal': 'adfasdf'}

# %%
{1,2,2,2,1,1,1,1,2,2,1,2}
# Out:
# {1, 2}

# %%
set(list('hesen'))
# Out:
# {'e', 'h', 'n', 's'}

# %%
set('hesen')
# Out:
# {'e', 'h', 'n', 's'}

# %%
x = 3

s = {1,2,2,1,1,1}
s.add(x)
s
# Out:
# {1, 2, 3}

# %%
1 in s
# Out:
# True

# %%
s
# Out:
# {1, 2, 3}

# %%
t = {3,4,5}
s.difference(t)
# Out:
# {1, 2}

# %% [markdown]
# # Funksiya

# %%
def kvadrata_yukselt(nese):
    return nese**2
def kuba_yukselt(nese):
    return nese**3

print(kvadrata_yukselt(4))
print(kuba_yukselt(4))
# Out:
# 16
# 64

# %%
def topla(neynense, neyise):
    return neynense + neyise

topla(4,5)
# x = topla(4,5)
# x + 1
# Out:
# 9

# %%
len('abcd')
# Out:
# 4

# %%
def uzunluq(l):
	x = 0
	for herf in l:
		x = x+1
	return x

uzunluq([1,2,3,3,43,3,3,]), uzunluq(['a'])
# Out:
# (7, 1)

# %%
def quvvete_yukselt(nese=10, quvveti=2):
    cavab = nese**quvveti
    return cavab

quvvete_yukselt(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 5
#       2     cavab = nese**quvveti
#       3     return cavab
# ----> 5 quvvete_yukselt(2,nese=3)
#
# TypeError: quvvete_yukselt() got multiple values for argument 'nese'
