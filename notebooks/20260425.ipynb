# %%
db = []

users = [
	{
		"name" : "ali",
		"surname" : "valiyev",
		"age" : 19,
        "gender": "M"
	},
	{
		"name" : "hesen",
		"surname" : "memmedov",
		"age" : 20,
		"gender" : "M",
	},
]

def dbya_yaz(name:str, surname:str, age:int, **kwargs):
    print(kwargs)
    db.append(f'{name.capitalize()} {surname}: {age}, {list(kwargs.items())}')
    
dbya_yaz(
    **users[1]
)
# Out:
# {'gender': 'M'}

# %%
l = [1,2,3,4,5]

['a', *l, 'b']
# Out:
# ['a', 1, 2, 3, 4, 5, 'b']

# %%
user={
		"name" : "hesen",
		"surname" : "memmedov",
		"age" : 20,
		"gender" : "M",
	}

{
    'a' : 1,
    'v':user, 
    'b':2
}
# Out:
# {'a': 1,
#  'v': {'name': 'hesen', 'surname': 'memmedov', 'age': 20, 'gender': 'M'},
#  'b': 2}

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
iter_ojb = iter(l)

# %%
def kublar_yarat(baslama_yeri=1, bitme_yeri=8):
    a = baslama_yeri
    while True:
        yield a**3
        a += 1
        
gen = kublar_yarat(3)

# %%
next(gen)
# Out:
# 343

# %%
# !pip install pillow

# %%
# import PIL
from PIL import Image
from pathlib import Path
# from PIL import *

img_path = Path(r"C:\Users\user\Desktop\Untitled.png")
img = Image.open(img_path)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1606x648>

# %%
img.resize((120,120))
# Out:
# <PIL.Image.Image image mode=RGBA size=120x120>

# %%
import requests

res = requests.get('https://api.dicebear.com/9.x/pixel-art/png?skinColor=ffffff,ffffff,ffffff&mouth=happy01,happy02,happy03&hatProbability=60')
Image.open(io.BytesIO(res.content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=128x128>

# %%
import io
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=128x128>

# %%
txt_path = Path(r'./salam.txt')
txt_path.exists()
# Out:
# True

# %%
with open(txt_path, 'w') as f:
    f.write('ali, \nsagol \n, necesen\n')

# %%
# !pip install pandas numpy

# %%
csv = Path(r'C:\Users\user\Desktop\div\data\files\housing.csv')
csv
# Out:
# WindowsPath('C:/Users/user/Desktop/div/data/files/housing.csv')

# %%
import pandas
cedvel = pandas.read_csv(csv)
cedvel
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
cedvel[cedvel['population'] > 15000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5215     -121.44     38.43                 3.0      39320.0          6210.0
# 5979     -117.87     34.04                 7.0      27700.0          4179.0
# 9795     -121.79     36.64                11.0      32627.0          6445.0
# 11617    -117.74     33.89                 4.0      37937.0          5471.0
# 12594    -117.42     33.35                14.0      25135.0          4819.0
# 18514    -117.78     34.03                 8.0      32054.0          5290.0
#
#        population  households  median_income  median_house_value  \
# 5215      16305.0      5358.0         4.9516            153700.0
# 5979      15037.0      4072.0         6.6288            339700.0
# 9795      28566.0      6082.0         2.3087            118800.0
# 11617     16122.0      5189.0         7.4947            366300.0
# 12594     35682.0      4769.0         2.5729            134400.0
# ...
