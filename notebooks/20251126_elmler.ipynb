# %%
l = [-2,-4,9,12,3]

x = filter(lambda eded:eded>0, l)
list(x)
# Out:
# [9, 12, 3]

# %%
[eded for eded in l if eded > 0]
# Out:
# [9, 12, 3]

# %%
list(map(lambda x:x**2, l))
# Out:
# [4, 16, 81, 144, 9]

# %%
l = [-2,-4,9,12,3]
[eded**2 for eded in l]
# Out:
# [4, 16, 81, 144, 9]

# %%
from functools import reduce

reduce(lambda x,y:x**y, [2,3,4,5])
# Out:
# 1152921504606846976

# %%
# s = {1,2,-3,-1,1,2,12}
# {eded**2 for eded in s if eded>0}
# t = (1,2,-3,-1,1,2,12)
# tuple(eded**2 for eded in t if eded>0)
d = {'a':1, 'b':2, 'c':3}
{k*3:v+100 for k, v in d.items()}
# Out:
# {'aaa': 101, 'bbb': 102, 'ccc': 103}

# %%
l = [-2, -4, 9, 12, 3]
{eded:'musbet' if eded>0 else 'menfi' 
 	for eded in l}
# Out:
# {-2: 'menfi', -4: 'menfi', 9: 'musbet', 12: 'musbet', 3: 'musbet'}

# %%
for x in l:

# %%
x = (3)
type(x)
# Out:
# int

# %%
(3,)
# Out:
# (3,)

# %%
x = 10
y = 2

try:
	print(x / int(y))
except ZeroDivisionError as e:
	print(f'sifira bolme xetasi var: {e}')
except TypeError:
	print('deyishkenlerin tipinde problem var')
except Exception as e:
	print(f'nese var amma bilmirik: {e}')
else:
	print('her shey yaxsi getdi')
finally:
	print('axir ki qutardi')

print('adfasdf')
# Out:
# 5.0
# her shey yaxsi getdi
# axir ki qutardi
# adfasdf

# %%
try:
	print(x / int(y))
except Exception as e:
	print(f'nese var amma bilmirik: {e}')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 x / y
#
# ZeroDivisionError: division by zero

# %%
x = 10
y = 0

assert y!=0, 'y sifirdir'
assert type(y) == int or type(y) == float, 'y normal tipde deyil'
assert y >=0

print(x/y)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[80], line 4
#       1 x = 10
#       2 y = 0
# ----> 4 assert y!=0, 'y sifirdir'
#       5 assert type(y) == int or type(y) == float, 'y normal tipde deyil'
#       6 assert y >=0
#
# AssertionError: y sifirdir

# %%
x = 10
y = 0
if y==0:
	raise ZeroDivisionError
elif type(y) == 'str':
	raise TypeError

print(x/y)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[83], line 4
#       2 y = 0
#       3 if y==0:
# ----> 4 	raise ZeroDivisionError
#       5 elif type(y) == 'str':
#       6 	raise TypeError
#
# ZeroDivisionError:

# %%
class Pishik:
	ayaq = 4
	quyrugu_var = True

	def __init__(self, p_adi, p_rengi, p_yashi):
		self.ad = p_adi
		self.reng = p_rengi
		self.yash = p_yashi

	def myau_ele(self):
		if self.ad == 'linda':
			return 'myau'
		elif self.ad == 'fexaret':
			return 'MYAU'
    
menim_pishiyim = Pishik('linda', 'boz',3)
senin_pishiyin = Pishik('fexaret', 'sari',0)
# menim_pishiyim.yash
senin_pishiyin.myau_ele()
# Out:
# 'MYAU'

# %%
senin_pishiyin.quyrugu_var
# Out:
# True
