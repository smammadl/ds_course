# %%
# %pip install scikit-learn scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
y = np.random.randint(18, 35, size=8)
y
# Out:
# array([19, 24, 20, 22, 20, 20, 30, 28], dtype=int32)

# %%
np.abs(y - y.mean()).mean()
# Out:
# np.float64(3.34375)

# %%
np.sqrt(np.sum((y - y.mean())**2) / 8)
# Out:
# np.float64(3.8547859862773186)

# %%
np.sum((y - 21)**2) / 8
# Out:
# np.float64(18.375)

# %%
y.var()
# Out:
# np.float64(14.859375)

# %%
np.mean((y - y.mean())**2)**(1/2)
# Out:
# np.float64(3.8547859862773186)

# %%
np.sort(y)
# Out:
# array([19, 20, 20, 20, 22, 24, 28, 30], dtype=int32)

# %%
np.median(y)
# Out:
# np.float64(21.0)

# %%
np.mean(y)
# Out:
# np.float64(22.875)

# %%
np.std(y)
# Out:
# np.float64(3.8547859862773186)

# %%
np.mean(y) + 3 * np.std(y)
# Out:
# np.float64(34.439357958831955)

# %%
np.quantile(y, 0.75)
# Out:
# np.float64(25.0)

# %%
25 + 5 * 1.5
# Out:
# 32.5

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\div\data\files\housing.csv')
df.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df['median_income'].hist(bins=100, figsize=(10, 5))
# Out:
# <Axes: >

# %%
ideal_data = pd.Series(np.random.normal(loc=0, scale=1, size=10000))
ideal_data.hist(bins=100, figsize=(10, 5))
# Out:
# <Axes: >

# %%
ideal_data.skew(), ideal_data.kurtosis()
# Out:
# (np.float64(0.037211956179259195), np.float64(0.0644726837599201))

# %%
df['median_income'].skew()
# Out:
# np.float64(1.6466567021344463)

# %%
df['median_income'].kurtosis()
# Out:
# np.float64(4.952524101991511)
