# %%
x = 10
print(x)
# Out:
# 10

# %%
y = (x + 1)**2
y # y = 121 olacaq
"""
bu cox setirli komment deyil eselinde
amma fikirlese bilerik
"""
# Out:
# '\nbu cox setirli komment deyil eselinde\namma fikirlese bilerik\n'

# %%
x = print('salam')
x
# Out:
# salam

# %%
'a' + 'b' # concatenation
'a'*3 # replication
# Out:
# 'aaa'

# %%
print('abcdadfasdf\'alfjalsjdfalskjd')
# Out:
# abcdadfasdf'alfjalsjdfalskjd

# %%
print('i\"m going to school')
# Out:
# i"m going to school

# %%
x = 1012313
str(x)[0]
# Out:
# '1'

# %%
x = 'abcdadfasdf\'alfjalsjdfalskjd'
list(x)
# Out:
# ['a',
#  'b',
#  'c',
#  'd',
#  'a',
#  'd',
#  'f',
#  'a',
#  's',
#  'd',
#  'f',
#  "'",
#  'a',
#  'l',
#  'f',
#  'j',
#  'a',
#  'l',
#  's',
#  'j',
#  'd',
#  'f',
#  'a',
#  'l',
#  's',
#  'k',
#  'j',
#  'd']
