# %% [markdown]
# # comprehension

# %%
bosh_list = []

for x in [-1,4,1,-2,3,-5,6,5]:
	if x>0:
		if x%3==0:
			bosh_list.append(f"{x} uce tam bolunur")
		else:
			bosh_list.append(x**2)
		
bosh_list
# Out:
# [-1, -1, 2, -3, -5, -5]

# %%
bosh_list = []

for x in [-1,4,1,-2,3,-5,6,5]:
	if x>0:
		if x%3==0:
			bosh_list.append(f"{x} uce tam bolunur")
		else:
			bosh_list.append(f"{x} uce tam bolunmur")
		
bosh_list

# %%
nese_list = [1,1,2,3,5,5]

[(x if x%2==0 else -x) for x in nese_list if x%2==1]
# Out:
# [-1, -1, 2, -3, -5, -5]

# %%
[sayi**2 for setir in m for sayi in setir]
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
m = [
		[1,2,3], 
		[4,5,6]
    ]

for setir in m:
    for sayi in setir:
        print(sayi**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36

# %%
import numpy as np

m = [
		[1,2,3], 
		[4,5,6]
    ]

np.array(m).flatten()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
import random
random.randint(0,100)
# Out:
# 71

# %%
bosh_list = []

for i in range(3):
    bosh_list.append(random.randint(0,100))
    
bosh_list
# Out:
# [6, 57, 45]

# %%
l1 = [random.randint(0,100) for i in range(3)]
l2 = [random.randint(0,100) for i in range(3)]
l3 = [random.randint(0,100) for i in range(3)]

l1,l2,l3
# Out:
# ([7, 34, 49], [41, 64, 77], [30, 85, 81])

# %%
for i in l1,l2,l3:
    print(i, end=' ')
# Out:
# [33, 43, 83] [3, 8, 86] [14, 63, 19]

# %%
print('a', end=' '); print('b')
# Out:
# a b

# %%
l1 = [random.randint(0,100) for i in range(9)]
l1
# Out:
# [79, 61, 12, 26, 30, 27, 20, 80, 38]

# %%
s = ''
for i in range(3):
    for j in range(3):
        s += f"  {l1[3*i+j]} "
    s += '\n'
print('[\n' + s + ']')
# Out:
# [
#   79   61   12
#   26   30   27
#   20   80   38
# ]

# %%
s = '['
for i,elem in enumerate(l1):
	if i%3 == 0:
		s += f'\n  {elem} '
	else:
		s += f'{elem} '
s += '\n]'
print(s)
# Out:
# [
#   90 90 49
#   4 67 37
#   9 76 20
# ]

# %%
# f(x,y) = (x**2, x + 3y)
t = 100
s = 99

def f(p):
    t = 10
    return (p**2, t+3, s)

f(2)
# Out:
# (4, 13, 99)

# %%
def tek_cut(x):
    if x%2 == 0:
        y = 'cut'
    else:
        y = 'tek'
    return y

tek_cut(9)
# Out:
# 'tek'

# %%
def ad_uzundur(x):
    uzunluq = len(x)
    if uzunluq > 5:
        y = True
    else:
        y = False
    return y

ad_uzundur('shahariyar')
# Out:
# True

# %%
def ad_uzundur(x):
    if len(x) > 5:
        return True
    else:
        return False

ad_uzundur('shahariyar')
# Out:
# True

# %%
l = [random.randint(0,99) for i in range(10)]
l
# Out:
# [39, 8, 23, 27, 51, 57, 99, 36, 59, 1]

# %%
for i in l:
    if i%2 == 0:
        print(i)
        break
# Out:
# 8

# %%
l
# Out:
# [39, 8, 23, 27, 51, 57, 99, 36, 59, 1]

# %%
def ilk_cut_elem(nese_list):
	for i in nese_list:
		if i%2 == 0:
			return(i)

ilk_cut_elem(l)
# Out:
# 8

# %%
l
# Out:
# [39, 8, 23, 27, 51, 57, 99, 36, 59, 1]

# %%
def ilk_cut_elem(nese_list):
	for i in nese_list:
		if i%2 == 0:
			print(i)

ilk_cut_elem(l)
# Out:
# 8
# 36

# %%
t = 100
s = 99

def f(a,b,c,d):
    t = 10
    return (a**2, -b,c,d)

f(2,3,d=2,c=1)
# Out:
# (4, -3, 1, 2)

# %%
t = 100
s = 99

def f(a,b,c=-1,d=None):
    t = 10
    return (a**2, -b,c,d)

f(2,b=3)
# Out:
# (4, -3, -1, None)

# %%
from pathlib import Path

folder_path = r"C:\Users\user\Desktop\div\test"

list(Path(folder_path).iterdir())
# Out:
# [WindowsPath('C:/Users/user/Desktop/div/test/debug_upload_results.json')]

# %%
from pathlib import Path

folder_path = r"C:\Users\user\Desktop\div\others"

list(Path(folder_path).iterdir())
# Out:
# [WindowsPath('C:/Users/user/Desktop/div/others/2.2_pandas-exercises-db-extras original.py'),
#  WindowsPath('C:/Users/user/Desktop/div/others/basqa.nese.txt'),
#  WindowsPath('C:/Users/user/Desktop/div/others/Complete-Python-3-Bootcamp'),
#  WindowsPath('C:/Users/user/Desktop/div/others/div_old'),
#  WindowsPath('C:/Users/user/Desktop/div/others/lap-basqa.nese.txt'),
#  WindowsPath('C:/Users/user/Desktop/div/others/nese.txt'),
#  WindowsPath('C:/Users/user/Desktop/div/others/practical-python'),
#  WindowsPath('C:/Users/user/Desktop/div/others/rustam')]

# %%
def icindekiler(folderin_pathi):
    return list(Path(folderin_pathi).iterdir())

icindekiler(r"C:\Users\user\Desktop\div\others\div_old")
# Out:
# [WindowsPath('C:/Users/user/Desktop/div/others/div_old/.gitignore'),
#  WindowsPath('C:/Users/user/Desktop/div/others/div_old/div'),
#  WindowsPath('C:/Users/user/Desktop/div/others/div_old/py')]
