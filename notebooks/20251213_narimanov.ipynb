# %%
import pandas as pd

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([10,20,30,40,50])
df = pd.DataFrame([s1,s2]).T
df
# Out:
#    0   1
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
csv_path_str = r"C:\Users\user\Desktop\div\data\world_population.csv"
from pathlib import Path
csv_path = Path(csv_path_str)
df = pd.read_csv(csv_path)
df.head(3)
# Out:
#    Rank CCA3      Country  Capital Continent  2022 Population  \
# 0    36  AFG  Afghanistan    Kabul      Asia       41128771.0
# 1   138  ALB      Albania   Tirana    Europe        2842321.0
# 2    34  DZA      Algeria  Algiers    Africa       44903225.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 0       10694796.0       12486631.0       10752971.0    652230.0
# 1        3295066.0        2941651.0        2324731.0     28748.0
# 2       25518074.0       18739378.0       13795915.0   2381741.0
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 0            63.0587       1.0257                         0.52
# ...

# %%
# df.Country
df['Country']
df.loc[:, 'Country']
df.iloc[:, 2]
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3         American Samoa
# 4                Andorra
#              ...
# 229    Wallis and Futuna
# 230       Western Sahara
# 231                Yemen
# 232               Zambia
# 233             Zimbabwe
# Name: Country, Length: 234, dtype: object

# %%
cols = ['Country', 'Continent', '2022 Population']
# df[cols]
# df.loc[:, cols]
cols_i = [2,4,5]
df.iloc[:, cols_i]
# Out:
#                Country Continent  2022 Population
# 0          Afghanistan      Asia       41128771.0
# 1              Albania    Europe        2842321.0
# 2              Algeria    Africa       44903225.0
# 3       American Samoa   Oceania          44273.0
# 4              Andorra    Europe          79824.0
# ..                 ...       ...              ...
# 229  Wallis and Futuna   Oceania          11572.0
# 230     Western Sahara    Africa         575986.0
# 231              Yemen      Asia       33696614.0
# 232             Zambia    Africa       20017675.0
# 233           Zimbabwe    Africa       16320537.0
#
# [234 rows x 3 columns]

# %%
df.head(3)
# Out:
#    Rank CCA3      Country  Capital Continent  2022 Population  \
# 0    36  AFG  Afghanistan    Kabul      Asia       41128771.0
# 1   138  ALB      Albania   Tirana    Europe        2842321.0
# 2    34  DZA      Algeria  Algiers    Africa       44903225.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 0       10694796.0       12486631.0       10752971.0    652230.0
# 1        3295066.0        2941651.0        2324731.0     28748.0
# 2       25518074.0       18739378.0       13795915.0   2381741.0
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 0            63.0587       1.0257                         0.52
# ...

# %%
df.loc[:, 'Country':'2022 Population']
df.iloc[:, 2:6]
# Out:
#                Country           Capital Continent  2022 Population
# 0          Afghanistan             Kabul      Asia       41128771.0
# 1              Albania            Tirana    Europe        2842321.0
# 2              Algeria           Algiers    Africa       44903225.0
# 3       American Samoa         Pago Pago   Oceania          44273.0
# 4              Andorra  Andorra la Vella    Europe          79824.0
# ..                 ...               ...       ...              ...
# 229  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# 230     Western Sahara          El Aaiún    Africa         575986.0
# 231              Yemen             Sanaa      Asia       33696614.0
# 232             Zambia            Lusaka    Africa       20017675.0
# 233           Zimbabwe            Harare    Africa       16320537.0
#
# [234 rows x 4 columns]

# %%
df.head(2)
# Out:
#    Rank CCA3      Country Capital Continent  2022 Population  2020 Population  \
# 0    36  AFG  Afghanistan   Kabul      Asia       41128771.0       38972230.0
# 1   138  ALB      Albania  Tirana    Europe        2842321.0        2866849.0
#
#    2015 Population  2010 Population  2000 Population  1990 Population  \
# 0       33753499.0       28189672.0       19542982.0       10694796.0
# 1        2882481.0        2913399.0        3182021.0        3295066.0
#
#    1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 0       12486631.0       10752971.0    652230.0            63.0587
# 1        2941651.0        2324731.0     28748.0            98.8702
#
#    Growth Rate  World Population Percentage
# 0       1.0257                         0.52
# 1       0.9957                         0.04

# %%
df2 = df.set_index('CCA3')
df2.head(2)
# Out:
#       Rank      Country Capital Continent  2022 Population  2020 Population  \
# CCA3
# AFG     36  Afghanistan   Kabul      Asia       41128771.0       38972230.0
# ALB    138      Albania  Tirana    Europe        2842321.0        2866849.0
#
#       2015 Population  2010 Population  2000 Population  1990 Population  \
# CCA3
# AFG        33753499.0       28189672.0       19542982.0       10694796.0
# ALB         2882481.0        2913399.0        3182021.0        3295066.0
#
#       1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# CCA3
# AFG        12486631.0       10752971.0    652230.0            63.0587
# ALB         2941651.0        2324731.0     28748.0            98.8702
#
#       Growth Rate  World Population Percentage
# CCA3
# AFG        1.0257                         0.52
# ALB        0.9957                         0.04

# %%
df2.iloc[0]
df2.loc['AFG']
# Out:
# Rank                                    36
# Country                        Afghanistan
# Capital                              Kabul
# Continent                             Asia
# 2022 Population                 41128771.0
# 2020 Population                 38972230.0
# 2015 Population                 33753499.0
# 2010 Population                 28189672.0
# 2000 Population                 19542982.0
# 1990 Population                 10694796.0
# 1980 Population                 12486631.0
# 1970 Population                 10752971.0
# Area (km²)                        652230.0
# Density (per km²)                  63.0587
# Growth Rate                         1.0257
# World Population Percentage           0.52
# Name: AFG, dtype: object

# %%
df2.loc['AFG':'AZE']
df2.iloc[0:14]
# Out:
#       Rank              Country           Capital      Continent  \
# CCA3
# AFG     36          Afghanistan             Kabul           Asia
# ALB    138              Albania            Tirana         Europe
# DZA     34              Algeria           Algiers         Africa
# ASM    213       American Samoa         Pago Pago        Oceania
# AND    203              Andorra  Andorra la Vella         Europe
# AGO     42               Angola            Luanda         Africa
# AIA    224             Anguilla        The Valley  North America
# ATG    201  Antigua and Barbuda      Saint John’s  North America
# ARG     33            Argentina      Buenos Aires  South America
# ARM    140              Armenia           Yerevan           Asia
# ABW    198                Aruba        Oranjestad  North America
# AUS     55            Australia          Canberra        Oceania
# AUT     99              Austria            Vienna         Europe
# ...

# %%
df2.loc['AFG':'AZE', 'Country':'2022 Population']
df2.iloc[0:14, 1:5]
# Out:
#                   Country           Capital      Continent  2022 Population
# CCA3
# AFG           Afghanistan             Kabul           Asia       41128771.0
# ALB               Albania            Tirana         Europe        2842321.0
# DZA               Algeria           Algiers         Africa       44903225.0
# ASM        American Samoa         Pago Pago        Oceania          44273.0
# AND               Andorra  Andorra la Vella         Europe          79824.0
# AGO                Angola            Luanda         Africa       35588987.0
# AIA              Anguilla        The Valley  North America          15857.0
# ATG   Antigua and Barbuda      Saint John’s  North America          93763.0
# ARG             Argentina      Buenos Aires  South America       45510318.0
# ARM               Armenia           Yerevan           Asia        2780469.0
# ABW                 Aruba        Oranjestad  North America         106445.0
# ...

# %%
df2.loc['AFG':'AZE', 'Country':'2022 Population']
# Out:
#                   Country           Capital      Continent  2022 Population
# CCA3
# AFG           Afghanistan             Kabul           Asia       41128771.0
# ALB               Albania            Tirana         Europe        2842321.0
# DZA               Algeria           Algiers         Africa       44903225.0
# ASM        American Samoa         Pago Pago        Oceania          44273.0
# AND               Andorra  Andorra la Vella         Europe          79824.0
# AGO                Angola            Luanda         Africa       35588987.0
# AIA              Anguilla        The Valley  North America          15857.0
# ATG   Antigua and Barbuda      Saint John’s  North America          93763.0
# ARG             Argentina      Buenos Aires  South America       45510318.0
# ARM               Armenia           Yerevan           Asia        2780469.0
# ABW                 Aruba        Oranjestad  North America         106445.0
# ...

# %%
m = df2.loc[:, '2022 Population'] > 50e6
df2.loc[m, ['Country', 'Continent']]
# Out:
#              Country      Continent
# CCA3
# BGD       Bangladesh           Asia
# BRA           Brazil  South America
# CHN            China           Asia
# COL         Colombia  South America
# COD         DR Congo         Africa
# EGY            Egypt         Africa
# ETH         Ethiopia         Africa
# FRA           France         Europe
# DEU          Germany         Europe
# IND            India           Asia
# IDN        Indonesia           Asia
# IRN             Iran           Asia
# ITA            Italy         Europe
# JPN            Japan           Asia
# KEN            Kenya         Africa
# MEX           Mexico  North America
# MMR          Myanmar           Asia
# NGA          Nigeria         Africa
# PAK         Pakistan           Asia
# PHL      Philippines           Asia
# RUS           Russia         Europe
# ZAF     South Africa         Africa
# KOR      South Korea           Asia
# TZA         Tanzania         Africa
# THA         Thailand           Asia
# ...

# %%
s_2025 = df2.loc[:, '2022 Population'] * 1.2
s_2025
# Out:
# CCA3
# AFG    49354525.2
# ALB     3410785.2
# DZA    53883870.0
# ASM       53127.6
# AND       95788.8
#           ...
# WLF       13886.4
# ESH      691183.2
# YEM    40435936.8
# ZMB    24021210.0
# ZWE    19584644.4
# Name: 2022 Population, Length: 234, dtype: float64

# %%
df2['2025 Population'] = s_2025
df2
# Out:
#       Rank            Country           Capital Continent  2022 Population  \
# CCA3
# AFG     36        Afghanistan             Kabul      Asia       41128771.0
# ALB    138            Albania            Tirana    Europe        2842321.0
# DZA     34            Algeria           Algiers    Africa       44903225.0
# ASM    213     American Samoa         Pago Pago   Oceania          44273.0
# AND    203            Andorra  Andorra la Vella    Europe          79824.0
# ...    ...                ...               ...       ...              ...
# WLF    226  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# ESH    172     Western Sahara          El Aaiún    Africa         575986.0
# YEM     46              Yemen             Sanaa      Asia       33696614.0
# ZMB     63             Zambia            Lusaka    Africa       20017675.0
# ZWE     74           Zimbabwe            Harare    Africa       16320537.0
#
# ...

# %%
gr_2025 = df2['Growth Rate'] * 0.8
df2['Growth Rate2'] = gr_2025
df2
# Out:
#       Rank            Country           Capital Continent  2022 Population  \
# CCA3
# AFG     36        Afghanistan             Kabul      Asia       41128771.0
# ALB    138            Albania            Tirana    Europe        2842321.0
# DZA     34            Algeria           Algiers    Africa       44903225.0
# ASM    213     American Samoa         Pago Pago   Oceania          44273.0
# AND    203            Andorra  Andorra la Vella    Europe          79824.0
# ...    ...                ...               ...       ...              ...
# WLF    226  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# ESH    172     Western Sahara          El Aaiún    Africa         575986.0
# YEM     46              Yemen             Sanaa      Asia       33696614.0
# ZMB     63             Zambia            Lusaka    Africa       20017675.0
# ZWE     74           Zimbabwe            Harare    Africa       16320537.0
#
# ...

# %%
df2.sort_index(axis='columns', ascending = False)
# Out:
#       World Population Percentage  Rank  Growth Rate2  Growth Rate  \
# CCA3
# AFG                          0.52    36       0.82056       1.0257
# ALB                          0.04   138       0.79656       0.9957
# DZA                          0.56    34       0.81312       1.0164
# ASM                          0.00   213       0.78648       0.9831
# AND                          0.00   203       0.80800       1.0100
# ...                           ...   ...           ...          ...
# WLF                          0.00   226       0.79624       0.9953
# ESH                          0.01   172       0.81472       1.0184
# YEM                          0.42    46       0.81736       1.0217
# ZMB                          0.25    63       0.82240       1.0280
# ZWE                          0.20    74       0.81632       1.0204
#
#       Density (per km²)            Country Continent           Capital  \
# CCA3
# AFG             63.0587        Afghanistan      Asia             Kabul
# ...

# %%
df2.head(2)
# Out:
#       Rank      Country Capital Continent  2022 Population  2020 Population  \
# CCA3
# AFG     36  Afghanistan   Kabul      Asia       41128771.0       38972230.0
# ALB    138      Albania  Tirana    Europe        2842321.0        2866849.0
#
#       2015 Population  2010 Population  2000 Population  1990 Population  \
# CCA3
# AFG        33753499.0       28189672.0       19542982.0       10694796.0
# ALB         2882481.0        2913399.0        3182021.0        3295066.0
#
#       1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# CCA3
# AFG        12486631.0       10752971.0    652230.0            63.0587
# ALB         2941651.0        2324731.0     28748.0            98.8702
#
#       Growth Rate  World Population Percentage  2025 Population  Growth Rate2
# CCA3
# AFG        1.0257                         0.52       49354525.2       0.82056
# ALB        0.9957                         0.04        3410785.2       0.79656

# %%
del df2['alsdjfal']
# Out:
#       Rank           Capital Continent  2022 Population  2020 Population  \
# CCA3
# AFG     36             Kabul      Asia       41128771.0       38972230.0
# ALB    138            Tirana    Europe        2842321.0        2866849.0
# DZA     34           Algiers    Africa       44903225.0       43451666.0
# ASM    213         Pago Pago   Oceania          44273.0          46189.0
# AND    203  Andorra la Vella    Europe          79824.0          77700.0
# ...    ...               ...       ...              ...              ...
# WLF    226          Mata-Utu   Oceania          11572.0          11655.0
# ESH    172          El Aaiún    Africa         575986.0         556048.0
# YEM     46             Sanaa      Asia       33696614.0       32284046.0
# ZMB     63            Lusaka    Africa       20017675.0       18927715.0
# ZWE     74            Harare    Africa       16320537.0       15669666.0
#
#       2015 Population  2010 Population  2000 Population  1990 Population  \
# CCA3
# ...

# %%
df2 = df.set_index('CCA3')
df2.head(2)
# Out:
#       Rank      Country Capital Continent  2022 Population  2020 Population  \
# CCA3
# AFG     36  Afghanistan   Kabul      Asia       41128771.0       38972230.0
# ALB    138      Albania  Tirana    Europe        2842321.0        2866849.0
#
#       2015 Population  2010 Population  2000 Population  1990 Population  \
# CCA3
# AFG        33753499.0       28189672.0       19542982.0       10694796.0
# ALB         2882481.0        2913399.0        3182021.0        3295066.0
#
#       1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# CCA3
# AFG        12486631.0       10752971.0    652230.0            63.0587
# ALB         2941651.0        2324731.0     28748.0            98.8702
#
#       Growth Rate  World Population Percentage
# CCA3
# AFG        1.0257                         0.52
# ALB        0.9957                         0.04

# %%
# df2.sort_index(axis='columns', ascending=True)
df2.sort_values(
    ['Continent', '2022 Population'], 
    ascending=[True, False]
    )
# Out:
#       Rank           Country      Capital      Continent  2022 Population  \
# CCA3
# NGA      6           Nigeria        Abuja         Africa      218541212.0
# ETH     12          Ethiopia  Addis Ababa         Africa      123379924.0
# EGY     14             Egypt        Cairo         Africa      110990103.0
# COD     15          DR Congo     Kinshasa         Africa       99010212.0
# TZA     22          Tanzania       Dodoma         Africa       65497748.0
# ...    ...               ...          ...            ...              ...
# URY    133           Uruguay   Montevideo  South America        3422794.0
# GUY    164            Guyana   Georgetown  South America         808726.0
# SUR    170          Suriname   Paramaribo  South America         618040.0
# GUF    184     French Guiana      Cayenne  South America         304557.0
# FLK    231  Falkland Islands      Stanley  South America           3780.0
#
# ...

# %%
# df2['2022 Population']
m1 = df2.loc[:, '2022 Population'] > 50e6
m2 = df2.loc[:, 'Continent'] == 'Asia'
df2.loc[m1&m2, :]
# Out:
#       Rank      Country      Capital Continent  2022 Population  \
# CCA3
# BGD      8   Bangladesh        Dhaka      Asia     1.711864e+08
# CHN      1        China      Beijing      Asia     1.425887e+09
# IND      2        India    New Delhi      Asia     1.417173e+09
# IDN      4    Indonesia      Jakarta      Asia     2.755013e+08
# IRN     17         Iran       Tehran      Asia     8.855057e+07
# JPN     11        Japan        Tokyo      Asia     1.239517e+08
# MMR     26      Myanmar  Nay Pyi Taw      Asia     5.417931e+07
# PAK      5     Pakistan    Islamabad      Asia     2.358249e+08
# PHL     13  Philippines       Manila      Asia     1.155590e+08
# KOR     29  South Korea        Seoul      Asia     5.181581e+07
# THA     20     Thailand      Bangkok      Asia     7.169703e+07
# TUR     18       Turkey       Ankara      Asia     8.534124e+07
# VNM     16      Vietnam        Hanoi      Asia     9.818686e+07
#
# ...

# %%
# s = df2.pop('Country')
# del df2['Country']
# df2.drop(['Country'], axis='columns')

# %%
df_pop = df2.loc[:, '2022 Population':'1970 Population']
df_pop.head()
# Out:
#       2022 Population  2020 Population  2015 Population  2010 Population  \
# CCA3
# AFG        41128771.0       38972230.0       33753499.0       28189672.0
# ALB         2842321.0        2866849.0        2882481.0        2913399.0
# DZA        44903225.0       43451666.0       39543154.0       35856344.0
# ASM           44273.0          46189.0          51368.0          54849.0
# AND           79824.0          77700.0          71746.0          71519.0
#
#       2000 Population  1990 Population  1980 Population  1970 Population
# CCA3
# AFG        19542982.0       10694796.0       12486631.0       10752971.0
# ALB         3182021.0        3295066.0        2941651.0        2324731.0
# DZA        30774621.0       25518074.0       18739378.0       13795915.0
# ASM           58230.0          47818.0          32886.0          27075.0
# AND           66097.0          53569.0          35611.0          19860.0

# %%
m = df_pop > 50e6
df_pop[m].dropna(axis='rows', how='any')
# Out:
#       2022 Population  2020 Population  2015 Population  2010 Population  \
# CCA3
# BGD      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# BRA      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# CHN      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# FRA      6.462663e+07     6.448005e+07     6.380977e+07     6.244457e+07
# DEU      8.336984e+07     8.332899e+07     8.207323e+07     8.132509e+07
# IDN      2.755013e+08     2.718580e+08     2.590920e+08     2.440162e+08
# ITA      5.903747e+07     5.950058e+07     6.023291e+07     5.982245e+07
# JPN      1.239517e+08     1.252448e+08     1.272509e+08     1.281054e+08
# MEX      1.275041e+08     1.259983e+08     1.201499e+08     1.125324e+08
# NGA      2.185412e+08     2.083274e+08     1.839958e+08     1.609529e+08
# PAK      2.358249e+08     2.271967e+08     2.109693e+08     1.944545e+08
# RUS      1.447133e+08     1.456173e+08     1.446684e+08     1.432426e+08
# ...

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
m = arr > 3
m
# Out:
# array([False, False, False,  True,  True])

# %%
from functools import reduce
reduce((lambda a,b : a and b), m)
# Out:
# np.False_

# %%
df2.iloc[41]
# Out:
# Rank                                      1
# Country                               China
# Capital                             Beijing
# Continent                              Asia
# 2022 Population                1425887337.0
# 2020 Population                1424929781.0
# 2015 Population                1393715448.0
# 2010 Population                1348191368.0
# 2000 Population                1264099069.0
# 1990 Population                1153704252.0
# 1980 Population                 982372466.0
# 1970 Population                 822534450.0
# Area (km²)                        9706961.0
# Density (per km²)                  146.8933
# Growth Rate                             1.0
# World Population Percentage           17.88
# Name: CHN, dtype: object

# %%
df_pop.head()
# Out:
#       2022 Population  2020 Population  2015 Population  2010 Population  \
# CCA3
# AFG        41128771.0       38972230.0       33753499.0       28189672.0
# ALB         2842321.0        2866849.0        2882481.0        2913399.0
# DZA        44903225.0       43451666.0       39543154.0       35856344.0
# ASM           44273.0          46189.0          51368.0          54849.0
# AND           79824.0          77700.0          71746.0          71519.0
#
#       2000 Population  1990 Population  1980 Population  1970 Population
# CCA3
# AFG        19542982.0       10694796.0       12486631.0       10752971.0
# ALB         3182021.0        3295066.0        2941651.0        2324731.0
# DZA        30774621.0       25518074.0       18739378.0       13795915.0
# ASM           58230.0          47818.0          32886.0          27075.0
# AND           66097.0          53569.0          35611.0          19860.0

# %%
df_pop.median()
# Out:
# CCA3
# AFG    195521552.0
# ALB     23248519.0
# DZA    252582377.0
# ASM       362688.0
# AND       475926.0
#           ...
# WLF        97420.0
# ESH      2679204.0
# YEM    167293517.0
# ZMB     80317122.0
# ZWE     93186324.0
# Length: 234, dtype: float64

# %%
df_pop[df_pop.isna().any(axis=1)]
# Out:
#       2022 Population  2020 Population  2015 Population  2010 Population  \
# CCA3
# AZE      1.035807e+07              NaN     9.863480e+06     9.237202e+06
# COL      5.187402e+07     5.093066e+07     4.711973e+07              NaN
# GNQ      1.674908e+06     1.596049e+06              NaN     1.094524e+06
# SWZ               NaN     1.180655e+06     1.133936e+06     1.099920e+06
# GMB      2.705992e+06     2.573995e+06     2.253133e+06              NaN
# GEO      3.744385e+06     3.765912e+06     3.771132e+06              NaN
# HUN      9.967308e+06     9.750573e+06     9.844246e+06     9.986825e+06
# ISL      3.728990e+05     3.666690e+05     3.310600e+05     3.183330e+05
# IND      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# MYS      3.393822e+07     3.319999e+07     3.106883e+07              NaN
# MDV      5.237870e+05     5.144380e+05     4.355820e+05              NaN
# MOZ      3.296952e+07     3.117824e+07              NaN              NaN
# ...

# %%
df5 = df_pop.fillna(0)
df5.loc['AZE']
# Out:
# 2022 Population    10358074.0
# 2020 Population           0.0
# 2015 Population     9863480.0
# 2010 Population     9237202.0
# 2000 Population     8190337.0
# 1990 Population     7427836.0
# 1980 Population     6383060.0
# 1970 Population     5425317.0
# Name: AZE, dtype: float64

# %%
df2['Continent'].drop_duplicates()
# Out:
# CCA3
# AFG             Asia
# ALB           Europe
# DZA           Africa
# ASM          Oceania
# AIA    North America
# ARG    South America
# Name: Continent, dtype: object
