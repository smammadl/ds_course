# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# Given a system of linear equations:
#
# $$
# \begin{aligned}
# x_{11}\theta_1 + x_{12}\theta_2 + \cdots + x_{1n}\theta_n &= y_1 \\
# x_{21}\theta_1 + x_{22}\theta_2 + \cdots + x_{2n}\theta_n &= y_2 \\
# \vdots \quad \quad \quad \quad \quad &= \vdots \\
# x_{m1}\theta_1 + x_{m2}\theta_2 + \cdots + x_{mn}\theta_n &= y_m
# \end{aligned}
# $$
#
# This is equivalent to writing **$X\mathbf{\theta} = \mathbf{y}$**, where:
# $$
# X = \begin{pmatrix}
# x_{11} & x_{12} & \cdots & x_{1n} \\
# x_{21} & x_{22} & \cdots & x_{2n} \\
# \vdots & \vdots & \ddots & \vdots \\
# x_{m1} & x_{m2} & \cdots & x_{mn}
# \end{pmatrix} \in \mathbb{R}^{m \times n}
# $$
# $$
# \theta = \begin{pmatrix}
# \theta_1 \\
# \theta_2 \\
# \vdots \\
# \theta_n
# \end{pmatrix} \in \mathbb{R}^n
# $$
# $$
# y = \begin{pmatrix}
# y_1 \\
# y_2 \\
# \vdots \\
# y_m
# \end{pmatrix} \in \mathbb{R}^m
# $$
#
# If $X$ is **square** ($m = n$) and **invertible**, we can solve:
#
# $$\mathbf{\theta} = X^{-1}\mathbf{y}$$

# %%
# System: 
# 170theta1 + 25theta2 + theta3 = 7
# 180theta1 + 30theta2 + theta3 = 8
# 200theta1 + 35theta2 + theta3 = 12

X = np.array([
    [170, 25, 1],
    [180, 30, 1],
    [200, 35, 1]
])
y = np.array([7, 8, 12])

theta = np.linalg.inv(X) @ y
theta
# Out:
# array([  0.3,  -0.4, -34. ])

# %%
# solve() (more numerically stable)
theta = np.linalg.solve(X, y)
theta
# Out:
# array([  0.3,  -0.4, -34. ])

# %% [markdown]
# - $A$ is not square → $X^{-1}$ **doesn't exist**
# - We have **more observations than features** ($m > n$)

# %%
# System: 
# 170theta1 + 25theta2 + theta3 = 7
# 180theta1 + 30theta2 + theta3 = 8
# 200theta1 + 35theta2 + theta3 = 12
# 160theta1 + 20theta2 + theta3 = 15

X = np.array([
    [170, 25, 1],
    [180, 30, 1],
    [200, 35, 1],
    [160, 20, 1],
])
y = np.array([7, 8, 12, 15])

theta = np.linalg.inv(X) @ y
theta
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[9], line 15
#       7 X = np.array([
#       8     [170, 25, 1],
#       9     [180, 30, 1],
#      10     [200, 35, 1],
#      11     [160, 20, 1],
#      12 ])
#      13 y = np.array([7, 8, 12, 15])
# ---> 15 theta = np.linalg.inv(X) @ y
#      16 theta
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\numpy\linalg\_linalg.py:642, in inv(a)
#     538 """
#     539 Compute the inverse of a matrix.
#     540
#    (...)    639
#     640 """
#     641 a, wrap = _makearray(a)
# --> 642 _assert_stacked_square(a)
#     643 t, result_t = _commonType(a)
#     645 signature = 'D->D' if isComplexType(t) else 'd->d'
#
# File c:\Users\user\miniconda3\envs\ds\Lib\site-packages\numpy\linalg\_linalg.py:246, in _assert_stacked_square(*arrays)
#     243     raise LinAlgError('%d-dimensional array given. Array must be '
#     244             'at least two-dimensional' % a.ndim)
#     245 if m != n:
# --> 246     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square

# %% [markdown]
# to find $\mathbf{\theta}$ we need to minimize $f(\mathbf{\theta}) = \| X\mathbf{\theta} - \mathbf{y} \|$
#
# $$
# \begin{aligned}
# f(\theta) &= \|X\theta - y\|^2 \\
# &= (X\theta - y)^T (X\theta - y) \\
# &= (\theta^T X^T - y^T)(X\theta - y) \\
# &= \theta^T X^T X\theta - \theta^T X^T y - y^T X\theta + y^T y \\
# &= \theta^T X^T X\theta - 2y^T X\theta + y^T y
# \end{aligned}
# $$
#
# Derivative rules can be applied
# $$
# \begin{aligned}
# \frac{\partial}{\partial \theta} a^{T}\theta &= a \\
# \frac{\partial}{\partial \theta} \theta^{T}A\theta &= (A + A^T)\theta
# \end{aligned}
# $$
#
# Taking the derivative and setting to zero:
# $$
# \begin{aligned}
# \frac{\partial f}{\partial \theta} &= \frac{\partial}{\partial \theta} (\theta^T X^T X\theta - 2y^T X\theta + y^T y) \\
# &= 2X^T X\theta - 2X^T y \\
# &= 0
# \end{aligned}
# $$
#
# So we must have
# $$\begin{aligned}
# X^TX\mathbf{\theta} &= X^T\mathbf{y} \\
# \mathbf{\theta} &= (X^TX)^{-1}X^T\mathbf{y} \quad \text{(if } X^TX \text{ is invertible)}
# \end{aligned}$$

# %%
# System: 
# 170theta1 + 25theta2 + theta3 = 7
# 180theta1 + 30theta2 + theta3 = 8
# 200theta1 + 35theta2 + theta3 = 12
# 160theta1 + 20theta2 + theta3 = 15

X = np.array([
    [170, 25, 1],
    [180, 30, 1],
    [200, 35, 1],
    [160, 20, 1],
])
y = np.array([7, 8, 12, 15])

theta = np.linalg.pinv(X) @ y
theta
# Out:
# array([  0.9,  -2.5, -80.5])

# %% [markdown]
# **Problems with $(X^TX)^{-1}X^T\mathbf{y}$:**
#
# 1. High Computational Cost for inverting $X^TA$
# 2. $X^TA$ can be **ill-conditioned** (nearly singular). Small changes in data → huge changes in solution
# 3. Need to store $n \times n$ matrix

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X[:, :-1], y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (np.float64(-80.50000000000003), array([ 0.9, -2.5]))

# %% [markdown]
# # Gradient descent

# %% [markdown]
# $$f(x) = x^2 + 10$$
#
# This is a simple parabola with a global minimum at $x = 0$, where $f(0) = 10$.
#
# The derivative of this function is:
#
# $$f'(x) = 2x$$
#
# ### Initial Setup
# - Starting point: $x_0 = 5$
# - Learning rate: $\eta = 0.1$
# - We'll run for 10 iterations
#
# ### Iteration 1
# - Current position: $x_0 = 5$
# - Gradient: $f'(x_0) = 2 \times  5 = 10$
# - Update: $x_1 =  x_0 - \eta \times f'(x_0) =  5 - 0.1 \times 10 = 5 - 1 = 4$
# - New function value: $f(x_1) = 4^2 + 10 = 16 + 10 = 26$
#
# ### Iteration 2
# - Current position: $x_1 = 4$
# - Gradient: $f'(x_1) = 2 \times  4 = 8$
# - Update: $x_2 =  x_1 - \eta \times f'(x_1) =  4 - 0.1 \times 8 = 4 - 0.8 = 3.2$
# - New function value: $f(x_2) = 3.2^2 + 10 = 10.24 + 10 = 20.24$
#
# ### Iteration 3
# - Current position: $x_2 = 3.2$
# - Gradient: $f'(x_2) = 2 \times  3.2 = 6.4$
# - Update: $x_3 =  x_2 - \eta \times f'(x_2) =  3.2 - 0.1 \times 6.4 = 3.2 - 0.64 = 2.56$
# - New function value: $f(x_3) = 2.56^2 + 10 = 6.55 + 10 = 16.55$
#
# ### Iteration 4
# - Current position: $x_3 = 2.56$
# - Gradient: $f'(x_3) = 2 \times 2.56 = 5.12$
# - Update: $x_4 = x_3 - \eta \times f'(x_3) = 2.56 - 0.1 \times 5.12 = 2.56 - 0.512 = 2.048$
# - New function value: $f(x_4) = 2.048^2 + 10 = 4.19 + 10 = 14.19$
#
# ### Iteration 5
# - Current position: $x_4 = 2.048$
# - Gradient: $f'(x_4) = 2 \times 2.048 = 4.096$
# - Update: $x_5 = x_4 - \eta \times f'(x_4) = 2.048 - 0.1 \times 4.096 = 2.048 - 0.4096 = 1.6384$
# - New function value: $f(x_5) = 1.6384^2 + 10 = 2.68 + 10 = 12.68$
#
# ### Summary of Progress
#
# | Iteration | x value | Gradient | Function Value |
# |-----------|---------|----------|----------------|
# | 0         | 5.0000  | 10.0000  | 35.0000        |
# | 1         | 4.0000  | 8.0000   | 26.0000        |
# | 2         | 3.2000  | 6.4000   | 20.2400        |
# | 3         | 2.5600  | 5.1200   | 16.5536        |
# | 4         | 2.0480  | 4.0960   | 14.1943        |
# | 5         | 1.6384  | 3.2768   | 12.6829        |

# %%
theta1= np.array([0.3, 0.5, 0.7])
theta2= np.array([3, 5, 7])

np.linalg.norm(theta1), np.linalg.norm(theta2),
# Out:
# (np.float64(0.9110433579144298), np.float64(9.1104335791443))

# %% [markdown]
# # Gradient descent for LR

# %% [markdown]
# Instead of computing the inverse, **iteratively update** parameters to minimize the cost function.
#
# **Cost Function (MSE)**:
# $$J(\mathbf{\theta}) = \frac{1}{2m} \|X\mathbf{\theta} - \mathbf{y}\|^2$$
#
# Where $m$ is the size of sample. We divide by $2m$ because the cost function is defined as the mean of the squared errors.
#
# $$\begin{aligned}
# J(\mathbf{\theta}) &= \frac{1}{2m} \|X\mathbf{\theta} - \mathbf{y}\|^2 \\
# &= \frac{1}{2m} \|\mathbf{y}_{pred} - \mathbf{y}\|^2 \\
# &= \frac{1}{2m} \|\text{error}\|^2 \\
# &= \frac{1}{2m} (e_1^2 + e_2^2 + \dots + e_m^2) \\
# &= \frac{1}{2} \ \text{MSE}(\mathbf{\theta}) \\
# \end{aligned}$$
#
# ### The Gradient
#
# $$\begin{aligned}
# \nabla J(\mathbf{\theta}) &= \frac{\partial J}{\partial \mathbf{\theta}}  \\
#  &= \frac{\partial}{\partial \mathbf{\theta}} \left( \frac{1}{2m} \|X\mathbf{\theta} - \mathbf{y}\|^2 \right) \\
#  &= \frac{1}{2m} \frac{\partial}{\partial \mathbf{\theta}} \|X\mathbf{\theta} - \mathbf{y}\|^2 \\
#  &= \frac{1}{2m} 2 X^T(X\mathbf{\theta}-\mathbf{y}) \\
# &= \frac{1}{m} X^T(X\mathbf{\theta} - \mathbf{y})
# \end{aligned}$$
#
# ### Update Rule
#
# $$\mathbf{\theta}_{new} := \mathbf{\theta}_{old} - \eta \ \nabla J(\mathbf{\theta})$$
#
# Where $\eta$ is the **learning rate**.

# %% [markdown]
# ### Why Gradient Descent?
#
# | Aspect | Normal Equation | Gradient Descent |
# |--------|----------------|------------------|
# | Complexity | $O(n^3)$ | $O(k \cdot m \cdot n)$ |
# | Features | Works for small $n$ | Scales to large $n$ |
# | Inversion | Required | Not needed |
# | Learning Rate | N/A | Need to tune $\alpha$ |
# | Iterations | 1 (closed-form) | Many |
#
# ---

# %%
import numpy as np

rng = np.random.default_rng(seed=42)
m = 2000  # number of instances

boylar = rng.normal(175, 10, size=(m,1))
yashlar = rng.uniform(18, 60, size=(m,1))
# maashlar = rng.exponential(scale=4, size=(m,1))
# maashlar = rng.chisquare(df=6, size=(m,1))
maashlar = rng.gamma(shape=3.5, scale=2, size=(m,1))

plt.hist(maashlar, bins=100)
plt.show()

# %%
from sklearn.preprocessing import add_dummy_feature

X = np.hstack([boylar/100, yashlar/100])
X_b = add_dummy_feature(X)
# X_b = np.c_[X, np.ones((m, 1))]

y = maashlar/10

X_b, y
# Out:
# (array([[1.        , 1.78047171, 0.19778537],
#         [1.        , 1.64600159, 0.36687386],
#         [1.        , 1.82504512, 0.40973487],
#         ...,
#         [1.        , 1.740846  , 0.23681841],
#         [1.        , 1.69691782, 0.56835309],
#         [1.        , 1.97141526, 0.38183515]], shape=(2000, 3)),
#  array([[0.61006609],
#         [0.64261833],
#         [0.39956131],
#         ...,
#         [0.39419609],
#         [1.47388686],
#         [0.21100565]], shape=(2000, 1)))

# %% [markdown]
# ## Batch Gradient Descent

# %% [markdown]
# $$\nabla J(\mathbf{\theta}) = \frac{1}{m} X^T(X\mathbf{\theta} - \mathbf{y})$$
#
# $$\mathbf{\theta}_{new} := \mathbf{\theta}_{old} - \eta \ \nabla J(\mathbf{\theta}_{old})$$

# %%
from sklearn.metrics import mean_squared_error
eta = 0.1
m = len(X_b)
n_epochs = 1000

rng = np.random.default_rng(seed=123)
theta = rng.standard_normal(size=(3,1))

for epoch in range(n_epochs):
	gradient = (1 / m) * X_b.T @ (X_b @ theta - y)
	theta = theta - eta * gradient

	mse = mean_squared_error(X_b@theta, y)
	print(f"epoch {epoch}: mse = {mse:.3f}")
# Out:
# epoch 0: mse = 1.293
# epoch 1: mse = 0.546
# epoch 2: mse = 0.294
# epoch 3: mse = 0.210
# epoch 4: mse = 0.181
# epoch 5: mse = 0.172
# epoch 6: mse = 0.168
# epoch 7: mse = 0.167
# epoch 8: mse = 0.167
# epoch 9: mse = 0.166
# epoch 10: mse = 0.166
# epoch 11: mse = 0.166
# epoch 12: mse = 0.166
# epoch 13: mse = 0.166
# epoch 14: mse = 0.166
# epoch 15: mse = 0.166
# epoch 16: mse = 0.166
# epoch 17: mse = 0.166
# epoch 18: mse = 0.166
# epoch 19: mse = 0.165
# epoch 20: mse = 0.165
# epoch 21: mse = 0.165
# epoch 22: mse = 0.165
# epoch 23: mse = 0.165
# epoch 24: mse = 0.165
# epoch 25: mse = 0.165
# epoch 26: mse = 0.165
# epoch 27: mse = 0.165
# epoch 28: mse = 0.165
# epoch 29: mse = 0.165
# epoch 30: mse = 0.165
# epoch 31: mse = 0.164
# epoch 32: mse = 0.164
# epoch 33: mse = 0.164
# epoch 34: mse = 0.164
# epoch 35: mse = 0.164
# epoch 36: mse = 0.164
# epoch 37: mse = 0.164
# epoch 38: mse = 0.164
# epoch 39: mse = 0.164
# epoch 40: mse = 0.164
# epoch 41: mse = 0.164
# epoch 42: mse = 0.164
# epoch 43: mse = 0.163
# epoch 44: mse = 0.163
# epoch 45: mse = 0.163
# epoch 46: mse = 0.163
# epoch 47: mse = 0.163
# epoch 48: mse = 0.163
# epoch 49: mse = 0.163
# epoch 50: mse = 0.163
# epoch 51: mse = 0.163
# epoch 52: mse = 0.163
# epoch 53: mse = 0.163
# epoch 54: mse = 0.163
# epoch 55: mse = 0.162
# epoch 56: mse = 0.162
# epoch 57: mse = 0.162
# epoch 58: mse = 0.162
# epoch 59: mse = 0.162
# epoch 60: mse = 0.162
# epoch 61: mse = 0.162
# epoch 62: mse = 0.162
# epoch 63: mse = 0.162
# epoch 64: mse = 0.162
# epoch 65: mse = 0.162
# epoch 66: mse = 0.162
# epoch 67: mse = 0.162
# epoch 68: mse = 0.161
# epoch 69: mse = 0.161
# epoch 70: mse = 0.161
# epoch 71: mse = 0.161
# epoch 72: mse = 0.161
# epoch 73: mse = 0.161
# epoch 74: mse = 0.161
# epoch 75: mse = 0.161
# epoch 76: mse = 0.161
# epoch 77: mse = 0.161
# epoch 78: mse = 0.161
# epoch 79: mse = 0.161
# epoch 80: mse = 0.161
# epoch 81: mse = 0.161
# epoch 82: mse = 0.160
# epoch 83: mse = 0.160
# epoch 84: mse = 0.160
# epoch 85: mse = 0.160
# epoch 86: mse = 0.160
# epoch 87: mse = 0.160
# epoch 88: mse = 0.160
# epoch 89: mse = 0.160
# epoch 90: mse = 0.160
# epoch 91: mse = 0.160
# epoch 92: mse = 0.160
# epoch 93: mse = 0.160
# epoch 94: mse = 0.160
# epoch 95: mse = 0.160
# epoch 96: mse = 0.159
# epoch 97: mse = 0.159
# epoch 98: mse = 0.159
# epoch 99: mse = 0.159
# epoch 100: mse = 0.159
# epoch 101: mse = 0.159
# epoch 102: mse = 0.159
# epoch 103: mse = 0.159
# epoch 104: mse = 0.159
# epoch 105: mse = 0.159
# epoch 106: mse = 0.159
# epoch 107: mse = 0.159
# epoch 108: mse = 0.159
# epoch 109: mse = 0.159
# epoch 110: mse = 0.159
# epoch 111: mse = 0.158
# epoch 112: mse = 0.158
# epoch 113: mse = 0.158
# epoch 114: mse = 0.158
# epoch 115: mse = 0.158
# epoch 116: mse = 0.158
# epoch 117: mse = 0.158
# epoch 118: mse = 0.158
# epoch 119: mse = 0.158
# epoch 120: mse = 0.158
# epoch 121: mse = 0.158
# epoch 122: mse = 0.158
# epoch 123: mse = 0.158
# epoch 124: mse = 0.158
# epoch 125: mse = 0.158
# epoch 126: mse = 0.157
# epoch 127: mse = 0.157
# epoch 128: mse = 0.157
# epoch 129: mse = 0.157
# epoch 130: mse = 0.157
# epoch 131: mse = 0.157
# epoch 132: mse = 0.157
# epoch 133: mse = 0.157
# epoch 134: mse = 0.157
# epoch 135: mse = 0.157
# epoch 136: mse = 0.157
# epoch 137: mse = 0.157
# epoch 138: mse = 0.157
# epoch 139: mse = 0.157
# epoch 140: mse = 0.157
# epoch 141: mse = 0.157
# epoch 142: mse = 0.156
# epoch 143: mse = 0.156
# epoch 144: mse = 0.156
# epoch 145: mse = 0.156
# epoch 146: mse = 0.156
# epoch 147: mse = 0.156
# epoch 148: mse = 0.156
# epoch 149: mse = 0.156
# epoch 150: mse = 0.156
# epoch 151: mse = 0.156
# epoch 152: mse = 0.156
# epoch 153: mse = 0.156
# epoch 154: mse = 0.156
# epoch 155: mse = 0.156
# epoch 156: mse = 0.156
# epoch 157: mse = 0.156
# epoch 158: mse = 0.155
# epoch 159: mse = 0.155
# epoch 160: mse = 0.155
# epoch 161: mse = 0.155
# epoch 162: mse = 0.155
# epoch 163: mse = 0.155
# epoch 164: mse = 0.155
# epoch 165: mse = 0.155
# epoch 166: mse = 0.155
# epoch 167: mse = 0.155
# epoch 168: mse = 0.155
# epoch 169: mse = 0.155
# epoch 170: mse = 0.155
# epoch 171: mse = 0.155
# epoch 172: mse = 0.155
# epoch 173: mse = 0.155
# epoch 174: mse = 0.155
# epoch 175: mse = 0.155
# epoch 176: mse = 0.154
# epoch 177: mse = 0.154
# epoch 178: mse = 0.154
# epoch 179: mse = 0.154
# epoch 180: mse = 0.154
# epoch 181: mse = 0.154
# epoch 182: mse = 0.154
# epoch 183: mse = 0.154
# epoch 184: mse = 0.154
# epoch 185: mse = 0.154
# epoch 186: mse = 0.154
# epoch 187: mse = 0.154
# epoch 188: mse = 0.154
# epoch 189: mse = 0.154
# epoch 190: mse = 0.154
# epoch 191: mse = 0.154
# epoch 192: mse = 0.154
# epoch 193: mse = 0.154
# epoch 194: mse = 0.153
# epoch 195: mse = 0.153
# epoch 196: mse = 0.153
# epoch 197: mse = 0.153
# epoch 198: mse = 0.153
# epoch 199: mse = 0.153
# epoch 200: mse = 0.153
# epoch 201: mse = 0.153
# epoch 202: mse = 0.153
# epoch 203: mse = 0.153
# epoch 204: mse = 0.153
# epoch 205: mse = 0.153
# epoch 206: mse = 0.153
# epoch 207: mse = 0.153
# epoch 208: mse = 0.153
# epoch 209: mse = 0.153
# epoch 210: mse = 0.153
# epoch 211: mse = 0.153
# epoch 212: mse = 0.153
# epoch 213: mse = 0.153
# epoch 214: mse = 0.152
# epoch 215: mse = 0.152
# epoch 216: mse = 0.152
# epoch 319: mse = 0.148
# epoch 320: mse = 0.148
# epoch 321: mse = 0.148
# epoch 322: mse = 0.148
# epoch 323: mse = 0.148
# epoch 324: mse = 0.148
# epoch 325: mse = 0.148
# epoch 326: mse = 0.148
# epoch 327: mse = 0.148
# epoch 328: mse = 0.148
# epoch 329: mse = 0.148
# epoch 330: mse = 0.148
# epoch 331: mse = 0.148
# epoch 332: mse = 0.147
# epoch 333: mse = 0.147
# epoch 334: mse = 0.147
# epoch 335: mse = 0.147
# epoch 336: mse = 0.147
# epoch 337: mse = 0.147
# epoch 338: mse = 0.147
# epoch 339: mse = 0.147
# epoch 340: mse = 0.147
# epoch 341: mse = 0.147
# epoch 342: mse = 0.147
# epoch 343: mse = 0.147
# epoch 344: mse = 0.147
# epoch 345: mse = 0.147
# epoch 346: mse = 0.147
# epoch 347: mse = 0.147
# epoch 348: mse = 0.147
# epoch 349: mse = 0.147
# epoch 350: mse = 0.147
# epoch 351: mse = 0.147
# epoch 352: mse = 0.147
# epoch 353: mse = 0.147
# epoch 354: mse = 0.147
# epoch 355: mse = 0.147
# epoch 356: mse = 0.147
# epoch 357: mse = 0.147
# epoch 358: mse = 0.147
# epoch 359: mse = 0.147
# epoch 360: mse = 0.147
# epoch 361: mse = 0.146
# epoch 362: mse = 0.146
# epoch 363: mse = 0.146
# epoch 364: mse = 0.146
# epoch 365: mse = 0.146
# epoch 366: mse = 0.146
# epoch 367: mse = 0.146
# epoch 368: mse = 0.146
# epoch 369: mse = 0.146
# epoch 370: mse = 0.146
# epoch 371: mse = 0.146
# epoch 372: mse = 0.146
# epoch 373: mse = 0.146
# epoch 374: mse = 0.146
# epoch 375: mse = 0.146
# epoch 376: mse = 0.146
# epoch 377: mse = 0.146
# epoch 378: mse = 0.146
# epoch 379: mse = 0.146
# epoch 380: mse = 0.146
# epoch 381: mse = 0.146
# epoch 382: mse = 0.146
# epoch 383: mse = 0.146
# epoch 384: mse = 0.146
# epoch 385: mse = 0.146
# epoch 386: mse = 0.146
# epoch 387: mse = 0.146
# epoch 388: mse = 0.146
# epoch 389: mse = 0.146
# epoch 390: mse = 0.146
# epoch 391: mse = 0.146
# epoch 392: mse = 0.146
# epoch 393: mse = 0.145
# epoch 394: mse = 0.145
# epoch 395: mse = 0.145
# epoch 396: mse = 0.145
# epoch 397: mse = 0.145
# epoch 398: mse = 0.145
# epoch 399: mse = 0.145
# epoch 400: mse = 0.145
# epoch 401: mse = 0.145
# epoch 402: mse = 0.145
# epoch 403: mse = 0.145
# epoch 404: mse = 0.145
# epoch 405: mse = 0.145
# epoch 406: mse = 0.145
# epoch 407: mse = 0.145
# epoch 408: mse = 0.145
# epoch 409: mse = 0.145
# epoch 410: mse = 0.145
# epoch 411: mse = 0.145
# epoch 412: mse = 0.145
# epoch 413: mse = 0.145
# epoch 414: mse = 0.145
# epoch 415: mse = 0.145
# epoch 416: mse = 0.145
# epoch 417: mse = 0.145
# epoch 418: mse = 0.145
# epoch 419: mse = 0.145
# epoch 420: mse = 0.145
# epoch 421: mse = 0.145
# epoch 422: mse = 0.145
# epoch 423: mse = 0.145
# epoch 424: mse = 0.145
# epoch 425: mse = 0.145
# epoch 426: mse = 0.145
# epoch 427: mse = 0.145
# epoch 428: mse = 0.144
# epoch 429: mse = 0.144
# epoch 430: mse = 0.144
# epoch 431: mse = 0.144
# epoch 432: mse = 0.144
# epoch 433: mse = 0.144
# epoch 434: mse = 0.144
# epoch 435: mse = 0.144
# epoch 436: mse = 0.144
# epoch 437: mse = 0.144
# epoch 438: mse = 0.144
# epoch 439: mse = 0.144
# epoch 440: mse = 0.144
# epoch 441: mse = 0.144
# epoch 442: mse = 0.144
# epoch 443: mse = 0.144
# epoch 444: mse = 0.144
# epoch 445: mse = 0.144
# epoch 446: mse = 0.144
# epoch 447: mse = 0.144
# epoch 448: mse = 0.144
# epoch 449: mse = 0.144
# epoch 450: mse = 0.144
# epoch 451: mse = 0.144
# epoch 452: mse = 0.144
# epoch 453: mse = 0.144
# epoch 454: mse = 0.144
# epoch 455: mse = 0.144
# epoch 456: mse = 0.144
# epoch 457: mse = 0.144
# epoch 458: mse = 0.144
# epoch 459: mse = 0.144
# epoch 460: mse = 0.144
# epoch 461: mse = 0.144
# epoch 462: mse = 0.144
# epoch 463: mse = 0.144
# epoch 464: mse = 0.144
# epoch 465: mse = 0.144
# epoch 466: mse = 0.144
# epoch 467: mse = 0.143
# epoch 468: mse = 0.143
# epoch 469: mse = 0.143
# epoch 470: mse = 0.143
# epoch 471: mse = 0.143
# epoch 472: mse = 0.143
# epoch 473: mse = 0.143
# epoch 474: mse = 0.143
# epoch 475: mse = 0.143
# epoch 476: mse = 0.143
# epoch 477: mse = 0.143
# epoch 478: mse = 0.143
# epoch 479: mse = 0.143
# epoch 480: mse = 0.143
# epoch 481: mse = 0.143
# epoch 482: mse = 0.143
# epoch 483: mse = 0.143
# epoch 484: mse = 0.143
# epoch 485: mse = 0.143
# epoch 486: mse = 0.143
# epoch 487: mse = 0.143
# epoch 488: mse = 0.143
# epoch 489: mse = 0.143
# epoch 490: mse = 0.143
# epoch 491: mse = 0.143
# epoch 492: mse = 0.143
# epoch 493: mse = 0.143
# epoch 494: mse = 0.143
# epoch 495: mse = 0.143
# epoch 496: mse = 0.143
# epoch 497: mse = 0.143
# epoch 498: mse = 0.143
# epoch 499: mse = 0.143
# epoch 500: mse = 0.143
# epoch 501: mse = 0.143
# epoch 502: mse = 0.143
# epoch 503: mse = 0.143
# epoch 504: mse = 0.143
# epoch 505: mse = 0.143
# epoch 506: mse = 0.143
# epoch 507: mse = 0.143
# epoch 508: mse = 0.143
# epoch 509: mse = 0.143
# epoch 510: mse = 0.142
# epoch 511: mse = 0.142
# epoch 512: mse = 0.142
# epoch 513: mse = 0.142
# epoch 514: mse = 0.142
# epoch 515: mse = 0.142
# epoch 516: mse = 0.142
# epoch 517: mse = 0.142
# epoch 518: mse = 0.142
# epoch 519: mse = 0.142
# epoch 520: mse = 0.142
# epoch 521: mse = 0.142
# epoch 522: mse = 0.142
# epoch 523: mse = 0.142
# epoch 524: mse = 0.142
# epoch 525: mse = 0.142
# epoch 526: mse = 0.142
# epoch 527: mse = 0.142
# epoch 528: mse = 0.142
# epoch 529: mse = 0.142
# epoch 530: mse = 0.142
# epoch 531: mse = 0.142
# epoch 532: mse = 0.142
# epoch 533: mse = 0.142
# epoch 534: mse = 0.142
# epoch 535: mse = 0.142
# epoch 536: mse = 0.142
# epoch 537: mse = 0.142
# epoch 538: mse = 0.142
# epoch 539: mse = 0.142
# epoch 540: mse = 0.142
# epoch 541: mse = 0.142
# epoch 542: mse = 0.142
# epoch 543: mse = 0.142
# epoch 544: mse = 0.142
# epoch 545: mse = 0.142
# epoch 546: mse = 0.142
# epoch 547: mse = 0.142
# epoch 548: mse = 0.142
# epoch 549: mse = 0.142
# epoch 550: mse = 0.142
# epoch 551: mse = 0.142
# epoch 552: mse = 0.142
# epoch 553: mse = 0.142
# epoch 554: mse = 0.142
# epoch 555: mse = 0.142
# epoch 556: mse = 0.142
# epoch 557: mse = 0.142
# epoch 558: mse = 0.142
# epoch 559: mse = 0.141
# epoch 560: mse = 0.141
# epoch 561: mse = 0.141
# epoch 562: mse = 0.141
# epoch 563: mse = 0.141
# epoch 564: mse = 0.141
# epoch 565: mse = 0.141
# epoch 566: mse = 0.141
# epoch 567: mse = 0.141
# epoch 568: mse = 0.141
# epoch 569: mse = 0.141
# epoch 570: mse = 0.141
# epoch 571: mse = 0.141
# epoch 572: mse = 0.141
# epoch 573: mse = 0.141
# epoch 574: mse = 0.141
# epoch 575: mse = 0.141
# epoch 576: mse = 0.141
# epoch 577: mse = 0.141
# epoch 578: mse = 0.141
# epoch 579: mse = 0.141
# epoch 580: mse = 0.141
# epoch 581: mse = 0.141
# epoch 582: mse = 0.141
# epoch 583: mse = 0.141
# epoch 584: mse = 0.141
# epoch 585: mse = 0.141
# epoch 586: mse = 0.141
# epoch 587: mse = 0.141
# epoch 588: mse = 0.141
# epoch 589: mse = 0.141
# epoch 590: mse = 0.141
# epoch 591: mse = 0.141
# epoch 592: mse = 0.141
# epoch 593: mse = 0.141
# epoch 594: mse = 0.141
# epoch 595: mse = 0.141
# epoch 596: mse = 0.141
# epoch 597: mse = 0.141
# epoch 598: mse = 0.141
# epoch 599: mse = 0.141
# epoch 600: mse = 0.141
# epoch 601: mse = 0.141
# epoch 602: mse = 0.141
# epoch 603: mse = 0.141
# epoch 604: mse = 0.141
# epoch 605: mse = 0.141
# epoch 606: mse = 0.141
# epoch 607: mse = 0.141
# epoch 608: mse = 0.141
# epoch 609: mse = 0.141
# epoch 610: mse = 0.141
# epoch 611: mse = 0.141
# epoch 612: mse = 0.141
# epoch 613: mse = 0.141
# epoch 614: mse = 0.141
# epoch 615: mse = 0.141
# epoch 616: mse = 0.140
# epoch 617: mse = 0.140
# epoch 618: mse = 0.140
# epoch 619: mse = 0.140
# epoch 620: mse = 0.140
# epoch 621: mse = 0.140
# epoch 622: mse = 0.140
# epoch 623: mse = 0.140
# epoch 624: mse = 0.140
# epoch 625: mse = 0.140
# epoch 626: mse = 0.140
# epoch 627: mse = 0.140
# epoch 628: mse = 0.140
# epoch 629: mse = 0.140
# epoch 630: mse = 0.140
# epoch 631: mse = 0.140
# epoch 632: mse = 0.140
# epoch 633: mse = 0.140
# epoch 634: mse = 0.140
# epoch 635: mse = 0.140
# epoch 636: mse = 0.140
# epoch 637: mse = 0.140
# epoch 638: mse = 0.140
# epoch 639: mse = 0.140
# epoch 640: mse = 0.140
# epoch 641: mse = 0.140
# epoch 642: mse = 0.140
# epoch 643: mse = 0.140
# epoch 644: mse = 0.140
# epoch 645: mse = 0.140
# epoch 646: mse = 0.140
# epoch 647: mse = 0.140
# epoch 648: mse = 0.140
# epoch 649: mse = 0.140
# epoch 650: mse = 0.140
# epoch 651: mse = 0.140
# epoch 652: mse = 0.140
# epoch 653: mse = 0.140
# epoch 654: mse = 0.140
# epoch 655: mse = 0.140
# epoch 656: mse = 0.140
# epoch 657: mse = 0.140
# epoch 658: mse = 0.140
# epoch 659: mse = 0.140
# epoch 660: mse = 0.140
# epoch 661: mse = 0.140
# epoch 662: mse = 0.140
# epoch 663: mse = 0.140
# epoch 664: mse = 0.140
# epoch 665: mse = 0.140
# epoch 666: mse = 0.140
# epoch 667: mse = 0.140
# epoch 668: mse = 0.140
# epoch 669: mse = 0.140
# epoch 670: mse = 0.140
# epoch 671: mse = 0.140
# epoch 672: mse = 0.140
# epoch 673: mse = 0.140
# epoch 674: mse = 0.140
# epoch 675: mse = 0.140
# epoch 676: mse = 0.140
# epoch 677: mse = 0.140
# epoch 678: mse = 0.140
# epoch 679: mse = 0.140
# epoch 680: mse = 0.140
# epoch 681: mse = 0.140
# epoch 682: mse = 0.140
# epoch 683: mse = 0.139
# epoch 684: mse = 0.139
# epoch 685: mse = 0.139
# epoch 686: mse = 0.139
# epoch 687: mse = 0.139
# epoch 688: mse = 0.139
# epoch 689: mse = 0.139
# epoch 690: mse = 0.139
# epoch 691: mse = 0.139
# epoch 692: mse = 0.139
# epoch 693: mse = 0.139
# epoch 694: mse = 0.139
# epoch 695: mse = 0.139
# epoch 696: mse = 0.139
# epoch 697: mse = 0.139
# epoch 698: mse = 0.139
# epoch 699: mse = 0.139
# epoch 700: mse = 0.139
# epoch 701: mse = 0.139
# epoch 702: mse = 0.139
# epoch 703: mse = 0.139
# epoch 704: mse = 0.139
# epoch 705: mse = 0.139
# epoch 706: mse = 0.139
# epoch 707: mse = 0.139
# epoch 708: mse = 0.139
# epoch 709: mse = 0.139
# epoch 710: mse = 0.139
# epoch 711: mse = 0.139
# epoch 712: mse = 0.139
# epoch 713: mse = 0.139
# epoch 714: mse = 0.139
# epoch 715: mse = 0.139
# epoch 716: mse = 0.139
# epoch 717: mse = 0.139
# epoch 718: mse = 0.139
# epoch 719: mse = 0.139
# epoch 720: mse = 0.139
# epoch 721: mse = 0.139
# epoch 722: mse = 0.139
# epoch 723: mse = 0.139
# epoch 724: mse = 0.139
# epoch 725: mse = 0.139
# epoch 726: mse = 0.139
# epoch 727: mse = 0.139
# epoch 728: mse = 0.139
# epoch 729: mse = 0.139
# epoch 730: mse = 0.139
# epoch 731: mse = 0.139
# epoch 732: mse = 0.139
# epoch 733: mse = 0.139
# epoch 734: mse = 0.139
# epoch 735: mse = 0.139
# epoch 736: mse = 0.139
# epoch 737: mse = 0.139
# epoch 738: mse = 0.139
# epoch 739: mse = 0.139
# epoch 740: mse = 0.139
# epoch 741: mse = 0.139
# epoch 742: mse = 0.139
# epoch 743: mse = 0.139
# epoch 744: mse = 0.139
# epoch 745: mse = 0.139
# epoch 746: mse = 0.139
# epoch 747: mse = 0.139
# epoch 748: mse = 0.139
# epoch 749: mse = 0.139
# epoch 750: mse = 0.139
# epoch 751: mse = 0.139
# epoch 752: mse = 0.139
# epoch 753: mse = 0.139
# epoch 754: mse = 0.139
# epoch 755: mse = 0.139
# epoch 756: mse = 0.139
# epoch 757: mse = 0.139
# epoch 758: mse = 0.139
# epoch 759: mse = 0.139
# epoch 760: mse = 0.139
# epoch 761: mse = 0.139
# epoch 762: mse = 0.139
# epoch 763: mse = 0.139
# epoch 764: mse = 0.138
# epoch 765: mse = 0.138
# epoch 766: mse = 0.138
# epoch 767: mse = 0.138
# epoch 768: mse = 0.138
# epoch 769: mse = 0.138
# epoch 770: mse = 0.138
# epoch 771: mse = 0.138
# epoch 772: mse = 0.138
# epoch 773: mse = 0.138
# epoch 774: mse = 0.138
# epoch 775: mse = 0.138
# epoch 776: mse = 0.138
# epoch 777: mse = 0.138
# epoch 778: mse = 0.138
# epoch 779: mse = 0.138
# epoch 780: mse = 0.138
# epoch 781: mse = 0.138
# epoch 782: mse = 0.138
# epoch 783: mse = 0.138
# epoch 784: mse = 0.138
# epoch 785: mse = 0.138
# epoch 786: mse = 0.138
# epoch 787: mse = 0.138
# epoch 788: mse = 0.138
# epoch 789: mse = 0.138
# epoch 790: mse = 0.138
# epoch 791: mse = 0.138
# epoch 792: mse = 0.138
# epoch 793: mse = 0.138
# epoch 794: mse = 0.138
# epoch 795: mse = 0.138
# epoch 796: mse = 0.138
# epoch 797: mse = 0.138
# epoch 798: mse = 0.138
# epoch 799: mse = 0.138
# epoch 800: mse = 0.138
# epoch 801: mse = 0.138
# epoch 802: mse = 0.138
# epoch 803: mse = 0.138
# epoch 804: mse = 0.138
# epoch 805: mse = 0.138
# epoch 806: mse = 0.138
# epoch 807: mse = 0.138
# epoch 808: mse = 0.138
# epoch 809: mse = 0.138
# epoch 810: mse = 0.138
# epoch 811: mse = 0.138
# epoch 812: mse = 0.138
# epoch 813: mse = 0.138
# epoch 814: mse = 0.138
# epoch 815: mse = 0.138
# epoch 816: mse = 0.138
# epoch 817: mse = 0.138
# epoch 818: mse = 0.138
# epoch 819: mse = 0.138
# epoch 820: mse = 0.138
# epoch 821: mse = 0.138
# epoch 822: mse = 0.138
# epoch 823: mse = 0.138
# epoch 824: mse = 0.138
# epoch 825: mse = 0.138
# epoch 826: mse = 0.138
# epoch 827: mse = 0.138
# epoch 828: mse = 0.138
# epoch 829: mse = 0.138
# epoch 830: mse = 0.138
# epoch 831: mse = 0.138
# epoch 832: mse = 0.138
# epoch 833: mse = 0.138
# epoch 834: mse = 0.138
# epoch 835: mse = 0.138
# epoch 836: mse = 0.138
# epoch 837: mse = 0.138
# epoch 838: mse = 0.138
# epoch 839: mse = 0.138
# epoch 840: mse = 0.138
# epoch 841: mse = 0.138
# epoch 842: mse = 0.138
# epoch 843: mse = 0.138
# epoch 844: mse = 0.138
# epoch 845: mse = 0.138
# epoch 846: mse = 0.138
# epoch 847: mse = 0.138
# epoch 848: mse = 0.138
# epoch 849: mse = 0.138
# epoch 850: mse = 0.138
# epoch 851: mse = 0.138
# epoch 852: mse = 0.138
# epoch 853: mse = 0.138
# epoch 854: mse = 0.138
# epoch 855: mse = 0.138
# epoch 856: mse = 0.138
# epoch 857: mse = 0.138
# epoch 858: mse = 0.138
# epoch 859: mse = 0.138
# epoch 860: mse = 0.138
# epoch 861: mse = 0.138
# epoch 862: mse = 0.138
# epoch 863: mse = 0.138
# epoch 864: mse = 0.138
# epoch 865: mse = 0.138
# epoch 866: mse = 0.138
# epoch 867: mse = 0.137
# epoch 868: mse = 0.137
# epoch 869: mse = 0.137
# epoch 870: mse = 0.137
# epoch 871: mse = 0.137
# epoch 872: mse = 0.137
# epoch 873: mse = 0.137
# epoch 874: mse = 0.137
# epoch 875: mse = 0.137
# epoch 876: mse = 0.137
# epoch 877: mse = 0.137
# epoch 878: mse = 0.137
# epoch 879: mse = 0.137
# epoch 880: mse = 0.137
# epoch 881: mse = 0.137
# epoch 882: mse = 0.137
# epoch 883: mse = 0.137
# epoch 884: mse = 0.137
# epoch 885: mse = 0.137
# epoch 886: mse = 0.137
# epoch 887: mse = 0.137
# epoch 888: mse = 0.137
# epoch 889: mse = 0.137
# epoch 890: mse = 0.137
# epoch 891: mse = 0.137
# epoch 892: mse = 0.137
# epoch 893: mse = 0.137
# epoch 894: mse = 0.137
# epoch 895: mse = 0.137
# epoch 896: mse = 0.137
# epoch 897: mse = 0.137
# epoch 898: mse = 0.137
# epoch 899: mse = 0.137
# epoch 900: mse = 0.137
# epoch 901: mse = 0.137
# epoch 902: mse = 0.137
# epoch 903: mse = 0.137
# epoch 904: mse = 0.137
# epoch 905: mse = 0.137
# epoch 906: mse = 0.137
# epoch 907: mse = 0.137
# epoch 908: mse = 0.137
# epoch 909: mse = 0.137
# epoch 910: mse = 0.137
# epoch 911: mse = 0.137
# epoch 912: mse = 0.137
# epoch 913: mse = 0.137
# epoch 914: mse = 0.137
# epoch 915: mse = 0.137
# epoch 916: mse = 0.137
# epoch 917: mse = 0.137
# epoch 918: mse = 0.137
# epoch 919: mse = 0.137
# epoch 920: mse = 0.137
# epoch 921: mse = 0.137
# epoch 922: mse = 0.137
# epoch 923: mse = 0.137
# epoch 924: mse = 0.137
# epoch 925: mse = 0.137
# epoch 926: mse = 0.137
# epoch 927: mse = 0.137
# epoch 928: mse = 0.137
# epoch 929: mse = 0.137
# epoch 930: mse = 0.137
# epoch 931: mse = 0.137
# epoch 932: mse = 0.137
# epoch 933: mse = 0.137
# epoch 934: mse = 0.137
# epoch 935: mse = 0.137
# epoch 936: mse = 0.137
# epoch 937: mse = 0.137
# epoch 938: mse = 0.137
# epoch 939: mse = 0.137
# epoch 940: mse = 0.137
# epoch 941: mse = 0.137
# epoch 942: mse = 0.137
# epoch 943: mse = 0.137
# epoch 944: mse = 0.137
# epoch 945: mse = 0.137
# epoch 946: mse = 0.137
# epoch 947: mse = 0.137
# epoch 948: mse = 0.137
# epoch 949: mse = 0.137
# epoch 950: mse = 0.137
# epoch 951: mse = 0.137
# epoch 952: mse = 0.137
# epoch 953: mse = 0.137
# epoch 954: mse = 0.137
# epoch 955: mse = 0.137
# epoch 956: mse = 0.137
# epoch 957: mse = 0.137
# epoch 958: mse = 0.137
# epoch 959: mse = 0.137
# epoch 960: mse = 0.137
# epoch 961: mse = 0.137
# epoch 962: mse = 0.137
# epoch 963: mse = 0.137
# epoch 964: mse = 0.137
# epoch 965: mse = 0.137
# epoch 966: mse = 0.137
# epoch 967: mse = 0.137
# epoch 968: mse = 0.137
# epoch 969: mse = 0.137
# epoch 970: mse = 0.137
# epoch 971: mse = 0.137
# epoch 972: mse = 0.137
# epoch 973: mse = 0.137
# epoch 974: mse = 0.137
# epoch 975: mse = 0.137
# epoch 976: mse = 0.137
# epoch 977: mse = 0.137
# epoch 978: mse = 0.137
# epoch 979: mse = 0.137
# epoch 980: mse = 0.137
# epoch 981: mse = 0.137
# epoch 982: mse = 0.137
# epoch 983: mse = 0.137
# epoch 984: mse = 0.137
# epoch 985: mse = 0.137
# epoch 986: mse = 0.137
# epoch 987: mse = 0.137
# epoch 988: mse = 0.137
# epoch 989: mse = 0.137
# epoch 990: mse = 0.137
# epoch 991: mse = 0.137
# epoch 992: mse = 0.137
# epoch 993: mse = 0.137
# epoch 994: mse = 0.137
# epoch 995: mse = 0.137
# epoch 996: mse = 0.137
# epoch 997: mse = 0.137
# epoch 998: mse = 0.137
# epoch 999: mse = 0.137

# %% [markdown]
# ## Stochastic Gradient Descent

# %% [markdown]
# $$\nabla J_i(\mathbf{\theta}) = X_i^T(X_i\mathbf{\theta} - \mathbf{y}_i)$$
#
# $$\mathbf{\theta}_{new} := \mathbf{\theta}_{old} - \eta \ \nabla J_i(\mathbf{\theta}_{old})$$

# %%
eta = 0.01
n_epochs = 100
m = len(X_b)

theta = rng.standard_normal(size=(3,1))
sample_size = 100


for epoch in range(n_epochs):
	for iteration in range(sample_size):
		i = rng.integers(m)
		Xi = X_b[i:i+1]
		yi = y[i:i+1]


		gradient_i = Xi.T @ (Xi @ theta - yi)
		theta = theta - eta * gradient_i

	mse = mean_squared_error(X_b@theta, y)
	print(f"epoch {epoch}: mse = {mse:.3f}")
# Out:
# epoch 0: mse = 0.161
# epoch 1: mse = 0.145
# epoch 2: mse = 0.175
# epoch 3: mse = 0.148
# epoch 4: mse = 0.141
# epoch 5: mse = 0.141
# epoch 6: mse = 0.142
# epoch 7: mse = 0.141
# epoch 8: mse = 0.143
# epoch 9: mse = 0.140
# epoch 10: mse = 0.149
# epoch 11: mse = 0.144
# epoch 12: mse = 0.141
# epoch 13: mse = 0.142
# epoch 14: mse = 0.140
# epoch 15: mse = 0.140
# epoch 16: mse = 0.139
# epoch 17: mse = 0.142
# epoch 18: mse = 0.139
# epoch 19: mse = 0.144
# epoch 20: mse = 0.143
# epoch 21: mse = 0.139
# epoch 22: mse = 0.139
# epoch 23: mse = 0.140
# epoch 24: mse = 0.148
# epoch 25: mse = 0.146
# epoch 26: mse = 0.140
# epoch 27: mse = 0.140
# epoch 28: mse = 0.139
# epoch 29: mse = 0.140
# epoch 30: mse = 0.139
# epoch 31: mse = 0.139
# epoch 32: mse = 0.139
# epoch 33: mse = 0.141
# epoch 34: mse = 0.139
# epoch 35: mse = 0.139
# epoch 36: mse = 0.139
# epoch 37: mse = 0.148
# epoch 38: mse = 0.142
# epoch 39: mse = 0.143
# epoch 40: mse = 0.148
# epoch 41: mse = 0.144
# epoch 42: mse = 0.143
# epoch 43: mse = 0.139
# epoch 44: mse = 0.140
# epoch 45: mse = 0.138
# epoch 46: mse = 0.150
# epoch 47: mse = 0.139
# epoch 48: mse = 0.138
# epoch 49: mse = 0.138
# epoch 50: mse = 0.138
# epoch 51: mse = 0.141
# epoch 52: mse = 0.138
# epoch 53: mse = 0.138
# epoch 54: mse = 0.137
# epoch 55: mse = 0.137
# epoch 56: mse = 0.144
# epoch 57: mse = 0.138
# epoch 58: mse = 0.138
# epoch 59: mse = 0.140
# epoch 60: mse = 0.137
# epoch 61: mse = 0.145
# epoch 62: mse = 0.137
# epoch 63: mse = 0.141
# epoch 64: mse = 0.137
# epoch 65: mse = 0.139
# epoch 66: mse = 0.143
# epoch 67: mse = 0.137
# epoch 68: mse = 0.168
# epoch 69: mse = 0.140
# epoch 70: mse = 0.137
# epoch 71: mse = 0.137
# epoch 72: mse = 0.147
# epoch 73: mse = 0.137
# epoch 74: mse = 0.142
# epoch 75: mse = 0.137
# epoch 76: mse = 0.137
# epoch 77: mse = 0.137
# epoch 78: mse = 0.140
# epoch 79: mse = 0.143
# epoch 80: mse = 0.139
# epoch 81: mse = 0.136
# epoch 82: mse = 0.139
# epoch 83: mse = 0.138
# epoch 84: mse = 0.137
# epoch 85: mse = 0.136
# epoch 86: mse = 0.141
# epoch 87: mse = 0.137
# epoch 88: mse = 0.139
# epoch 89: mse = 0.138
# epoch 90: mse = 0.141
# epoch 91: mse = 0.139
# epoch 92: mse = 0.139
# epoch 93: mse = 0.141
# epoch 94: mse = 0.140
# epoch 95: mse = 0.136
# epoch 96: mse = 0.138
# epoch 97: mse = 0.137
# epoch 98: mse = 0.144
# epoch 99: mse = 0.137

# %%
theta
# Out:
# array([[-0.26884769],
#        [ 0.47688869],
#        [ 0.34663288]])

# %%
sgd.coef_, sgd.intercept_
# Out:
# (array([0.27539471, 0.04333292]), array([0.18374098]))

# %%
from sklearn.linear_model import SGDRegressor

sgd = SGDRegressor()
sgd.fit(X, y.flatten())
y_pred = sgd.predict(X)
mean_squared_error(y_pred, y.flatten())
# Out:
# 0.13321022546040467

# %% [markdown]
# # mini batch gd

# %% [markdown]
# $$\nabla J_{batch}(\mathbf{\theta}) = \frac{1}{m_{batch}} X_{batch}^T(X_{batch}\mathbf{\theta} - \mathbf{y}_{batch})$$
#
# $$\mathbf{\theta}_{new} := \mathbf{\theta}_{old} - \eta \ \nabla J_{batch}(\mathbf{\theta}_{old})$$

# %%
eta = 0.005
n_epochs = 10000
m = len(X_b) # 2000
minibatch_size = 50
n_batches_per_epoch = np.ceil(m / minibatch_size).astype('int') # 40

theta = rng.standard_normal(size=(3,1))
sample_size = 100


for epoch in range(n_epochs):
	shuffled_indices = rng.permutation(m)
	X_b_sh = X_b[shuffled_indices]
	y_sh = y[shuffled_indices]

	for iteration in range(n_batches_per_epoch): # iteration = 39
		i = iteration * minibatch_size # i = 2 * 50 = 100
		X_batch = X_b[i : i+minibatch_size] # 100 : 150
		y_batch = y[i : i+minibatch_size]

		gradient_batch = (1/minibatch_size) * X_batch.T @ (X_batch @ theta - y_batch)
		theta = theta - eta * gradient_batch

	mse = mean_squared_error(X_b@theta, y)
	print(f"epoch {epoch}: mse = {mse:.3f}")
# Out:
# epoch 0: mse = 0.398
# epoch 1: mse = 0.278
# epoch 2: mse = 0.256
# epoch 3: mse = 0.251
# epoch 4: mse = 0.249
# epoch 5: mse = 0.249
# epoch 6: mse = 0.248
# epoch 7: mse = 0.247
# epoch 8: mse = 0.246
# epoch 9: mse = 0.246
# epoch 10: mse = 0.245
# epoch 11: mse = 0.244
# epoch 12: mse = 0.244
# epoch 13: mse = 0.243
# epoch 14: mse = 0.243
# epoch 15: mse = 0.242
# epoch 16: mse = 0.241
# epoch 17: mse = 0.241
# epoch 18: mse = 0.240
# epoch 19: mse = 0.239
# epoch 20: mse = 0.239
# epoch 21: mse = 0.238
# epoch 22: mse = 0.237
# epoch 23: mse = 0.237
# epoch 24: mse = 0.236
# epoch 25: mse = 0.236
# epoch 26: mse = 0.235
# epoch 27: mse = 0.234
# epoch 28: mse = 0.234
# epoch 29: mse = 0.233
# epoch 30: mse = 0.233
# epoch 31: mse = 0.232
# epoch 32: mse = 0.231
# epoch 33: mse = 0.231
# epoch 34: mse = 0.230
# epoch 35: mse = 0.230
# epoch 36: mse = 0.229
# epoch 37: mse = 0.229
# epoch 38: mse = 0.228
# epoch 39: mse = 0.227
# epoch 40: mse = 0.227
# epoch 41: mse = 0.226
# epoch 42: mse = 0.226
# epoch 43: mse = 0.225
# epoch 44: mse = 0.225
# epoch 45: mse = 0.224
# epoch 46: mse = 0.224
# epoch 47: mse = 0.223
# epoch 48: mse = 0.222
# epoch 49: mse = 0.222
# epoch 50: mse = 0.221
# epoch 51: mse = 0.221
# epoch 52: mse = 0.220
# epoch 53: mse = 0.220
# epoch 54: mse = 0.219
# epoch 55: mse = 0.219
# epoch 56: mse = 0.218
# epoch 57: mse = 0.218
# epoch 58: mse = 0.217
# epoch 59: mse = 0.217
# epoch 60: mse = 0.216
# epoch 61: mse = 0.216
# epoch 62: mse = 0.215
# epoch 63: mse = 0.215
# epoch 64: mse = 0.214
# epoch 65: mse = 0.214
# epoch 66: mse = 0.213
# epoch 67: mse = 0.213
# epoch 68: mse = 0.212
# epoch 69: mse = 0.212
# epoch 70: mse = 0.212
# epoch 71: mse = 0.211
# epoch 72: mse = 0.211
# epoch 73: mse = 0.210
# epoch 74: mse = 0.210
# epoch 75: mse = 0.209
# epoch 76: mse = 0.209
# epoch 77: mse = 0.208
# epoch 78: mse = 0.208
# epoch 79: mse = 0.207
# epoch 80: mse = 0.207
# epoch 81: mse = 0.207
# epoch 82: mse = 0.206
# epoch 83: mse = 0.206
# epoch 84: mse = 0.205
# epoch 85: mse = 0.205
# epoch 86: mse = 0.204
# epoch 87: mse = 0.204
# epoch 88: mse = 0.204
# epoch 89: mse = 0.203
# epoch 90: mse = 0.203
# epoch 91: mse = 0.202
# epoch 92: mse = 0.202
# epoch 93: mse = 0.201
# epoch 94: mse = 0.201
# epoch 95: mse = 0.201
# epoch 96: mse = 0.200
# epoch 97: mse = 0.200
# epoch 98: mse = 0.199
# epoch 99: mse = 0.199
# epoch 100: mse = 0.199
# epoch 101: mse = 0.198
# epoch 102: mse = 0.198
# epoch 103: mse = 0.198
# epoch 104: mse = 0.197
# epoch 105: mse = 0.197
# epoch 106: mse = 0.196
# epoch 107: mse = 0.196
# epoch 108: mse = 0.196
# epoch 109: mse = 0.195
# epoch 110: mse = 0.195
# epoch 111: mse = 0.195
# epoch 112: mse = 0.194
# epoch 113: mse = 0.194
# epoch 114: mse = 0.193
# epoch 115: mse = 0.193
# epoch 116: mse = 0.193
# epoch 117: mse = 0.192
# epoch 118: mse = 0.192
# epoch 119: mse = 0.192
# epoch 120: mse = 0.191
# epoch 121: mse = 0.191
# epoch 122: mse = 0.191
# epoch 123: mse = 0.190
# epoch 124: mse = 0.190
# epoch 125: mse = 0.190
# epoch 126: mse = 0.189
# epoch 127: mse = 0.189
# epoch 128: mse = 0.189
# epoch 129: mse = 0.188
# epoch 130: mse = 0.188
# epoch 131: mse = 0.188
# epoch 132: mse = 0.187
# epoch 133: mse = 0.187
# epoch 134: mse = 0.187
# epoch 135: mse = 0.186
# epoch 136: mse = 0.186
# epoch 137: mse = 0.186
# epoch 138: mse = 0.185
# epoch 139: mse = 0.185
# epoch 140: mse = 0.185
# epoch 141: mse = 0.184
# epoch 142: mse = 0.184
# epoch 143: mse = 0.184
# epoch 144: mse = 0.184
# epoch 145: mse = 0.183
# epoch 146: mse = 0.183
# epoch 147: mse = 0.183
# epoch 148: mse = 0.182
# epoch 149: mse = 0.182
# epoch 150: mse = 0.182
# epoch 151: mse = 0.181
# epoch 152: mse = 0.181
# epoch 153: mse = 0.181
# epoch 154: mse = 0.181
# epoch 155: mse = 0.180
# epoch 156: mse = 0.180
# epoch 157: mse = 0.180
# epoch 158: mse = 0.179
# epoch 159: mse = 0.179
# epoch 160: mse = 0.179
# epoch 161: mse = 0.179
# epoch 162: mse = 0.178
# epoch 163: mse = 0.178
# epoch 164: mse = 0.178
# epoch 165: mse = 0.178
# epoch 166: mse = 0.177
# epoch 167: mse = 0.177
# epoch 168: mse = 0.177
# epoch 169: mse = 0.176
# epoch 170: mse = 0.176
# epoch 171: mse = 0.176
# epoch 172: mse = 0.176
# epoch 173: mse = 0.175
# epoch 174: mse = 0.175
# epoch 175: mse = 0.175
# epoch 176: mse = 0.175
# epoch 177: mse = 0.174
# epoch 178: mse = 0.174
# epoch 179: mse = 0.174
# epoch 180: mse = 0.174
# epoch 181: mse = 0.173
# epoch 182: mse = 0.173
# epoch 183: mse = 0.173
# epoch 184: mse = 0.173
# epoch 185: mse = 0.173
# epoch 186: mse = 0.172
# epoch 187: mse = 0.172
# epoch 188: mse = 0.172
# epoch 189: mse = 0.172
# epoch 190: mse = 0.171
# epoch 191: mse = 0.171
# epoch 192: mse = 0.171
# epoch 193: mse = 0.171
# epoch 194: mse = 0.170
# epoch 195: mse = 0.170
# epoch 196: mse = 0.170
# epoch 197: mse = 0.170
# epoch 198: mse = 0.170
# epoch 199: mse = 0.169
# epoch 200: mse = 0.169
# epoch 201: mse = 0.169
# epoch 202: mse = 0.169
# epoch 203: mse = 0.168
# epoch 204: mse = 0.168
# epoch 205: mse = 0.168
# epoch 206: mse = 0.168
# epoch 207: mse = 0.168
# epoch 208: mse = 0.167
# epoch 209: mse = 0.167
# epoch 210: mse = 0.167
# epoch 211: mse = 0.167
# epoch 212: mse = 0.167
# epoch 213: mse = 0.166
# epoch 214: mse = 0.166
# epoch 215: mse = 0.166
# epoch 216: mse = 0.166
# epoch 217: mse = 0.166
# epoch 218: mse = 0.165
# epoch 219: mse = 0.165
# epoch 220: mse = 0.165
# epoch 221: mse = 0.165
# epoch 222: mse = 0.165
# epoch 223: mse = 0.164
# epoch 224: mse = 0.164
# epoch 225: mse = 0.164
# epoch 226: mse = 0.164
# epoch 227: mse = 0.164
# epoch 228: mse = 0.163
# epoch 229: mse = 0.163
# epoch 230: mse = 0.163
# epoch 231: mse = 0.163
# epoch 232: mse = 0.163
# epoch 233: mse = 0.163
# epoch 234: mse = 0.162
# epoch 235: mse = 0.162
# epoch 236: mse = 0.162
# epoch 237: mse = 0.162
# epoch 238: mse = 0.162
# epoch 239: mse = 0.162
# epoch 240: mse = 0.161
# epoch 241: mse = 0.161
# epoch 242: mse = 0.161
# epoch 243: mse = 0.161
# epoch 244: mse = 0.161
# epoch 245: mse = 0.161
# epoch 246: mse = 0.160
# epoch 247: mse = 0.160
# epoch 248: mse = 0.160
# epoch 249: mse = 0.160
# epoch 250: mse = 0.160
# epoch 251: mse = 0.160
# epoch 252: mse = 0.159
# epoch 253: mse = 0.159
# epoch 254: mse = 0.159
# epoch 255: mse = 0.159
# epoch 256: mse = 0.159
# epoch 257: mse = 0.159
# epoch 258: mse = 0.158
# epoch 259: mse = 0.158
# epoch 260: mse = 0.158
# epoch 261: mse = 0.158
# epoch 262: mse = 0.158
# epoch 263: mse = 0.158
# epoch 264: mse = 0.158
# epoch 265: mse = 0.157
# epoch 266: mse = 0.157
# epoch 267: mse = 0.157
# epoch 268: mse = 0.157
# epoch 269: mse = 0.157
# epoch 270: mse = 0.157
# epoch 271: mse = 0.156
# epoch 272: mse = 0.156
# epoch 273: mse = 0.156
# epoch 274: mse = 0.156
# epoch 275: mse = 0.156
# epoch 276: mse = 0.156
# epoch 277: mse = 0.156
# epoch 278: mse = 0.156
# epoch 279: mse = 0.155
# epoch 280: mse = 0.155
# epoch 281: mse = 0.155
# epoch 282: mse = 0.155
# epoch 283: mse = 0.155
# epoch 284: mse = 0.155
# epoch 285: mse = 0.155
# epoch 286: mse = 0.154
# epoch 287: mse = 0.154
# epoch 288: mse = 0.154
# epoch 289: mse = 0.154
# epoch 290: mse = 0.154
# epoch 291: mse = 0.154
# epoch 292: mse = 0.154
# epoch 293: mse = 0.154
# epoch 294: mse = 0.153
# epoch 295: mse = 0.153
# epoch 296: mse = 0.153
# epoch 297: mse = 0.153
# epoch 298: mse = 0.153
# epoch 299: mse = 0.153
# epoch 300: mse = 0.153
# epoch 301: mse = 0.153
# epoch 302: mse = 0.152
# epoch 303: mse = 0.152
# epoch 304: mse = 0.152
# epoch 305: mse = 0.152
# epoch 306: mse = 0.152
# epoch 307: mse = 0.152
# epoch 308: mse = 0.152
# epoch 309: mse = 0.152
# epoch 310: mse = 0.152
# epoch 311: mse = 0.151
# epoch 312: mse = 0.151
# epoch 313: mse = 0.151
# epoch 314: mse = 0.151
# epoch 315: mse = 0.151
# epoch 316: mse = 0.151
# epoch 317: mse = 0.151
# epoch 318: mse = 0.151
# epoch 319: mse = 0.151
# epoch 320: mse = 0.150
# epoch 321: mse = 0.150
# epoch 322: mse = 0.150
# epoch 323: mse = 0.150
# epoch 324: mse = 0.150
# epoch 325: mse = 0.150
# epoch 326: mse = 0.150
# epoch 327: mse = 0.150
# epoch 328: mse = 0.150
# epoch 329: mse = 0.149
# epoch 330: mse = 0.149
# epoch 331: mse = 0.149
# epoch 332: mse = 0.149
# epoch 333: mse = 0.149
# epoch 334: mse = 0.149
# epoch 335: mse = 0.149
# epoch 336: mse = 0.149
# epoch 337: mse = 0.149
# epoch 338: mse = 0.149
# epoch 339: mse = 0.148
# epoch 340: mse = 0.148
# epoch 341: mse = 0.148
# epoch 342: mse = 0.148
# epoch 343: mse = 0.148
# epoch 344: mse = 0.148
# epoch 345: mse = 0.148
# epoch 346: mse = 0.148
# epoch 347: mse = 0.148
# epoch 348: mse = 0.148
# epoch 349: mse = 0.148
# epoch 350: mse = 0.147
# epoch 351: mse = 0.147
# epoch 352: mse = 0.147
# epoch 353: mse = 0.147
# epoch 354: mse = 0.147
# epoch 355: mse = 0.147
# epoch 356: mse = 0.147
# epoch 357: mse = 0.147
# epoch 358: mse = 0.147
# epoch 359: mse = 0.147
# epoch 360: mse = 0.147
# epoch 361: mse = 0.146
# epoch 362: mse = 0.146
# epoch 363: mse = 0.146
# epoch 364: mse = 0.146
# epoch 365: mse = 0.146
# epoch 366: mse = 0.146
# epoch 367: mse = 0.146
# epoch 368: mse = 0.146
# epoch 369: mse = 0.146
# epoch 370: mse = 0.146
# epoch 371: mse = 0.146
# epoch 372: mse = 0.146
# epoch 373: mse = 0.146
# epoch 374: mse = 0.145
# epoch 375: mse = 0.145
# epoch 376: mse = 0.145
# epoch 377: mse = 0.145
# epoch 378: mse = 0.145
# epoch 379: mse = 0.145
# epoch 380: mse = 0.145
# epoch 381: mse = 0.145
# epoch 382: mse = 0.145
# epoch 383: mse = 0.145
# epoch 384: mse = 0.145
# epoch 385: mse = 0.145
# epoch 386: mse = 0.145
# epoch 387: mse = 0.144
# epoch 388: mse = 0.144
# epoch 389: mse = 0.144
# epoch 390: mse = 0.144
# epoch 391: mse = 0.144
# epoch 392: mse = 0.144
# epoch 393: mse = 0.144
# epoch 394: mse = 0.144
# epoch 395: mse = 0.144
# epoch 396: mse = 0.144
# epoch 397: mse = 0.144
# epoch 398: mse = 0.144
# epoch 399: mse = 0.144
# epoch 400: mse = 0.144
# epoch 401: mse = 0.143
# epoch 402: mse = 0.143
# epoch 403: mse = 0.143
# epoch 404: mse = 0.143
# epoch 405: mse = 0.143
# epoch 406: mse = 0.143
# epoch 407: mse = 0.143
# epoch 408: mse = 0.143
# epoch 409: mse = 0.143
# epoch 410: mse = 0.143
# epoch 411: mse = 0.143
# epoch 412: mse = 0.143
# epoch 413: mse = 0.143
# epoch 414: mse = 0.143
# epoch 415: mse = 0.143
# epoch 416: mse = 0.143
# epoch 417: mse = 0.142
# epoch 418: mse = 0.142
# epoch 419: mse = 0.142
# epoch 420: mse = 0.142
# epoch 421: mse = 0.142
# epoch 422: mse = 0.142
# epoch 423: mse = 0.142
# epoch 424: mse = 0.142
# epoch 425: mse = 0.142
# epoch 426: mse = 0.142
# epoch 427: mse = 0.142
# epoch 428: mse = 0.142
# epoch 429: mse = 0.142
# epoch 430: mse = 0.142
# epoch 431: mse = 0.142
# epoch 432: mse = 0.142
# epoch 433: mse = 0.142
# epoch 434: mse = 0.141
# epoch 435: mse = 0.141
# epoch 436: mse = 0.141
# epoch 437: mse = 0.141
# epoch 438: mse = 0.141
# epoch 439: mse = 0.141
# epoch 440: mse = 0.141
# epoch 441: mse = 0.141
# epoch 442: mse = 0.141
# epoch 443: mse = 0.141
# epoch 444: mse = 0.141
# epoch 445: mse = 0.141
# epoch 446: mse = 0.141
# epoch 447: mse = 0.141
# epoch 448: mse = 0.141
# epoch 449: mse = 0.141
# epoch 450: mse = 0.141
# epoch 451: mse = 0.141
# epoch 452: mse = 0.141
# epoch 453: mse = 0.141
# epoch 454: mse = 0.140
# epoch 455: mse = 0.140
# epoch 456: mse = 0.140
# epoch 457: mse = 0.140
# epoch 458: mse = 0.140
# epoch 459: mse = 0.140
# epoch 460: mse = 0.140
# epoch 461: mse = 0.140
# epoch 462: mse = 0.140
# epoch 463: mse = 0.140
# epoch 464: mse = 0.140
# epoch 465: mse = 0.140
# epoch 466: mse = 0.140
# epoch 467: mse = 0.140
# epoch 468: mse = 0.140
# epoch 469: mse = 0.140
# epoch 470: mse = 0.140
# epoch 471: mse = 0.140
# epoch 472: mse = 0.140
# epoch 473: mse = 0.140
# epoch 474: mse = 0.140
# epoch 475: mse = 0.139
# epoch 476: mse = 0.139
# epoch 477: mse = 0.139
# epoch 478: mse = 0.139
# epoch 479: mse = 0.139
# epoch 480: mse = 0.139
# epoch 481: mse = 0.139
# epoch 482: mse = 0.139
# epoch 483: mse = 0.139
# epoch 484: mse = 0.139
# epoch 485: mse = 0.139
# epoch 486: mse = 0.139
# epoch 487: mse = 0.139
# epoch 488: mse = 0.139
# epoch 489: mse = 0.139
# epoch 490: mse = 0.139
# epoch 491: mse = 0.139
# epoch 492: mse = 0.139
# epoch 493: mse = 0.139
# epoch 494: mse = 0.139
# epoch 495: mse = 0.139
# epoch 496: mse = 0.139
# epoch 497: mse = 0.139
# epoch 498: mse = 0.139
# epoch 499: mse = 0.139
# epoch 500: mse = 0.138
# epoch 501: mse = 0.138
# epoch 502: mse = 0.138
# epoch 503: mse = 0.138
# epoch 504: mse = 0.138
# epoch 505: mse = 0.138
# epoch 506: mse = 0.138
# epoch 507: mse = 0.138
# epoch 508: mse = 0.138
# epoch 509: mse = 0.138
# epoch 510: mse = 0.138
# epoch 511: mse = 0.138
# epoch 512: mse = 0.138
# epoch 513: mse = 0.138
# epoch 514: mse = 0.138
# epoch 515: mse = 0.138
# epoch 516: mse = 0.138
# epoch 517: mse = 0.138
# epoch 518: mse = 0.138
# epoch 519: mse = 0.138
# epoch 520: mse = 0.138
# epoch 521: mse = 0.138
# epoch 522: mse = 0.138
# epoch 523: mse = 0.138
# epoch 524: mse = 0.138
# epoch 525: mse = 0.138
# epoch 526: mse = 0.138
# epoch 527: mse = 0.138
# epoch 528: mse = 0.138
# epoch 529: mse = 0.138
# epoch 530: mse = 0.137
# epoch 531: mse = 0.137
# epoch 532: mse = 0.137
# epoch 533: mse = 0.137
# epoch 534: mse = 0.137
# epoch 535: mse = 0.137
# epoch 536: mse = 0.137
# epoch 537: mse = 0.137
# epoch 538: mse = 0.137
# epoch 539: mse = 0.137
# epoch 540: mse = 0.137
# epoch 541: mse = 0.137
# epoch 542: mse = 0.137
# epoch 543: mse = 0.137
# epoch 544: mse = 0.137
# epoch 545: mse = 0.137
# epoch 546: mse = 0.137
# epoch 547: mse = 0.137
# epoch 548: mse = 0.137
# epoch 549: mse = 0.137
# epoch 550: mse = 0.137
# epoch 551: mse = 0.137
# epoch 552: mse = 0.137
# epoch 553: mse = 0.137
# epoch 554: mse = 0.137
# epoch 555: mse = 0.137
# epoch 556: mse = 0.137
# epoch 557: mse = 0.137
# epoch 558: mse = 0.137
# epoch 559: mse = 0.137
# epoch 560: mse = 0.137
# epoch 561: mse = 0.137
# epoch 562: mse = 0.137
# epoch 563: mse = 0.137
# epoch 564: mse = 0.137
# epoch 565: mse = 0.136
# epoch 566: mse = 0.136
# epoch 567: mse = 0.136
# epoch 568: mse = 0.136
# epoch 569: mse = 0.136
# epoch 570: mse = 0.136
# epoch 571: mse = 0.136
# epoch 572: mse = 0.136
# epoch 573: mse = 0.136
# epoch 574: mse = 0.136
# epoch 575: mse = 0.136
# epoch 576: mse = 0.136
# epoch 577: mse = 0.136
# epoch 578: mse = 0.136
# epoch 579: mse = 0.136
# epoch 580: mse = 0.136
# epoch 581: mse = 0.136
# epoch 582: mse = 0.136
# epoch 583: mse = 0.136
# epoch 584: mse = 0.136
# epoch 585: mse = 0.136
# epoch 586: mse = 0.136
# epoch 587: mse = 0.136
# epoch 588: mse = 0.136
# epoch 589: mse = 0.136
# epoch 590: mse = 0.136
# epoch 591: mse = 0.136
# epoch 592: mse = 0.136
# epoch 593: mse = 0.136
# epoch 594: mse = 0.136
# epoch 595: mse = 0.136
# epoch 596: mse = 0.136
# epoch 597: mse = 0.136
# epoch 598: mse = 0.136
# epoch 599: mse = 0.136
# epoch 600: mse = 0.136
# epoch 601: mse = 0.136
# epoch 602: mse = 0.136
# epoch 603: mse = 0.136
# epoch 604: mse = 0.136
# epoch 605: mse = 0.136
# epoch 606: mse = 0.136
# epoch 607: mse = 0.136
# epoch 608: mse = 0.136
# epoch 609: mse = 0.135
# epoch 610: mse = 0.135
# epoch 611: mse = 0.135
# epoch 612: mse = 0.135
# epoch 613: mse = 0.135
# epoch 614: mse = 0.135
# epoch 615: mse = 0.135
# epoch 616: mse = 0.135
# epoch 617: mse = 0.135
# epoch 618: mse = 0.135
# epoch 619: mse = 0.135
# epoch 620: mse = 0.135
# epoch 621: mse = 0.135
# epoch 622: mse = 0.135
# epoch 623: mse = 0.135
# epoch 624: mse = 0.135
# epoch 625: mse = 0.135
# epoch 626: mse = 0.135
# epoch 627: mse = 0.135
# epoch 628: mse = 0.135
# epoch 629: mse = 0.135
# epoch 630: mse = 0.135
# epoch 631: mse = 0.135
# epoch 632: mse = 0.135
# epoch 633: mse = 0.135
# epoch 634: mse = 0.135
# epoch 635: mse = 0.135
# epoch 636: mse = 0.135
# epoch 637: mse = 0.135
# epoch 638: mse = 0.135
# epoch 639: mse = 0.135
# epoch 640: mse = 0.135
# epoch 641: mse = 0.135
# epoch 642: mse = 0.135
# epoch 643: mse = 0.135
# epoch 644: mse = 0.135
# epoch 645: mse = 0.135
# epoch 646: mse = 0.135
# epoch 647: mse = 0.135
# epoch 648: mse = 0.135
# epoch 649: mse = 0.135
# epoch 650: mse = 0.135
# epoch 651: mse = 0.135
# epoch 652: mse = 0.135
# epoch 653: mse = 0.135
# epoch 654: mse = 0.135
# epoch 655: mse = 0.135
# epoch 656: mse = 0.135
# epoch 657: mse = 0.135
# epoch 658: mse = 0.135
# epoch 659: mse = 0.135
# epoch 660: mse = 0.135
# epoch 661: mse = 0.135
# epoch 662: mse = 0.135
# epoch 663: mse = 0.135
# epoch 664: mse = 0.135
# epoch 665: mse = 0.135
# epoch 666: mse = 0.135
# epoch 667: mse = 0.135
# epoch 668: mse = 0.135
# epoch 669: mse = 0.134
# epoch 670: mse = 0.134
# epoch 671: mse = 0.134
# epoch 672: mse = 0.134
# epoch 673: mse = 0.134
# epoch 674: mse = 0.134
# epoch 675: mse = 0.134
# epoch 676: mse = 0.134
# epoch 677: mse = 0.134
# epoch 678: mse = 0.134
# epoch 679: mse = 0.134
# epoch 680: mse = 0.134
# epoch 681: mse = 0.134
# epoch 682: mse = 0.134
# epoch 683: mse = 0.134
# epoch 684: mse = 0.134
# epoch 685: mse = 0.134
# epoch 686: mse = 0.134
# epoch 687: mse = 0.134
# epoch 688: mse = 0.134
# epoch 689: mse = 0.134
# epoch 690: mse = 0.134
# epoch 691: mse = 0.134
# epoch 692: mse = 0.134
# epoch 693: mse = 0.134
# epoch 694: mse = 0.134
# epoch 695: mse = 0.134
# epoch 696: mse = 0.134
# epoch 697: mse = 0.134
# epoch 698: mse = 0.134
# epoch 699: mse = 0.134
# epoch 700: mse = 0.134
# epoch 701: mse = 0.134
# epoch 702: mse = 0.134
# epoch 703: mse = 0.134
# epoch 704: mse = 0.134
# epoch 705: mse = 0.134
# epoch 706: mse = 0.134
# epoch 707: mse = 0.134
# epoch 708: mse = 0.134
# epoch 709: mse = 0.134
# epoch 710: mse = 0.134
# epoch 711: mse = 0.134
# epoch 712: mse = 0.134
# epoch 713: mse = 0.134
# epoch 714: mse = 0.134
# epoch 715: mse = 0.134
# epoch 716: mse = 0.134
# epoch 717: mse = 0.134
# epoch 718: mse = 0.134
# epoch 719: mse = 0.134
# epoch 720: mse = 0.134
# epoch 721: mse = 0.134
# epoch 722: mse = 0.134
# epoch 723: mse = 0.134
# epoch 724: mse = 0.134
# epoch 725: mse = 0.134
# epoch 726: mse = 0.134
# epoch 727: mse = 0.134
# epoch 728: mse = 0.134
# epoch 729: mse = 0.134
# epoch 730: mse = 0.134
# epoch 731: mse = 0.134
# epoch 732: mse = 0.134
# epoch 733: mse = 0.134
# epoch 734: mse = 0.134
# epoch 735: mse = 0.134
# epoch 736: mse = 0.134
# epoch 737: mse = 0.134
# epoch 738: mse = 0.134
# epoch 739: mse = 0.134
# epoch 740: mse = 0.134
# epoch 741: mse = 0.134
# epoch 742: mse = 0.134
# epoch 743: mse = 0.134
# epoch 744: mse = 0.134
# epoch 745: mse = 0.134
# epoch 746: mse = 0.134
# epoch 747: mse = 0.134
# epoch 748: mse = 0.134
# epoch 749: mse = 0.134
# epoch 750: mse = 0.134
# epoch 751: mse = 0.134
# epoch 752: mse = 0.134
# epoch 753: mse = 0.134
# epoch 754: mse = 0.134
# epoch 755: mse = 0.134
# epoch 756: mse = 0.134
# epoch 757: mse = 0.134
# epoch 758: mse = 0.134
# epoch 759: mse = 0.134
# epoch 760: mse = 0.134
# epoch 761: mse = 0.134
# epoch 762: mse = 0.134
# epoch 763: mse = 0.133
# epoch 764: mse = 0.133
# epoch 765: mse = 0.133
# epoch 766: mse = 0.133
# epoch 767: mse = 0.133
# epoch 768: mse = 0.133
# epoch 769: mse = 0.133
# epoch 770: mse = 0.133
# epoch 771: mse = 0.133
# epoch 772: mse = 0.133
# epoch 773: mse = 0.133
# epoch 774: mse = 0.133
# epoch 775: mse = 0.133
# epoch 776: mse = 0.133
# epoch 777: mse = 0.133
# epoch 778: mse = 0.133
# epoch 779: mse = 0.133
# epoch 780: mse = 0.133
# epoch 781: mse = 0.133
# epoch 782: mse = 0.133
# epoch 783: mse = 0.133
# epoch 784: mse = 0.133
# epoch 785: mse = 0.133
# epoch 786: mse = 0.133
# epoch 787: mse = 0.133
# epoch 788: mse = 0.133
# epoch 789: mse = 0.133
# epoch 790: mse = 0.133
# epoch 791: mse = 0.133
# epoch 792: mse = 0.133
# epoch 793: mse = 0.133
# epoch 794: mse = 0.133
# epoch 795: mse = 0.133
# epoch 796: mse = 0.133
# epoch 797: mse = 0.133
# epoch 798: mse = 0.133
# epoch 799: mse = 0.133
# epoch 800: mse = 0.133
# epoch 801: mse = 0.133
# epoch 802: mse = 0.133
# epoch 803: mse = 0.133
# epoch 804: mse = 0.133
# epoch 805: mse = 0.133
# epoch 806: mse = 0.133
# epoch 807: mse = 0.133
# epoch 808: mse = 0.133
# epoch 809: mse = 0.133
# epoch 810: mse = 0.133
# epoch 811: mse = 0.133
# epoch 812: mse = 0.133
# epoch 813: mse = 0.133
# epoch 814: mse = 0.133
# epoch 815: mse = 0.133
# epoch 816: mse = 0.133
# epoch 817: mse = 0.133
# epoch 818: mse = 0.133
# epoch 819: mse = 0.133
# epoch 820: mse = 0.133
# epoch 821: mse = 0.133
# epoch 822: mse = 0.133
# epoch 823: mse = 0.133
# epoch 824: mse = 0.133
# epoch 825: mse = 0.133
# epoch 826: mse = 0.133
# epoch 827: mse = 0.133
# epoch 828: mse = 0.133
# epoch 829: mse = 0.133
# epoch 830: mse = 0.133
# epoch 831: mse = 0.133
# epoch 832: mse = 0.133
# epoch 833: mse = 0.133
# epoch 834: mse = 0.133
# epoch 835: mse = 0.133
# epoch 836: mse = 0.133
# epoch 837: mse = 0.133
# epoch 838: mse = 0.133
# epoch 839: mse = 0.133
# epoch 840: mse = 0.133
# epoch 841: mse = 0.133
# epoch 842: mse = 0.133
# epoch 843: mse = 0.133
# epoch 844: mse = 0.133
# epoch 845: mse = 0.133
# epoch 846: mse = 0.133
# epoch 847: mse = 0.133
# epoch 848: mse = 0.133
# epoch 849: mse = 0.133
# epoch 850: mse = 0.133
# epoch 851: mse = 0.133
# epoch 852: mse = 0.133
# epoch 853: mse = 0.133
# epoch 854: mse = 0.133
# epoch 855: mse = 0.133
# epoch 856: mse = 0.133
# epoch 857: mse = 0.133
# epoch 858: mse = 0.133
# epoch 859: mse = 0.133
# epoch 860: mse = 0.133
# epoch 861: mse = 0.133
# epoch 862: mse = 0.133
# epoch 863: mse = 0.133
# epoch 864: mse = 0.133
# epoch 865: mse = 0.133
# epoch 866: mse = 0.133
# epoch 867: mse = 0.133
# epoch 868: mse = 0.133
# epoch 869: mse = 0.133
# epoch 870: mse = 0.133
# epoch 871: mse = 0.133
# epoch 872: mse = 0.133
# epoch 873: mse = 0.133
# epoch 874: mse = 0.133
# epoch 875: mse = 0.133
# epoch 876: mse = 0.133
# epoch 877: mse = 0.133
# epoch 878: mse = 0.133
# epoch 879: mse = 0.133
# epoch 880: mse = 0.133
# epoch 881: mse = 0.133
# epoch 882: mse = 0.133
# epoch 883: mse = 0.133
# epoch 884: mse = 0.133
# epoch 885: mse = 0.133
# epoch 886: mse = 0.133
# epoch 887: mse = 0.133
# epoch 888: mse = 0.133
# epoch 889: mse = 0.133
# epoch 890: mse = 0.133
# epoch 891: mse = 0.133
# epoch 892: mse = 0.133
# epoch 893: mse = 0.133
# epoch 894: mse = 0.133
# epoch 895: mse = 0.133
# epoch 896: mse = 0.133
# epoch 897: mse = 0.133
# epoch 898: mse = 0.133
# epoch 899: mse = 0.133
# epoch 900: mse = 0.133
# epoch 901: mse = 0.133
# epoch 902: mse = 0.133
# epoch 903: mse = 0.133
# epoch 904: mse = 0.133
# epoch 905: mse = 0.133
# epoch 906: mse = 0.133
# epoch 907: mse = 0.133
# epoch 908: mse = 0.133
# epoch 909: mse = 0.133
# epoch 910: mse = 0.133
# epoch 911: mse = 0.133
# epoch 912: mse = 0.133
# epoch 913: mse = 0.133
# epoch 914: mse = 0.133
# epoch 915: mse = 0.133
# epoch 916: mse = 0.133
# epoch 917: mse = 0.133
# epoch 918: mse = 0.133
# epoch 919: mse = 0.133
# epoch 920: mse = 0.133
# epoch 921: mse = 0.133
# epoch 922: mse = 0.133
# epoch 923: mse = 0.133
# epoch 924: mse = 0.133
# epoch 925: mse = 0.133
# epoch 926: mse = 0.133
# epoch 927: mse = 0.133
# epoch 928: mse = 0.133
# epoch 929: mse = 0.133
# epoch 930: mse = 0.133
# epoch 931: mse = 0.133
# epoch 932: mse = 0.133
# epoch 933: mse = 0.133
# epoch 934: mse = 0.133
# epoch 935: mse = 0.133
# epoch 936: mse = 0.133
# epoch 937: mse = 0.133
# epoch 938: mse = 0.133
# epoch 939: mse = 0.133
# epoch 940: mse = 0.133
# epoch 941: mse = 0.133
# epoch 942: mse = 0.133
# epoch 943: mse = 0.133
# epoch 944: mse = 0.133
# epoch 945: mse = 0.133
# epoch 946: mse = 0.133
# epoch 947: mse = 0.133
# epoch 948: mse = 0.133
# epoch 949: mse = 0.133
# epoch 950: mse = 0.133
# epoch 951: mse = 0.133
# epoch 952: mse = 0.133
# epoch 953: mse = 0.133
# epoch 954: mse = 0.133
# epoch 955: mse = 0.133
# epoch 956: mse = 0.133
# epoch 957: mse = 0.133
# epoch 958: mse = 0.133
# epoch 959: mse = 0.133
# epoch 960: mse = 0.133
# epoch 961: mse = 0.133
# epoch 962: mse = 0.133
# epoch 963: mse = 0.133
# epoch 964: mse = 0.133
# epoch 965: mse = 0.133
# epoch 966: mse = 0.133
# epoch 967: mse = 0.133
# epoch 968: mse = 0.133
# epoch 969: mse = 0.133
# epoch 970: mse = 0.133
# epoch 971: mse = 0.133
# epoch 972: mse = 0.133
# epoch 973: mse = 0.133
# epoch 974: mse = 0.133
# epoch 975: mse = 0.133
# epoch 976: mse = 0.133
# epoch 977: mse = 0.133
# epoch 978: mse = 0.133
# epoch 979: mse = 0.133
# epoch 980: mse = 0.133
# epoch 981: mse = 0.133
# epoch 982: mse = 0.132
# epoch 983: mse = 0.132
# epoch 984: mse = 0.132
