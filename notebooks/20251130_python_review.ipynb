# %%
# proqramlashdirma
# data analitika
# data science
# machine learning

# %%
# python - miniconda / colab
# vscode
# environment 
# jupyter notebook -ipynb

# %%
2**100
# Out:
# 1267650600228229401496703205376

# %%
6//4
# Out:
# 1

# %%
6%4
# Out:
# 2

# %%
4*(1 + 2)**2

# %%
()
**
* /
+ -

# %%
x = 19
x != 19 # true false qaytarir
# Out:
# False

# %%
x *= 10
x = x * 10

# %%
_adfasdf_123123_

# %%
while = 9

# %%
int  9, 12, -2, 0, 120938120381, -28132831
float 9.1928, 12.1928, -2.1928, 0.1928, 120938120381., -28132831.0
str '9.1928', 'salam', "shahriyar", """alsjflasjdfal""", "True", "None", 'for'
bool True, False
None None

# %%
x = 9.
type(x)
# Out:
# float

# %%
9+10
# Out:
# 19

# %%
'9'+'10' #concatenation
# Out:
# '910'

# %%
'91'*3 # replication
# Out:
# '919191'

# %%
l = [1,2,3]
l*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
x = '9'
int(x)
# Out:
# 9

# %%
print(r'salam\nnecesen') # raw string
# Out:
# salam\nnecesen

# %%
x = 'shahriyar'
x[0:7:2] # 0,2,4,6
# Out:
# 'sary'

# %%
x[2] = 'O' # string is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 x[2] = 'O'
#
# TypeError: 'str' object does not support item assignment

# %%
l = [
    	['a', ['b']], 
    	'c'
    ]
l[1] = 'Z' # list is mutable - can be mutated
l
# Out:
# [['a', 'b'], 'Z']

# %%
len(l)
# Out:
# 2

# %%
x.capitalize()
# Out:
# 'Shahriyar'

# %%
x.split('h')
# Out:
# ['s', 'a', 'riyar']

# %%
x = 'ali shahriyar hesen'
x
# Out:
# 'ali shahriyar hesen'

# %%
y = x.split(' ')
y
# Out:
# ['ali', 'shahriyar', 'hesen']

# %%
'X'.join(y)
# Out:
# 'aliXshahriyarXhesen'

# %%
f"*** {x} *** {x} ***"
# Out:
# '*** ali shahriyar hesen *** ali shahriyar hesen **'

# %%
inp = input('yashiniz?: ')
yash = int(inp)
yash
# Out:
# 30

# %%
yash + 1
# Out:
# 31

# %%
gelir = 30000000.38902834

f"pinin deyeri: {gelir:,.2f}"
# Out:
# 'pinin deyeri: 30,000,000.39'

# %%
# truncate
# round

# %%
# 00 - ff
# 0 - 255

# %%
x = 255
f'{x:x}'
# Out:
# 'ff'

# %%
# 5 + 3 * 2 - 8 / 4 ** 2
# 5 + 3 * 2 - 8 / 16
# 5 + 6 - 0.5
# 5 + 6 - 0.5
# 10.5

# %%
5 + 3 * 2 - 8 / 4 ** 2
# Out:
# 10.5

# %%
50 > 100
# Out:
# False

# %%
33 == 33.0
# Out:
# True

# %%
"hello" == "hello"
# Out:
# True

# %%
len("python") > 5
# Out:
# True

# %%
1st_place = 'hesen'

# %%
FirstPlace = 10
firstplace = 11

# %%
FirstPlace
# Out:
# 10

# %%
firstplace
# Out:
# 11

# %%
def f(x):
    return x**2

def F(x):
    return x**3

# %%
price_str = "25.99"
price_float = float(price_str)
price_float
# Out:
# 25.99

# %%
quantity = 3
quantity_str = str(quantity)
quantity_str
# Out:
# '3'

# %%
quantity_str  + " items"
# Out:
# '3 items'

# %%
'-'*30
# Out:
# '------------------------------'

# %%
first_name = 'shahriyar'
last_name = 'mammadli'
separator = '*'*30
print(first_name, last_name, sep=separator)
# Out:
# shahriyar******************************mammadli

# %%
The file is located at:
C:\Users\new_folder\tabbed_file.txt
He said, "It's a beautiful day."

# %%
x1 = "The file is located at:"
x2 = r"C:\Users\new_folder\tabbed_file.txt"
x3 = "He said, \"It\'s a beautiful day.\""
x = x1+ '\n' + x2 + '\n' + x3
print(x)
# Out:
# The file is located at:
# C:\Users\new_folder\tabbed_file.txt
# He said, "It's a beautiful day."

# %%
tweet = " WOW, what a great game! #sports #python "
tweet.lower().strip().replace("#python", "#DataScience").split(' ')
# Out:
# ['wow,', 'what', 'a', 'great', 'game!', '#sports', '#DataScience']

# %%
yash_input = input("yashinizi deyin")
yash_int = int(yash_input)
print(yash_int)

# %%
item = "Laptop"
price = 1200.50
quantity = 2

f"Item: {item}, Quantity: {quantity}, Total Cost: ${price*quantity:,.2f}"
# Out:
# 'Item: Laptop, Quantity: 2, Total Cost: $2,401.00'

# %%
l = 'baki gence sumqayit'
l = l.split(' ')
l
# Out:
# ['baki', 'gence', 'sumqayit']

# %%
qarishiq_list = ['baki', 'gence', 'sumqayit', 3, None, 8.4]
qarishiq_list
# Out:
# ['baki', 'gence', 'sumqayit', 3, None, 8.4]

# %%
'yevlax' not in qarishiq_list
# Out:
# True

# %%
qarishiq_list[2:4]
# Out:
# ['sumqayit', 3]

# %%
qarishiq_list.append('salam')
qarishiq_list
# Out:
# ['baki', 'gence', 'sumqayit', 3, None, 8.4, 'salam']

# %%
qarishiq_list.insert(2, 'yevlax')
qarishiq_list
# Out:
# ['baki', 'gence', 'yevlax', 'sumqayit', 3, None, 8.4, 'salam']

# %%
qarishiq_list.remove('yevlax')
qarishiq_list
# Out:
# ['baki', 'gence', 'sumqayit', 3, None, 8.4, 'salam']

# %%
del qarishiq_list[-1]
qarishiq_list
# Out:
# ['baki', 'gence', 'sumqayit', 3, None, 8.4]

# %%
x = 10
x
# Out:
# 10

# %%
del x

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
qarishiq_list + ['a', 'b'] # concatenation
# Out:
# ['baki', 'gence', 'sumqayit', 3, None, 8.4, 'a', 'b']

# %%
qarishiq_list * 3
# Out:
# ['baki',
#  'gence',
#  'sumqayit',
#  3,
#  None,
#  8.4,
#  'baki',
#  'gence',
#  'sumqayit',
#  3,
#  None,
#  8.4,
#  'baki',
#  'gence',
#  'sumqayit',
#  3,
#  None,
#  8.4]

# %%
qarishiq_list.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 qarishiq_list.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
sheherler = ['baki','gence','sumqayit','balaken',]
sheherler.sort()

# %%
sheherler
# Out:
# ['baki', 'balaken', 'gence', 'sumqayit']

# %%
sheherler = ['baki','gence','sumqayit','balaken',]
sorted(sheherler)
# Out:
# ['baki', 'balaken', 'gence', 'sumqayit']

# %%
sheherler
# Out:
# ['baki', 'gence', 'sumqayit', 'balaken']

# %%
adlar = ['ali', 'hesen', 'huseyn']
sheherler = ['baki','gence','sumqayit','balaken',]

x = zip(adlar, sheherler)
x

# %%
set(list(tuple(adlar)))
# Out:
# {'ali', 'hesen', 'huseyn'}

# %%
x = ['a', 'b', 'c']
y = x
print(x is y)
print(x,y)
y = ['x', 'y', 'z'] # ayirici emeliyyat
print(x is y)
print(x,y)
# Out:
# True
# ['a', 'b', 'c'] ['a', 'b', 'c']
# False
# ['a', 'b', 'c'] ['x', 'y', 'z']

# %%
x = ['a', 'b', 'c']
y = x
print(x is y)
print(x,y)

y[0] = 'M'
print(x is y)
print(x,y)
# Out:
# True
# ['a', 'b', 'c'] ['a', 'b', 'c']
# True
# ['M', 'b', 'c'] ['M', 'b', 'c']

# %%
x = ['a', 'b', 'c']
y = x.copy()
print(x is y)
print(x,y)

y[0] = 'M'
print(x is y)
print(x,y)
# Out:
# False
# ['a', 'b', 'c'] ['a', 'b', 'c']
# False
# ['a', 'b', 'c'] ['M', 'b', 'c']

# %%
y
# Out:
# ['M', 'b', 'c']

# %%
'M' not in y
# Out:
# False

# %%
not('M' in y)
# Out:
# False

# %%
not False
# Out:
# True

# %%
a = 20

# %%
a%2==1 and a>0
# Out:
# False

# %%
a%2==1 or a>0
# Out:
# True

# %%
maas = [100,200,300]
bonus = [10,20,30]

maas_serti and bonus_serti

# %%
# if sert:
#     sert odenirse nese olsun
# elif basqa sert:
# 	basqa sert odenirse nese olsun
# else:
#     hec ne olmasa en azindan bu olsun

# %%
olke = 'FR'
olke_avropadadir = True

if olke_avropadadir:
	if olke == 'DE':
		print('hallo')
	elif olke == 'FR':
		print('salut')
elif olke == 'US':
	print('hello')
elif olke == 'AZ':
	print('salam')
else:
	print('where are you from?')
# Out:
# salut

# %%
olke = 'FR'
x = 'salam' if olke=='AZ' else 'hello'

x
# Out:
# 'hello'

# %%
if olke == 'FR': print('salut')
# Out:
# salut

# %%
adlar
# Out:
# ['ali', 'hesen', 'huseyn']

# %%
for i,ad in enumerate(adlar):
    print(i, ad[0])
# Out:
# 0 a
# 1 h
# 2 h

# %%
list(range(9))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
adlar = ['ali', 'azer', 'alim', 'hesen', 'huseyn']

# while sert:
#     nese ele sert dogrudursa

ind = 0
while adlar[ind][0] == 'a':
    print(adlar[ind])
    ind += 1
# Out:
# ali
# azer
# alim

# %%
if adlar[0][0] == 'a':
    print(adlar[0])
# Out:
# ali

# %%
for x in adlar:
    print(x)
# Out:
# ali
# azer
# alim
# hesen
# huseyn
