# %%
import numpy as np
arr = np.arange(20,50,5)
l = list(range(160,190,5))
l
# Out:
# [160, 165, 170, 175, 180, 185]

# %%
# %pip install pandas
import pandas as pd

# %%
s_yashlar = pd.Series(arr)
s_yashlar
# Out:
# 0    20
# 1    25
# 2    30
# 3    35
# 4    40
# 5    45
# dtype: int64

# %%
s_boylar = pd.Series(l)
s_boylar
# Out:
# 0    160
# 1    165
# 2    170
# 3    175
# 4    180
# 5    185
# dtype: int64

# %%
import numpy as np
np.sqrt(s_yashlar)
# Out:
# 0    4.472136
# 1    5.000000
# 2    5.477226
# 3    5.916080
# 4    6.324555
# 5    6.708204
# dtype: float64

# %%
s_yashlar[s_yashlar >= 40]
# Out:
# 4    40
# 5    45
# dtype: int64

# %%
# s_yashlar.to_numpy()
d = s_yashlar.to_dict()
d
# Out:
# {'ali': 20, 'vali': 25, 'hasan': 30, 'huseyn': 35, 'lale': 40, 'gulnar': 45}

# %%
s_yashlar = pd.Series(arr, index=['ali', 'vali', 'hasan', 'huseyn', 'lale', 'gulnar'])
s_boylar = pd.Series(l, index=['ali', 'qezenfer', 'elovset', 'huseyn', 'lale', 'gulnar'])

# pd.DataFrame({
#     'yash' : s_yashlar,
#     'boy' : s_boylar,
# })

s_yashlar + s_boylar
# Out:
# ali         180.0
# elovset       NaN
# gulnar      230.0
# hasan         NaN
# huseyn      210.0
# lale        220.0
# qezenfer      NaN
# vali          NaN
# dtype: float64

# %%
s_yashlar
# Out:
# ali       20
# vali      25
# hasan     30
# huseyn    35
# lale      40
# gulnar    45
# dtype: int64

# %%
# s_yashlar['ali']
s_yashlar.loc['hasan']
s_yashlar.iloc[2]
# Out:
# np.int64(30)

# %%
s_yashlar
# Out:
# ali       20
# vali      25
# hasan     30
# huseyn    35
# lale      40
# gulnar    45
# dtype: int64

# %%
# s_yashlar['hasan':'lale']
s_yashlar.loc['hasan':'lale']
s_yashlar.iloc[2:5]
# Out:
# hasan     30
# huseyn    35
# lale      40
# dtype: int64

# %%
s_yashlar.index
s_yashlar.values
s_yashlar.to_dict().items()
# Out:
# dict_items([('ali', 20), ('vali', 25), ('hasan', 30), ('huseyn', 35), ('lale', 40), ('gulnar', 45)])

# %%
# d['huseyn'] = 70
s_yashlar['huseyn'] = 70
s_yashlar
# Out:
# ali       20
# vali      25
# hasan     30
# huseyn    70
# lale      40
# gulnar    45
# dtype: int64

# %%
# s_yashlar.loc['vali':]
s_yashlar.iloc[1:]
# Out:
# vali      25
# hasan     30
# huseyn    70
# lale      40
# gulnar    45
# dtype: int64

# %%
s3 = s_yashlar + s_boylar
s3
# Out:
# ali         180.0
# elovset       NaN
# gulnar      230.0
# hasan         NaN
# huseyn      245.0
# lale        220.0
# qezenfer      NaN
# vali          NaN
# dtype: float64

# %%
s3
# Out:
# ali         180.0
# elovset       NaN
# gulnar      230.0
# hasan         NaN
# huseyn      245.0
# lale        220.0
# qezenfer      NaN
# vali          NaN
# dtype: float64

# %%
s3.loc[s3.isna()] = s3.mean()
s3
# Out:
# ali         180.00
# elovset     218.75
# gulnar      230.00
# hasan       218.75
# huseyn      245.00
# lale        220.00
# qezenfer    218.75
# vali        218.75
# dtype: float64

# %%
# s3 = s3.fillna(s3.mean())
# s3.fillna(s3.mean(), inplace=True)
# Out:
# ali         180.00
# elovset     218.75
# gulnar      230.00
# hasan       218.75
# huseyn      245.00
# lale        220.00
# qezenfer    218.75
# vali        218.75
# dtype: float64

# %%
s3
# Out:
# ali         180.0
# elovset       NaN
# gulnar      230.0
# hasan         NaN
# huseyn      245.0
# lale        220.0
# qezenfer      NaN
# vali          NaN
# dtype: float64

# %%
s3.loc[s3.notna()]
# Out:
# ali       180.0
# gulnar    230.0
# huseyn    245.0
# lale      220.0
# dtype: float64

# %%
s3.dropna()
# Out:
# ali       180.0
# gulnar    230.0
# huseyn    245.0
# lale      220.0
# dtype: float64

# %%
from pathlib import Path
csv_path = Path(r"C:\Users\user\Desktop\div\data\world_population.csv")
df = pd.read_csv(csv_path)
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
s4 = df['Continent']
s4
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 229    Oceania
# 230     Africa
# 231       Asia
# 232     Africa
# 233     Africa
# Name: Continent, Length: 234, dtype: object

# %%
s4.value_counts()
# Out:
# Continent
# Africa           57
# Asia             50
# Europe           50
# North America    40
# Oceania          23
# South America    14
# Name: count, dtype: int64

# %%
57 / s4.value_counts().sum() * 100
# Out:
# np.float64(24.358974358974358)

# %%
s4.value_counts() / s4.value_counts().sum() * 100
# Out:
# Continent
# Africa           24.358974
# Asia             21.367521
# Europe           21.367521
# North America    17.094017
# Oceania           9.829060
# South America     5.982906
# Name: count, dtype: float64

# %%
s4.value_counts(normalize=True) * 100
# Out:
# Continent
# Africa           24.358974
# Asia             21.367521
# Europe           21.367521
# North America    17.094017
# Oceania           9.829060
# South America     5.982906
# Name: proportion, dtype: float64

# %%
s_pop = df['2022 Population']
s_pop
# Out:
# 0      41128771.0
# 1       2842321.0
# 2      44903225.0
# 3         44273.0
# 4         79824.0
#           ...
# 229       11572.0
# 230      575986.0
# 231    33696614.0
# 232    20017675.0
# 233    16320537.0
# Name: 2022 Population, Length: 234, dtype: float64

# %%
x = [0,10e6,50e6,100e6,2e9]
s_pop.value_counts(bins=x)
# Out:
# (-0.001, 10000000.0]           137
# (10000000.0, 50000000.0]        64
# (50000000.0, 100000000.0]       15
# (100000000.0, 2000000000.0]     14
# Name: count, dtype: int64

# %%
s_area = df['Area (km²)']
s_area
# Out:
# 0       652230.0
# 1        28748.0
# 2      2381741.0
# 3          199.0
# 4          468.0
#          ...
# 229        142.0
# 230     266000.0
# 231     527968.0
# 232     752612.0
# 233     390757.0
# Name: Area (km²), Length: 234, dtype: float64

# %%
def boyukdur_veya_kicikdir(s):
    if s>100e3:
        return 'boyuk'
    else:
        return 'kicik'

s_yeni = s_area.apply(boyukdur_veya_kicikdir)
s_yeni
# Out:
# 0      boyuk
# 1      kicik
# 2      boyuk
# 3      kicik
# 4      kicik
#        ...
# 229    kicik
# 230    boyuk
# 231    boyuk
# 232    boyuk
# 233    boyuk
# Name: Area (km²), Length: 234, dtype: object

# %%
df['boyuk olkeler'] = s_yeni
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
s = pd.Series([1, 1, 2, 2, 2, 3, 3, 4])
# s**2

# def kvadrata_yukselt(nese):
#     return nese**2
# s.apply(kvadrata_yukselt)

# s.apply(lambda nese: nese**2)
# Out:
# 0     1
# 1     1
# 2     4
# 3     4
# 4     4
# 5     9
# 6     9
# 7    16
# dtype: int64

# %%
s = pd.Series([1, 1, 2, 2, 2, 3, 3, 4])

# def tekdir_cutdur(nese):
#     if nese%2==0:
#         return 'cut'
#     else:
#         return 'tek'
# s.apply(tekdir_cutdur)


s2 = s.apply(lambda nese: 'cut' if nese%2==0 else 'tek')
s2
# Out:
# 0    tek
# 1    tek
# 2    cut
# 3    cut
# 4    cut
# 5    tek
# 6    tek
# 7    cut
# dtype: object

# %%
s7 = df['CCA3']
s7
# Out:
# 0      AFG
# 1      ALB
# 2      DZA
# 3      ASM
# 4      AND
#       ...
# 229    WLF
# 230    ESH
# 231    YEM
# 232    ZMB
# 233    ZWE
# Name: CCA3, Length: 234, dtype: object

# %%
len(s7)
# Out:
# 234

# %%
s7.shape
# Out:
# (234,)

# %%
len(df)
# Out:
# 234

# %%
'AZE' in s7.index
# Out:
# False

# %%
s7.iloc[13]
# Out:
# 'AZE'

# %%
s7.sort_values(ascending=False)
# Out:
# 233    ZWE
# 232    ZMB
# 193    ZAF
# 231    YEM
# 179    WSM
#       ...
# 1      ALB
# 6      AIA
# 5      AGO
# 0      AFG
# 10     ABW
# Name: CCA3, Length: 234, dtype: object

# %%
s7.tail(19)
# Out:
# 215    TCA
# 216    TUV
# 217    UGA
# 218    UKR
# 219    ARE
# 220    GBR
# 221    USA
# 222    VIR
# 223    URY
# 224    UZB
# 225    VUT
# 226    VAT
# 227    VEN
# 228    VNM
# 229    WLF
# 230    ESH
# 231    YEM
# 232    ZMB
# 233    ZWE
# Name: CCA3, dtype: object

# %%
s4.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
s4.value_counts()
# Out:
# Continent
# Africa           57
# Asia             50
# Europe           50
# North America    40
# Oceania          23
# South America    14
# Name: count, dtype: int64

# %%
s_pop.min()
# Out:
# np.float64(510.0)

# %%
s_pop.argmin()
# Out:
# np.int64(226)

# %%
df.iloc[226]
# Out:
# Rank                                    234
# CCA3                                    VAT
# Country                        Vatican City
# Capital                        Vatican City
# Continent                            Europe
# 2022 Population                       510.0
# 2020 Population                       520.0
# 2015 Population                       564.0
# 2010 Population                       596.0
# 2000 Population                       651.0
# 1990 Population                       700.0
# 1980 Population                       733.0
# 1970 Population                       752.0
# Area (km²)                              1.0
# Density (per km²)                     510.0
# Growth Rate                           0.998
# World Population Percentage             0.0
# boyuk olkeler                         kicik
# Name: 226, dtype: object

# %%
df.to_csv('yeni_df.csv')
