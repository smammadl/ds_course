# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\div\data\files\car-sales-extended-missing-data.csv")
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
fv = df['Make'].value_counts().idxmax()
fv
# Out:
# 'Toyota'

# %%
df['Make'] = df['Make'].fillna(fv)
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996  Toyota  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
df.loc[df['Make'].isnull(), :]
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price]
# Index: []

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0       NaN  White        35431.0    4.0  15323.0
# 1       NaN   Blue       192714.0    5.0  19943.0
# 2       NaN  White        84714.0    4.0  28343.0
# 3       NaN  White       154365.0    4.0  13434.0
# 4       NaN   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995     NaN  Black        35820.0    4.0  32042.0
# 996  Toyota  White       155144.0    3.0   5716.0
# 997     NaN   Blue        66604.0    4.0  31570.0
# 998     NaN  White       215883.0    4.0   4001.0
# 999     NaN   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
mask = df.isnull().any(axis=1)
df[mask]
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 7     Honda  White            NaN    4.0  20306.0
# 20   Toyota    NaN       124844.0    4.0  24130.0
# 21    Honda    NaN        30615.0    4.0  29653.0
# 31   Toyota  White       108569.0    NaN   6866.0
# 37   Nissan  White            NaN    4.0  15131.0
# ..      ...    ...            ...    ...      ...
# 960   Honda  White            NaN    4.0  13070.0
# 968  Nissan  White       227278.0    4.0      NaN
# 972   Honda  White            NaN    4.0  17939.0
# 975   Honda    NaN        22409.0    4.0  10429.0
# 983  Toyota    Red            NaN    4.0  14671.0
#
# [184 rows x 5 columns]

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996  Toyota  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
def f(x):
	if x > 15000:
		return x*1.2
	else:
		return x

df['Price2'] = df['Price'].apply(f)
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price    Price2
# 0     Honda  White        35431.0    4.0  18387.6  22065.12
# 1       BMW   Blue       192714.0    5.0  23931.6  28717.92
# 2     Honda  White        84714.0    4.0  34011.6  40813.92
# 3    Toyota  White       154365.0    4.0  13434.0  13434.00
# 4    Nissan   Blue       181577.0    3.0  14043.0  14043.00
# ..      ...    ...            ...    ...      ...       ...
# 995  Toyota  Black        35820.0    4.0  38450.4  46140.48
# 996  Toyota  White       155144.0    3.0   5716.0   5716.00
# 997  Nissan   Blue        66604.0    4.0  37884.0  45460.80
# 998   Honda  White       215883.0    4.0   4001.0   4001.00
# 999  Toyota   Blue       248360.0    4.0  12732.0  12732.00
#
# [1000 rows x 6 columns]

# %%
# df.head()
# df.tail(5)
df.sort_index(ascending=False).iloc[:3, :]
# Out:
#        Make Colour  Odometer (KM)  Doors    Price   Price2
# 999  Toyota   Blue       248360.0    4.0  12732.0  12732.0
# 998   Honda  White       215883.0    4.0   4001.0   4001.0
# 997  Nissan   Blue        66604.0    4.0  37884.0  45460.8

# %%
df["Make"].to_dict()
# Out:
# {0: 'Honda',
#  1: 'BMW',
#  2: 'Honda',
#  3: 'Toyota',
#  4: 'Nissan',
#  5: 'Honda',
#  6: 'Toyota',
#  7: 'Honda',
#  8: 'Toyota',
#  9: 'Honda',
#  10: 'Nissan',
#  11: 'Nissan',
#  12: 'Nissan',
#  13: 'Toyota',
#  14: 'Honda',
#  15: 'Toyota',
#  16: 'Toyota',
#  17: 'BMW',
#  18: 'Nissan',
#  19: 'Nissan',
#  20: 'Toyota',
#  21: 'Honda',
#  22: 'Toyota',
#  23: 'Honda',
#  24: 'Honda',
#  25: 'Honda',
#  26: 'Honda',
#  27: 'Honda',
#  28: 'Honda',
#  29: 'Toyota',
#  30: 'Nissan',
#  31: 'Toyota',
#  32: 'Nissan',
#  33: 'Nissan',
#  34: 'Honda',
#  35: 'Honda',
#  36: 'Nissan',
#  37: 'Nissan',
#  38: 'Nissan',
#  39: 'Toyota',
#  40: 'Toyota',
#  41: 'Toyota',
#  42: 'Honda',
#  43: 'Toyota',
#  44: 'Toyota',
#  45: 'Nissan',
#  46: 'Toyota',
#  47: 'Toyota',
#  48: 'Nissan',
#  49: 'Toyota',
#  50: 'Toyota',
#  51: 'Honda',
#  52: 'Toyota',
#  53: 'Toyota',
#  54: 'Toyota',
#  55: 'BMW',
#  56: 'Honda',
#  57: 'BMW',
#  58: 'Toyota',
#  59: 'Toyota',
#  60: 'BMW',
# ...

# %%
df['Price'].value_counts()
# Out:
# Price
# 18184.8    2
# 19822.8    2
# 7994.0     2
# 11648.0    2
# 7813.0     2
#           ..
# 38450.4    1
# 5716.0     1
# 37884.0    1
# 4001.0     1
# 12732.0    1
# Name: count, Length: 934, dtype: int64

# %%
df['Price'].value_counts(bins=[0,5000,10e3,20e3])
# Out:
# (10000.0, 20000.0]    311
# (5000.0, 10000.0]     223
# (-0.001, 5000.0]       36
# Name: count, dtype: int64

# %%
df.rename({"Odometer (KM)":"Odometer"}, axis=1)
# Out:
#        Make Colour  Odometer  Doors    Price    Price2
# 0     Honda  White   35431.0    4.0  18387.6  22065.12
# 1       BMW   Blue  192714.0    5.0  23931.6  28717.92
# 2     Honda  White   84714.0    4.0  34011.6  40813.92
# 3    Toyota  White  154365.0    4.0  13434.0  13434.00
# 4    Nissan   Blue  181577.0    3.0  14043.0  14043.00
# ..      ...    ...       ...    ...      ...       ...
# 995  Toyota  Black   35820.0    4.0  38450.4  46140.48
# 996  Toyota  White  155144.0    3.0   5716.0   5716.00
# 997  Nissan   Blue   66604.0    4.0  37884.0  45460.80
# 998   Honda  White  215883.0    4.0   4001.0   4001.00
# 999  Toyota   Blue  248360.0    4.0  12732.0  12732.00
#
# [1000 rows x 6 columns]

# %%
df = df.sort_values('Price', na_position ='first')
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price    Price2
# 119     BMW  White        18394.0    5.0      NaN       NaN
# 152  Toyota  White        66538.0    4.0      NaN       NaN
# 171  Toyota  White        97036.0    4.0      NaN       NaN
# 176  Toyota   Blue        94916.0    4.0      NaN       NaN
# 249     BMW    Red        33911.0    5.0      NaN       NaN
# ..      ...    ...            ...    ...      ...       ...
# 272     BMW  White        23996.0    5.0  57886.8  69464.16
# 978     BMW  White        85739.0    5.0  58102.8  69723.36
# 55      BMW  White        79937.0    5.0  58423.2  70107.84
# 720     BMW  White        57905.0    3.0  61041.6  73249.92
# 906     BMW  White        16274.0    5.0  62949.6  75539.52
#
# [1000 rows x 6 columns]

# %%
df.sort_values('Price', na_position ='last', inplace=True)

# %%
df.dropna(thresh=6, axis=0)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price    Price2
# 757  Nissan   Blue       233501.0    4.0   2796.0   2796.00
# 845  Toyota  Green       243177.0    4.0   3125.0   3125.00
# 173  Nissan  Black       240536.0    4.0   3247.0   3247.00
# 406   Honda   Blue       210446.0    4.0   3594.0   3594.00
# 678  Toyota  Green       213861.0    4.0   3751.0   3751.00
# ..      ...    ...            ...    ...      ...       ...
# 272     BMW  White        23996.0    5.0  57886.8  69464.16
# 978     BMW  White        85739.0    5.0  58102.8  69723.36
# 55      BMW  White        79937.0    5.0  58423.2  70107.84
# 720     BMW  White        57905.0    3.0  61041.6  73249.92
# 906     BMW  White        16274.0    5.0  62949.6  75539.52
#
# [816 rows x 6 columns]

# %%
df[~df.duplicated()]
# Out:
#        Make Colour  Odometer (KM)  Doors   Price  Price2
# 757  Nissan   Blue       233501.0    4.0  2796.0  2796.0
# 845  Toyota  Green       243177.0    4.0  3125.0  3125.0
# 173  Nissan  Black       240536.0    4.0  3247.0  3247.0
# 86   Nissan   Blue            NaN    4.0  3300.0  3300.0
# 700   Honda    NaN       203447.0    4.0  3509.0  3509.0
# ..      ...    ...            ...    ...     ...     ...
# 940   Honda  White        53474.0    4.0     NaN     NaN
# 947  Toyota   Blue        17609.0    4.0     NaN     NaN
# 952  Nissan  White       136022.0    4.0     NaN     NaN
# 959  Nissan  White       186786.0    4.0     NaN     NaN
# 968  Nissan  White       227278.0    4.0     NaN     NaN
#
# [999 rows x 6 columns]

# %%
from sqlalchemy import create_engine

query_emp = """
SELECT * 
FROM employees   
limit 100;
"""
query_sal = """
SELECT * 
FROM salaries  
limit 100;
"""

con = create_engine("postgresql+psycopg2://postgres:postgres@localhost/employees")

df_emp = pd.read_sql_query(query_emp, con)
df_sal = pd.read_sql_query(query_sal, con)

# %%
df_sal.head(3)
# Out:
#    emp_no  salary   from_date     to_date
# 0   10001   60117  1986-06-26  1987-06-26
# 1   10001   62102  1987-06-26  1988-06-25
# 2   10001   66074  1988-06-25  1989-06-25

# %%
df_sal['gender'] = 'M'
df_sal.head(3)
# Out:
#    emp_no  salary   from_date     to_date gender
# 0   10001   60117  1986-06-26  1987-06-26      M
# 1   10001   62102  1987-06-26  1988-06-25      M
# 2   10001   66074  1988-06-25  1989-06-25      M

# %%
df_sal.set_index('emp_no', inplace=True)

# %%
df_sal
# Out:
#         salary   from_date     to_date gender
# emp_no
# 10001    60117  1986-06-26  1987-06-26      M
# 10001    62102  1987-06-26  1988-06-25      M
# 10001    66074  1988-06-25  1989-06-25      M
# 10001    66596  1989-06-25  1990-06-25      M
# 10001    66961  1990-06-25  1991-06-25      M
# ...        ...         ...         ...    ...
# 10009    74612  1992-02-17  1993-02-16      M
# 10009    76518  1993-02-16  1994-02-16      M
# 10009    78335  1994-02-16  1995-02-16      M
# 10009    80944  1995-02-16  1996-02-16      M
# 10009    82507  1996-02-16  1997-02-15      M
#
# [100 rows x 4 columns]

# %%
df_emp.head(3)
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28

# %%
df_emp.set_index("emp_no", inplace=True)

# %%
pd.merge(df_emp, df_sal, how='right', left_on='emp_no', right_on='emp_no', suffixes=['_emp', '_sal'])
# Out:
#     emp_no  birth_date first_name last_name gender_emp   hire_date  salary  \
# 0    10001  1953-09-02     Georgi   Facello          M  1986-06-26   60117
# 1    10001  1953-09-02     Georgi   Facello          M  1986-06-26   62102
# 2    10001  1953-09-02     Georgi   Facello          M  1986-06-26   66074
# 3    10001  1953-09-02     Georgi   Facello          M  1986-06-26   66596
# 4    10001  1953-09-02     Georgi   Facello          M  1986-06-26   66961
# ..     ...         ...        ...       ...        ...         ...     ...
# 95   10009  1952-04-19     Sumant      Peac          F  1985-02-18   74612
# 96   10009  1952-04-19     Sumant      Peac          F  1985-02-18   76518
# 97   10009  1952-04-19     Sumant      Peac          F  1985-02-18   78335
# 98   10009  1952-04-19     Sumant      Peac          F  1985-02-18   80944
# 99   10009  1952-04-19     Sumant      Peac          F  1985-02-18   82507
#
#      from_date     to_date gender_sal
# ...

# %%
pd.merge(df_emp, df_sal, how='left', left_index=True, right_index=True, suffixes=['_emp', '_sal'])
# Out:
#         birth_date   first_name    last_name gender_emp   hire_date   salary  \
# emp_no
# 10001   1953-09-02       Georgi      Facello          M  1986-06-26  60117.0
# 10001   1953-09-02       Georgi      Facello          M  1986-06-26  62102.0
# 10001   1953-09-02       Georgi      Facello          M  1986-06-26  66074.0
# 10001   1953-09-02       Georgi      Facello          M  1986-06-26  66596.0
# 10001   1953-09-02       Georgi      Facello          M  1986-06-26  66961.0
# ...            ...          ...          ...        ...         ...      ...
# 10096   1954-09-16       Jayson      Mandell          M  1990-01-14      NaN
# 10097   1952-02-27        Remzi  Waschkowski          M  1990-09-15      NaN
# 10098   1961-09-23  Sreekrishna    Servieres          F  1985-05-13      NaN
# 10099   1956-05-25       Valter      Sullins          F  1988-10-18      NaN
# 10100   1953-04-21     Hironobu    Haraldson          F  1987-09-21      NaN
#
# ...

# %%
len(df_emp), len(df_sal)
# Out:
# (100, 100)

# %%
df_emp.reset_index(inplace=True)
df_sal.reset_index(inplace=True)

# %%
pd.concat([df_emp, df_sal], axis = 1)
# Out:
#     emp_no  birth_date   first_name    last_name gender   hire_date  emp_no  \
# 0    10001  1953-09-02       Georgi      Facello      M  1986-06-26   10001
# 1    10002  1964-06-02      Bezalel       Simmel      F  1985-11-21   10001
# 2    10003  1959-12-03        Parto      Bamford      M  1986-08-28   10001
# 3    10004  1954-05-01    Chirstian      Koblick      M  1986-12-01   10001
# 4    10005  1955-01-21      Kyoichi     Maliniak      M  1989-09-12   10001
# ..     ...         ...          ...          ...    ...         ...     ...
# 95   10096  1954-09-16       Jayson      Mandell      M  1990-01-14   10009
# 96   10097  1952-02-27        Remzi  Waschkowski      M  1990-09-15   10009
# 97   10098  1961-09-23  Sreekrishna    Servieres      F  1985-05-13   10009
# 98   10099  1956-05-25       Valter      Sullins      F  1988-10-18   10009
# 99   10100  1953-04-21     Hironobu    Haraldson      F  1987-09-21   10009
#
#     salary   from_date     to_date gender
# ...

# %%
from sqlalchemy import create_engine

query_emp = """
SELECT gender, count(*) 
FROM employees 
GROUP BY gender;
"""

con = create_engine("postgresql+psycopg2://postgres:postgres@localhost/employees")

df_emp = pd.read_sql_query(query_emp, con)
df_emp
# Out:
#   gender   count
# 0      M  179973
# 1      F  120051

# %%
from sqlalchemy import create_engine

query_emp = """
SELECT * 
FROM employees   
limit 1000;
"""

con = create_engine("postgresql+psycopg2://postgres:postgres@localhost/employees")

df_emp = pd.read_sql_query(query_emp, con)
df_emp
# Out:
#      emp_no  birth_date first_name     last_name gender   hire_date
# 0     10001  1953-09-02     Georgi       Facello      M  1986-06-26
# 1     10002  1964-06-02    Bezalel        Simmel      F  1985-11-21
# 2     10003  1959-12-03      Parto       Bamford      M  1986-08-28
# 3     10004  1954-05-01  Chirstian       Koblick      M  1986-12-01
# 4     10005  1955-01-21    Kyoichi      Maliniak      M  1989-09-12
# ..      ...         ...        ...           ...    ...         ...
# 995   10996  1955-02-01       Matk        Rahimi      F  1990-02-07
# 996   10997  1959-08-30     Alselm  Parascandalo      F  1994-05-06
# 997   10998  1956-02-17      Marlo       Kandlur      M  1992-06-28
# 998   10999  1961-12-04      Insup    Benveniste      F  1996-03-05
# 999   11000  1960-09-12      Alain      Bonifati      M  1988-08-20
#
# [1000 rows x 6 columns]

# %%
df_g = (
	df_emp
	.groupby(by=['gender'], as_index=False)
	['emp_no']
	.count()
	.rename(columns={'emp_no':'c'})
)
# Out:
#   gender    c
# 0      F  390
# 1      M  610

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_no      100 non-null    int64
#  1   birth_date  100 non-null    object
#  2   first_name  100 non-null    str
#  3   last_name   100 non-null    str
#  4   gender      100 non-null    str
#  5   hire_date   100 non-null    object
# dtypes: int64(1), object(2), str(3)
# memory usage: 4.8+ KB

# %%
df_emp['hire_date'] = pd.to_datetime(df_emp['hire_date'])
df_emp
# Out:
#      emp_no  birth_date first_name     last_name gender  hire_date
# 0     10001  1953-09-02     Georgi       Facello      M 1986-06-26
# 1     10002  1964-06-02    Bezalel        Simmel      F 1985-11-21
# 2     10003  1959-12-03      Parto       Bamford      M 1986-08-28
# 3     10004  1954-05-01  Chirstian       Koblick      M 1986-12-01
# 4     10005  1955-01-21    Kyoichi      Maliniak      M 1989-09-12
# ..      ...         ...        ...           ...    ...        ...
# 995   10996  1955-02-01       Matk        Rahimi      F 1990-02-07
# 996   10997  1959-08-30     Alselm  Parascandalo      F 1994-05-06
# 997   10998  1956-02-17      Marlo       Kandlur      M 1992-06-28
# 998   10999  1961-12-04      Insup    Benveniste      F 1996-03-05
# 999   11000  1960-09-12      Alain      Bonifati      M 1988-08-20
#
# [1000 rows x 6 columns]

# %%
df['year'] = df_emp['hire_date'].dt.year
df
# Out:
#     emp_no  birth_date   first_name    last_name gender   hire_date  year
# 0    10001  1953-09-02       Georgi      Facello      M  1986-06-26  1986
# 1    10002  1964-06-02      Bezalel       Simmel      F  1985-11-21  1985
# 2    10003  1959-12-03        Parto      Bamford      M  1986-08-28  1986
# 3    10004  1954-05-01    Chirstian      Koblick      M  1986-12-01  1986
# 4    10005  1955-01-21      Kyoichi     Maliniak      M  1989-09-12  1989
# ..     ...         ...          ...          ...    ...         ...   ...
# 95   10096  1954-09-16       Jayson      Mandell      M  1990-01-14  1990
# 96   10097  1952-02-27        Remzi  Waschkowski      M  1990-09-15  1990
# 97   10098  1961-09-23  Sreekrishna    Servieres      F  1985-05-13  1985
# 98   10099  1956-05-25       Valter      Sullins      F  1988-10-18  1988
# 99   10100  1953-04-21     Hironobu    Haraldson      F  1987-09-21  1987
#
# [100 rows x 7 columns]

# %%
df.groupby(by='year')

# %%
df = (
	df_sal
	.groupby(by='gender', as_index=False)
	[['salary']]
	.mean()
)
