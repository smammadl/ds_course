# %%
import time
time.time()
# Out:
# 1775574617.3444538

# %%
# import pathlib
# pathlib.Path()

from pathlib import Path
Path().resolve()
# Out:
# WindowsPath('C:/Users/user/Desktop/div/notebooks')

# %%
print(r"asdfas\nafasdf")
# Out:
# asdfas\nafasdf

# %%
test_path = Path(r"C:\Users\user\Desktop\div\test")
test_path
# Out:
# WindowsPath('C:/Users/user/Desktop/div/test')

# %%
fayl_path = test_path / "neseeee.txt"
fayl_path.exists()
# Out:
# False

# %%
list(test_path.iterdir())
# Out:
# [WindowsPath('C:/Users/user/Desktop/div/test/basqa.nese.txt'),
#  WindowsPath('C:/Users/user/Desktop/div/test/nese.txt')]

# %%
folder_items = list(test_path.iterdir())
if len(folder_items) == 0:
    print('hec ne yoxdur')
else:
    print('fayl var')
# Out:
# hec ne yoxdur

# %%
import time
from pathlib import Path

folder_path = Path(r"C:\Users\user\Desktop\div\test")

while True:
	folder_items = list(test_path.iterdir())
	if len(folder_items) == 0:
		print('hec ne yoxdur')
	else:
		print('fayl var')
		
	time.sleep(5)
# Out:
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# fayl var
# fayl var
# fayl var
# fayl var
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# hec ne yoxdur
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 12
#      10 else:
#      11 	print('fayl var')
# ---> 12 time.sleep(5)
#
# KeyboardInterrupt:

# %%
json_path = Path(r"C:\Users\user\Desktop\div\test\debug_upload_results.json")
json_path
# Out:
# WindowsPath('C:/Users/user/Desktop/div/test/debug_upload_results.json')

# %%
import json

with open(json_path, 'r') as f:
    d = json.load(f)
d
# Out:
# {'results': [{'day': '2026-02-28',
#    'file_results': [{'input_path': 'C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_newcommers_20260126_173500.xlsx',
#      'upload_type': 'Toplu yükləmək',
#      'status': 'SKIP',
#      'message': 'Marked as not to upload (empty or filtered out)',
#      'uploaded_at': None,
#      'report_path': None},
#     {'input_path': 'C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_reverse_maternity_20260126_173500.xlsx',
#      'upload_type': 'Toplu yükləmək',
#      'status': 'OK',
#      'message': 'Upload successful',
#      'uploaded_at': '2026-02-28 18:59:14.190329',
#      'report_path': None},
#     {'input_path': 'C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_exit_20260126_173500.xlsx',
#      'upload_type': 'Toplu xitam etmək',
#      'status': 'SKIP',
# ...

# %%
d.keys()
# Out:
# dict_keys(['results'])

# %%
l = d['results'][0]['file_results']

for result in l:
    file_path = Path(str(result['input_path']))
    print(file_path.name)
    print(result['status'])
    print()
# Out:
# insurance_newcommers_20260126_173500.xlsx
# SKIP
#
# insurance_reverse_maternity_20260126_173500.xlsx
# OK
#
# insurance_exit_20260126_173500.xlsx
# SKIP
#
# insurance_maternity_end_20260126_173500.xlsx
# SKIP
#
# insurance_position_change_20260126_173500.xlsx
# OK

# %%
Path(result['input_path']).name
# Out:
# 'insurance_position_change_20260126_173500.xlsx'

# %%
result['input_path'].split('\\')[-1]
# Out:
# 'insurance_position_change_20260126_173500.xlsx'

# %%
for x in ['a', 1, True, None, 3]:
    print(x)
# Out:
# a
# 1
# True
# None
# 3

# %%
x
# Out:
# 3

# %%
l[-2]
# Out:
# {'input_path': 'C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_maternity_end_20260126_173500.xlsx',
#  'upload_type': 'Toplu xitam etmək',
#  'status': 'SKIP',
#  'message': 'Marked as not to upload (empty or filtered out)',
#  'uploaded_at': None,
#  'report_path': None}

# %%
l = [1,2,3,5,2,1,1,5,1,132]
yeni_l = []

for nese in l:
    # print(nese**2)
    yeni_l.append(nese**2)

yeni_l
# Out:
# [1, 4, 9, 25, 4, 1, 1, 25, 1, 17424]

# %%
[nese**2 for nese in l]
# Out:
# [1, 4, 9, 25, 4, 1, 1, 25, 1, 17424]

# %%
l = ['ali', 'shahriyar', 'lale']

[ad[0] for ad in l]
# Out:
# ['a', 's', 'l']

# %%
bosh_list = []
for ad in l:
    bosh_list.append(ad[0])
bosh_list
# Out:
# ['a', 's', 'l']

# %%
bosh_list = []
for ad in l:
    if ad[0] == 'a':
    	bosh_list.append(ad[0])
bosh_list
# Out:
# ['a']

# %%
l = ['ali', 'shahriyar', 'lale']

yeni_l = [ad[0] for ad in l if ad[0] == 'a']
yeni_l
# Out:
# ['a']

# %%
l = [1,2,3,5,2,1,1,5,1,132]

[i**2 if i> 10 else -i for i in l if i%2 == 0]
# Out:
# [-2, -2, 17424]

# %%
l = [1,2,3,5,2,1,1,5,1,132]

{i**2 if i> 10 else -i for i in l if i%2 == 0}
# Out:
# {-2, 17424}

# %%
l = [1,2,3,5,2,1,1,5,1,132, 6]

{i**2:'salam' if i> 10 else -i for i in l if i%2 == 0}
# Out:
# {4: -2, 17424: 'salam', 36: -6}

# %%
result.keys()
# Out:
# dict_keys(['input_path', 'upload_type', 'status', 'message', 'uploaded_at', 'report_path'])

# %%
result.values()
# Out:
# dict_values(['C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_position_change_20260126_173500.xlsx', 'Toplu qrup dəyişmə', 'OK', 'Upload successful', '2026-02-28 18:59:19.084434', None])

# %%
result.items()
# Out:
# dict_items([('input_path', 'C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_position_change_20260126_173500.xlsx'), ('upload_type', 'Toplu qrup dəyişmə'), ('status', 'OK'), ('message', 'Upload successful'), ('uploaded_at', '2026-02-28 18:59:19.084434'), ('report_path', None)])

# %%
for k,v in result.items():
    print(f"key: {k}\nvalue: {v}")
# Out:
# key: input_path
# value: C:\Users\user\Desktop\dev\kapital\sigorta\data\dev_dry_run_source\Today\insurance_position_change_20260126_173500.xlsx
# key: upload_type
# value: Toplu qrup dəyişmə
# key: status
# value: OK
# key: message
# value: Upload successful
# key: uploaded_at
# value: 2026-02-28 18:59:19.084434
# key: report_path
# value: None

# %%
result
# Out:
# {'input_path': 'C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_position_change_20260126_173500.xlsx',
#  'upload_type': 'Toplu qrup dəyişmə',
#  'status': 'OK',
#  'message': 'Upload successful',
#  'uploaded_at': '2026-02-28 18:59:19.084434',
#  'report_path': None}

# %%
result['yeni_key'] = 'netersen'
result
# Out:
# {'input_path': 'C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_position_change_20260126_173500.xlsx',
#  'upload_type': 'Toplu qrup dəyişmə',
#  'status': 'OK',
#  'message': 'Upload successful',
#  'uploaded_at': '2026-02-28 18:59:19.084434',
#  'report_path': None,
#  'yeni_key': 'netersen'}

# %%
result['status'] = 'UNKNOWN'
result
# Out:
# {'input_path': 'C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_position_change_20260126_173500.xlsx',
#  'upload_type': 'Toplu qrup dəyişmə',
#  'status': 'UNKNOWN',
#  'message': 'Upload successful',
#  'uploaded_at': '2026-02-28 18:59:19.084434',
#  'report_path': None,
#  'yeni_key': 'netersen'}

# %%
v = None

if 'city' in result:
    v = result['city']
else:
    v = 'default'
v
# Out:
# 'default'

# %%
result.get('city', 'default')
# Out:
# 'default'

# %%
# result['status'] = 'salam'

# %%
result
# Out:
# {'input_path': 'C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_position_change_20260126_173500.xlsx',
#  'upload_type': 'Toplu qrup dəyişmə',
#  'status': 'UNKNOWN',
#  'message': 'Upload successful',
#  'uploaded_at': '2026-02-28 18:59:19.084434',
#  'report_path': None,
#  'yeni_key': 'netersen'}

# %%
result.setdefault('s', 'salam')
result
# Out:
# {'input_path': 'C:\\Users\\user\\Desktop\\dev\\kapital\\sigorta\\data\\dev_dry_run_source\\Today\\insurance_position_change_20260126_173500.xlsx',
#  'upload_type': 'Toplu qrup dəyişmə',
#  'status': 'UNKNOWN',
#  'message': 'Upload successful',
#  'uploaded_at': '2026-02-28 18:59:19.084434',
#  'report_path': None,
#  'yeni_key': 'netersen',
#  's': 'salam'}

# %%
s = {'asdf', 'asdf', 1,2,}
s.add('asdfljasdfl')
s
# Out:
# {1, 2, 'asdf', 'asdfljasdfl'}

# %%
dir(result)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
son_element = l.pop()
l
# Out:
# [1, 2, 127, 3, 5, 2, 1, 1, 5, 1]

# %%
l = [1,2,3,5,2,1,1,5,1,132, 6]

l[::-1]
# Out:
# [6, 132, 1, 5, 1, 1, 2, 5, 3, 2, 1]

# %%
m1 = ['ali', 'veli', 'hesen']
m2 = ['ali', 'shahriyar', 'lale']

set(m1).difference(set(m2))
# Out:
# {'hesen', 'veli'}

# %%
{'hesen', 'veli'} == {'veli', 'hesen'}
# Out:
# True

# %%
help(set(m1).difference_update)
# Out:
# Help on built-in function difference_update:
#
# difference_update(...) method of builtins.set instance
#     Remove all elements of another set from this set.
