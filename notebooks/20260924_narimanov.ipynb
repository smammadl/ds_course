# %% [markdown]
# # murekkeb hesablamalar
#
# Bizx bu dərsdə filan şeyi edirik:
#
# - vscode oyrenmek
# - basqa seyler
#
# 1. python sade inst
# 2. python murekkeb inst
#
# $$\sum _{i=1} ^{100} i$$

# %%
adfasf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 adfasf
#
# NameError: name 'adfasf' is not defined

# %% [markdown]
# ## sade hesablamaalr 2
# ### daha da sade
#
# 123123
# 12312308
#
# 203948lj
#
# aldfjaldsjf
#
# print("salam")

# %%
4*6
# Out:
# 24

# %% [markdown]
# # sade hesablamalar

# %% [markdown]
# \+
#
# \-
#
# \*
#
# /
#
# //
#
# %
#
# **

# %%
2 * 2 * 2
# Out:
# 8

# %%
2**3
# Out:
# 8

# %%
((2+3)*4)**2
# Out:
# 400

# %% [markdown]
# 1. parantez
# 2. **
# 3. \* /
# 4. \+ \-

# %%
(5-1) * ((7+1) / (3-1))
(5-1) * (8 / 2)
4 * 4
16
# Out:
# 16

# %%
1_000_000_000 + 12
# Out:
# 1000000012

# %%
3.5e15 + 1
# Out:
# 3500000000000001.0

# %% [markdown]
# ==
#
# !=
#
# \>
#
# \>=
#
# \<
#
# \<=

# %%
x = 10

# %%
2/2 == 1**10
# Out:
# True

# %%
x = 5
x = 7
x
# Out:
# 7

# %%
x = 7

# %%
x
# Out:
# 7

# %%
x
# Out:
# 10

# %%
x = 10
X = 10

x == X
# Out:
# True

# %%
-3 > -2
# Out:
# False

# %%
qutu == 10
qutu = 12
qutu
# Out:
# 12

# %%
kitab == 30
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 kitab == 30
#
# NameError: name 'kitab' is not defined

# %%
qelem
# Out:
# 30

# %%
ali
# Out:
# 40

# %%
Ali
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 Ali
#
# NameError: name 'Ali' is not defined

# %% [markdown]
# - herf (veya _ ) ile bashlamalidir
# - herf, reqem, _ ola biler icinde
# - for, while, in, not, else, if, elif ...
# - print

# %%
print(10)
print(20)
print(30)
# Out:
# 10
# 20
# 30

# %%
# print = 123
# print

# %%
# print(10)
# print(20)
# print(30)

# %%
print(10) # kod print ishine yarayir
# Out:
# 10

# %%
"alinin 20 yashi var"
# Out:
# 'alinin 20 yashi var'

# %%
ali = 10

# %%
print(ali)
print("ali")
# Out:
# 10
# ali

# %%
y = """alinin 25 yashi var)
hesenin 20 yashi var
adfsasdfalj"""

# %%
print(y)
# Out:
# alinin 25 yashi var)
# hesenin 20 yashi var
# adfsasdfalj

# %%
print(x, y, sep='?')
# Out:
# alinin 5 yashi var?hesenin 20 yashi var

# %%
x = "alinin 5 yashi var"
y = "hesenin 20 yashi var"

help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %% [markdown]
# - integer (1, 2, 3, -1, -2, 0) | int
# - floating point (2.5, -0.21231) | float
# - string '', "", """""" | str
# - boolean True, False | bool

# %%
10 
20
30
2.5
1.2
-0.12
-5.3
3.12

# %%
x = True
y = 8 == 8

# %%
y == x
# Out:
# True

# %%
3 = y
# Out:
#   Cell In[82], line 1
#     3 = y
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
b = y

# %%
3 * "ali"
# Out:
# 'alialiali'

# %%
"ali" *  'hesen'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 "ali" *  'hesen'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
1 * 3
# Out:
# 3

# %%
3 * "ali"
