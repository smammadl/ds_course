# %% [markdown]
# # Jupyter Notebook Basics

# %%
########## asdfkjasldkfjalskdfjlakjdflakjf

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# # Basic arithmetics in python

# %%
# addition 
1 + 1
# Out:
# 2

# %%
# subtraction
1 - 1
# Out:
# 0

# %%
# multiplication
1 * 1
# Out:
# 1

# %%
# division
7 / 2
# Out:
# 3.5

# %%
# floor division
7 // 2
# Out:
# 3

# %%
# modulus
13%5
# Out:
# 3

# %%
# exponentiation
2**4
# Out:
# 16

# %% [markdown]
# Parantheses
# Exp
# MD
# AS

# %% [markdown]
# # Operator precendence

# %%
# example

# %% [markdown]
# # Comparison Operators

# %%
# equal to True
2 == 2
# Out:
# True

# %%
# equal to False
2 == 1
# Out:
# False

# %%
# not equal to
2 != 1
# Out:
# True

# %%
2 < 1
# Out:
# False

# %%
2 >= 2
# Out:
# True

# %% [markdown]
# # Variables and assignment

# %% [markdown]
# 1. boshluq olmaz
# 2. herf reqem _
# 3. reqemle bashlaya bilmez

# %%
# assignment
a1age = 30
age2 = 40
aliage = 31
Age
age
aGe

# %%
# checking value
ali_age
# Out:
# 31

# %%
# reassignment
a = 5
a = 6.5
a
# Out:
# 6.5

# %%
# adding value to variable
a / 1
# Out:
# 6.5

# %%
# subtracting value from variable

# %%
# adding variable to itself
a
# Out:
# 6.5

# %%
a
# Out:
# 6.5

# %%
# adding variable to another variable
a = 5
b = 6
a+b
# Out:
# 11

# %%
# subtracting variable from itself

# %%
# subtracting variable from another variable

# %%
a
# Out:
# 7

# %%
# assignment operators
# a = a * 3
a *= 3
a
# Out:
# 21

# %%
# variable naming rules (show error)
age_ali = 10
age_Ali
# Out:
# 10

# %% [markdown]
# # Data types

# %%
# check type of variable
a = 5 # integer
b = 8.5 # float
c1 = 'asdfjalsdfjaklsj'
c2 = "asdfjalsdfjaklsj"
d = True # False
f = 'True'
g = None
g = 180
g
# Out:
# 180

# %%
menim 30 yashim var

# %%
# float examples

# %%
# example: 

maash = 567
# maash * 10 / 100
maash * 1.1
# Out:
# 623.7

# %%
mashinin_nomresi = 100
mashinin_nomresi + 2
# Out:
# 102

# %%
# boolean examples
is_student = True
is_working = not is_student

# %%
is_working
# Out:
# 'is_working' is not recognized as an internal or external command,
# operable program or batch file.

# %%
is_student = True
is_student
# Out:
# True

# %%
not is_student
# Out:
# False

# %% [markdown]
# Ali ya da Braziliyada yashayiram

# %%
ad = False
soyad = False
ad or soyad
# Out:
# False

# %%
# none examples
a = None

# %%
# example of is
a = 5
a == 5
# Out:
# True

# %%
b = None
b is not None
# Out:
# False

# %%
type(int(float('1.5')))
# Out:
# int

# %%
type(float('1.5'))
# Out:
# float

# %%
# type conversion
a = '1.5029384'
b = float(a)
b
# Out:
# 1.5029384

# %%
dir(b)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %%
b.__round__?
# Out:
# Signature: b.__round__(ndigits=None, /)
# Docstring:
# Return the Integral closest to x, rounding half toward even.
#
# When an argument is passed, work like built-in round(x, ndigits).
# Type:      builtin_function_or_method

# %%
b.__round__(4)
# Out:
# 1.5029

# %% [markdown]
# -2, 3, 0, 2, 1 -> int
# 1.34, 343.123, -12.1231, 0.1231 -> float
# 'asdfjalkjasf', '123', "123132.21"

# %%
a = -2.3
a.__abs__()
# Out:
# 2.3

# %%
dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %% [markdown]
# # strings

# %%
# string examples

# %%
# single quote
'aaa' == "aaa"
# Out:
# True

# %%
tekst_deyiskeni = "I\'m \tgoing \nto \\school"
print(tekst_deyiskeni)
# Out:
# I'm 	going
# to \school

# %%
# double quote

# %%
# mixing quotes

# %%
1 + 2
# Out:
# 3

# %%
# string concatenation
'1' + '2' + '3' + 'a' + str(1)
# Out:
# '123a1'

# %%
# string replication
'2' * 3
# Out:
# '222'

# %%
# escape characters

# %%
# string indexing
ad = 'shahriyar'
ad[3:7:2]
# Out:
# 'hi'

# %%
# string slicing

# %%
# steps

# %%
# immutability 
ad[5]='o'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 2
#       1 # immutability
# ----> 2 ad[5]='o'
#
# TypeError: 'str' object does not support item assignment

# %%
# string functions
len('div')
# Out:
# 3

# %%
# string methods
dir('adfjalskdfj')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
'asdfj alsd adff'.endswith('d')
# Out:
# False

# %% [markdown]
# # input / output

# %%
# printing
school_name = 'BDasdfasdfaU'
text_var = f"I am going to {school_name} academy"

print(text_var)
# Out:
# I am going to BDasdfasdfaU academy

# %%
# taking inputs
x = input('boyunuzu yazin z.o')
print(x+'1')
# Out:
# 1801

# %%
def print_sdlfkajsldjf(a, b):
	return 18

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
'18'

# %%
type(x)
# Out:
# str
