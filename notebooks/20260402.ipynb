# %%
x = 10
x
# Out:
# 10

# %%
int
float
str
bool
None

# %%
s = 'asdfjasldf'
s.upper()
# Out:
# 'ASDFJASLDF'

# %%
# !pip install numpy

# %%
list1 = ['men', 'sen', 'o'] # list
list2 = ['biz', 'siz', 'onlar'] # list
tuple1 = ('men', 'sen', 'o') # tuple
set1 = {'men', 'sen', 'o'} # set
dict1 = {
    'men':100, 
    'sen':90, 
    'o':80
} # dict

from numpy import array
arr1 = array([1,2,3]) + 10

# %%
list1[-1] = ('shahriyar', 'ali')
list1
# Out:
# ['men', 'sen', ('shahriyar', 'ali')]

# %%
obyekt = [
    ('a', 'b'), 
    [1, True, [
        'ali', 'vali', {
            'reng1' : 'ag', 
            'reng2' : 'qara'
		}
	]]
]

obyekt[-1][-1][-1]['reng2']
# Out:
# 'qara'

# %%
[1,2,3] + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 [1,2,3] + 10
#
# TypeError: can only concatenate list (not "int") to list

# %%
tuple1[1] = 1231
tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 tuple1[1] = 1231
#       2 tuple
#
# TypeError: 'tuple' object does not support item assignment

# %%
list1.sort(reverse=True)
list1
# Out:
# ['sen', 'o', 'men']

# %%
dir(list1)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list1
# Out:
# ['sen', 'o', 'men']

# %%
list1.append(10)
list1
# Out:
# ['sen', 'o', 'men', 10]

# %%
list1.extend([12,3])
list1
# Out:
# ['sen', 'o', 'men', 10, 12, 3]

# %%
list1.insert(1, *['shahriyar', 'ali'])
list1
# Out:
# ['sen',
#  ['shahriyar', 'ali'],
#  ['shahriyar', 'ali'],
#  'shahriyar',
#  'o',
#  'men',
#  10,
#  12,
#  3]

# %%
[list1[0], *['shahriyar', 'ali'], *list1[1:]]
# Out:
# ['men', 'shahriyar', 'ali', 'sen', 'o']

# %%
list1[1] = 'ali'
list1
# Out:
# ['sen', 'o', 'men']

# %%
list1.remove('o')
list1
# Out:
# ['men', 'sen']

# %%
del list1[-1]
list1
# Out:
# ['men']

# %%
x = ['a', 'b', 'c']
y = x
y
# Out:
# ['a', 'b', 'c']

# %%
x
# Out:
# ['a', 'b', 'c']

# %%
y[0] = 'shahriyar'
y
# Out:
# ['shahriyar', 'b', 'c']

# %%
x
# Out:
# ['shahriyar', 'b', 'c']

# %%
y = x.copy()
x
# Out:
# ['shahriyar', 'b', 'c']

# %%
x = 10
y = x
y = 20
x
# Out:
# 10

# %%
len(list1)
# Out:
# 1

# %%
list1
# Out:
# ['men']

# %%
x = [10, 20, 'ali', True, None, 5]
x
# Out:
# [10, 20, 'ali', True, None, 5]

# %%
20 not in x
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
bool('adfasd')
# Out:
# True

# %%
3<1 and 3<2
# Out:
# False

# %%
x
# Out:
# [10, 20, 'ali', True, None, 5]

# %%
not(20 in x)
# Out:
# False

# %%
x + 2

# %%
not (x > 100)
# Out:
# False

# %%
boyukfirat = 'baglidir'
kocet = 'aciqdir'
padisah = 'zeherlidir'

if boyukfirat == 'aciqdir':
	print('durum al')
	print('salam')
	print('sagol')
elif kocet == 'aciqdir':
    print('tombik al')

if padisah == 'zeherli deyil':
    print('doner al')
else:
    print('Pulu qaytar')
    print('DEYIL')
    print('DEYIL!!!!!')

print('bitdi')
# Out:
# tombik al
# Pulu qaytar
# DEYIL
# DEYIL!!!!!
# bitdi

# %%
boyukfirat = 'baglidir'
kocet = 'baglidir'
padisah = 'zeherlidir'
saat = 19

if boyukfirat == 'aciqdir':
	print('durum al')
	print('salam')
	print('sagol')
elif kocet == 'aciqdir':
    print('tombik al')
elif padisah == 'zeherli deyil':
    print('doner al')
else:
	if saat <= 20:
		print('parka teref get')
	else:
		print('Pulu qaytar')
		print('DEYIL')
		print('DEYIL!!!!!')

print('bitdi')
# Out:
# parka teref get
# bitdi

# %%
match saat:
    case 10:
        print('salam')
    case 19:
        print('sagol')
# Out:
# sagol
