# %% [markdown]
# # data types

# %% [markdown]
# - int (sayı, ədəd) == -2,0,1,2
# - float (kəsr sayı, kəsr ədəd) == -1.5, 1.5, 3.14
# - bool (mentiq tipi) == True, False
# - string (tekst, mətn) == 'shahriyar', "mammadli", '12', "3.14", 'True'
# - null (yoxluq) == None

# %%
x = 4
x
# Out:
# 4

# %%
aile_vez = None
aile_vez = 'subay'
aile_vez
# Out:
# 'subay'

# %%
x = 'shahriyar'
y = 'mammadli'
x + y
# Out:
# 'shahriyarmammadli'

# %%
x = '10'
y = 20
x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 x = '10'
#       2 y = 20
# ----> 3 x + y
#
# TypeError: can only concatenate str (not "int") to str

# %%
int()
str()
float()
bool()
# Out:
# False

# %%
x = 'shahriyar'
y = 'mammadli'
x + y
# Out:
# 'shahriyarmammadli'

# %%
cumle = 'I\'m going \nto \tschool\\'
print(cumle)
# Out:
# I'm going
# to 	school\

# %%
x = 'shahriyaralskdfjlaskjdflajsdlfjalsdfjlaksjdflkajsldkfjaldfskjakljdsflakjf'
x
# Out:
# 'shahriyaralskdfjlaskjdflajsdlfjalsdfjlaksjdflkajsldkfjaldfskjakljdsflakjf'

# %%
x[8:0:-2]
# Out:
# 'ryra'

# %%
len(x)
# Out:
# 73

# %%
x[0:74:2]
# Out:
# 'saryrlkflsjfasljldjasdlasdfadsjkjslkf'

# %%
x
# Out:
# 'shahriyaralskdfjlaskjdflajsdlfjalsdfjlaksjdflkajsldkfjaldfskjakljdsflakjf'

# %%
y
# Out:
# 'mammadli'

# %%
x[0:4] + y
# Out:
# 'shahmammadli'

# %%
y = 'shahriyar mammadli'
print(y)
print(y.capitalize())
print(y.capitalize().upper())
print(y.upper())
# Out:
# shahriyar mammadli
# Shahriyar mammadli
# SHAHRIYAR MAMMADLI
# SHAHRIYAR MAMMADLI

# %%
dir(y)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
y = 'Shahriyar Mammadli'
y.swapcase()
# Out:
# 'sHAHRIYAR mAMMADLI'

# %%
z = 10
dir('ali')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# # input/output

# %%
ad = input("adiniz nedir?")

cumle = f"menim adim {ad}-dir"
print(cumle)
# Out:
# menim adim Hesen-dir

# %%
reng = input("En sevdiyiniz reng nedir?")
c = f"En sevdiyim reng: {reng}"
print(c)
# Out:
# En sevdiyim reng: ag

# %%
x = "shahriyar"
print(f"menim adim: {x:^30}-dir")
# Out:
# menim adim:           shahriyar           -dir

# %%
y = 255
print(f"reqem: {y:x}")
# Out:
# reqem: ff

# %%
1-9
11-19
21-29

# %%
0-1
10-11
100-111
