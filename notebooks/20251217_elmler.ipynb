# %%
import numpy as np
import pandas as pd

adlar = np.array(['shahriyar','ali','lale'])
yashlar = [10,20,30]
s = pd.Series(data=[10,20,30], index=['shahriyar','ali','lale'])
s = pd.Series({
    'shahriyar' : 10,
    'ali' : 20,
	'lale' : 30,
})
s
# Out:
# shahriyar    10
# ali          20
# lale         30
# dtype: int64

# %%
s.loc[:'ali']
s.iloc[:2]
# Out:
# shahriyar    10
# ali          20
# dtype: int64

# %%
s
# Out:
# shahriyar    10
# ali          20
# lale         30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.to_list()
# Out:
# [10, 20, 30]

# %%
from pathlib import Path
csv_path = Path(r"C:\Users\user\Desktop\div\data\world_population.csv")
df = pd.read_csv(csv_path)
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df2 = df.set_index('CCA3')
df2.head(3)
# Out:
#       Rank      Country  Capital Continent  2022 Population  2020 Population  \
# CCA3
# AFG     36  Afghanistan    Kabul      Asia       41128771.0       38972230.0
# ALB    138      Albania   Tirana    Europe        2842321.0        2866849.0
# DZA     34      Algeria  Algiers    Africa       44903225.0       43451666.0
#
#       2015 Population  2010 Population  2000 Population  1990 Population  \
# CCA3
# AFG        33753499.0       28189672.0       19542982.0       10694796.0
# ALB         2882481.0        2913399.0        3182021.0        3295066.0
# DZA        39543154.0       35856344.0       30774621.0       25518074.0
#
#       1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# CCA3
# AFG        12486631.0       10752971.0    652230.0            63.0587
# ALB         2941651.0        2324731.0     28748.0            98.8702
# DZA        18739378.0       13795915.0   2381741.0            18.8531
#
#       Growth Rate  World Population Percentage
# CCA3
# ...

# %%
s_aze = df2.loc['AZE']
s_aze
# Out:
# Rank                                   91
# Country                        Azerbaijan
# Capital                              Baku
# Continent                            Asia
# 2022 Population                10358074.0
# 2020 Population                       NaN
# 2015 Population                 9863480.0
# 2010 Population                 9237202.0
# 2000 Population                 8190337.0
# 1990 Population                 7427836.0
# 1980 Population                 6383060.0
# 1970 Population                 5425317.0
# Area (km²)                        86600.0
# Density (per km²)                119.6082
# Growth Rate                        1.0044
# World Population Percentage          0.13
# Name: AZE, dtype: object

# %%
s_aze.loc['Capital':'Area (km²)']
# Out:
# Capital                  Baku
# Continent                Asia
# 2022 Population    10358074.0
# 2020 Population           NaN
# 2015 Population     9863480.0
# 2010 Population     9237202.0
# 2000 Population     8190337.0
# 1990 Population     7427836.0
# 1980 Population     6383060.0
# 1970 Population     5425317.0
# Area (km²)            86600.0
# Name: AZE, dtype: object

# %%
s_adlar = pd.Series(['emin', 'elton', 'mahmud', 'shahriyar'])
s_yemek = pd.Series(['ash', 'dolma', 'merci', 'bughlama'])

sinif = pd.DataFrame({
    'ad' : s_adlar,
    'yemek' : s_yemek,
})
sinif
# Out:
#           ad     yemek
# 0       emin       ash
# 1      elton     dolma
# 2     mahmud     merci
# 3  shahriyar  bughlama

# %%
# sinif['yemek']
sinif.loc[: , 'yemek']
sinif.iloc[: , 1]
# Out:
# 0         ash
# 1       dolma
# 2       merci
# 3    bughlama
# Name: yemek, dtype: object

# %%
# %pip install openpyxl xlsxwriter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# df2['2022 Population']
df2.loc['ARM':'AZE', '2022 Population':'1970 Population']
df2.iloc[9:14, 4:12]

qafqaz = df2.loc[
    ['ARM', "AZE", 'RUS'], 
    ['2022 Population', 'Capital', 'Continent']
    ]
qafqaz.to_excel('qafqaz.xlsx')

# %%
q = pd.read_excel('qafqaz.xlsx')
q
# Out:
#   CCA3  2022 Population Capital Continent
# 0  ARM        2780469.0     NaN      Asia
# 1  AZE       10358074.0    Baku      Asia
# 2  RUS              NaN  Moscow    Europe

# %%
df2.head(4)
# Out:
#       Rank         Country    Capital Continent  2022 Population  \
# CCA3
# AFG     36     Afghanistan      Kabul      Asia       41128771.0
# ALB    138         Albania     Tirana    Europe        2842321.0
# DZA     34         Algeria    Algiers    Africa       44903225.0
# ASM    213  American Samoa  Pago Pago   Oceania          44273.0
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# CCA3
# AFG        38972230.0       33753499.0       28189672.0       19542982.0
# ALB         2866849.0        2882481.0        2913399.0        3182021.0
# DZA        43451666.0       39543154.0       35856344.0       30774621.0
# ASM           46189.0          51368.0          54849.0          58230.0
#
#       1990 Population  1980 Population  1970 Population  Area (km²)  \
# CCA3
# AFG        10694796.0       12486631.0       10752971.0    652230.0
# ALB         3295066.0        2941651.0        2324731.0     28748.0
# ...

# %%
df3 = df.set_index(['Continent', 'CCA3']).sort_index()
df3 = df3.loc[:, 'Rank':'2015 Population']
df3.columns = [
    ['General', 'General', 'General', 'Population', 'Population','Population'],
    ['Rank', 'Country', 'Capital', '2022 Population', '2020 Population','2015 Population']
]
df3.head(3)
# Out:
#                General                           Population                  \
#                   Rank  Country     Capital 2022 Population 2020 Population
# Continent CCA3
# Africa    AGO       42   Angola      Luanda      35588987.0      33428485.0
#           BDI       78  Burundi   Bujumbura      12889576.0      12220227.0
#           BEN       77    Benin  Porto-Novo      13352864.0      12643123.0
#
#
#                2015 Population
# Continent CCA3
# Africa    AGO       28127721.0
#           BDI       10727148.0
#           BEN       10932783.0

# %%
df3.loc[('Asia', 'AZE'), ('Population', '2022 Population')]
# Out:
# np.float64(10358074.0)

# %%
df3.head(3)
# Out:
#                General                           Population                  \
#                   Rank  Country     Capital 2022 Population 2020 Population
# Continent CCA3
# Africa    AGO       42   Angola      Luanda      35588987.0      33428485.0
#           BDI       78  Burundi   Bujumbura      12889576.0      12220227.0
#           BEN       77    Benin  Porto-Novo      13352864.0      12643123.0
#
#
#                2015 Population
# Continent CCA3
# Africa    AGO       28127721.0
#           BDI       10727148.0
#           BEN       10932783.0

# %%
df3.drop(labels=('Asia', 'AZE'), axis='rows').head(3)
# Out:
#                General                           Population                  \
#                   Rank  Country     Capital 2022 Population 2020 Population
# Continent CCA3
# Africa    AGO       42   Angola      Luanda      35588987.0      33428485.0
#           BDI       78  Burundi   Bujumbura      12889576.0      12220227.0
#           BEN       77    Benin  Porto-Novo      13352864.0      12643123.0
#
#
#                2015 Population
# Continent CCA3
# Africa    AGO       28127721.0
#           BDI       10727148.0
#           BEN       10932783.0

# %%
df4 = df3.droplevel('Continent', axis='rows').droplevel(0, axis='columns')
df4.head()
# Out:
#       Rank       Country      Capital  2022 Population  2020 Population  \
# CCA3
# AGO     42        Angola       Luanda       35588987.0       33428485.0
# BDI     78       Burundi    Bujumbura       12889576.0       12220227.0
# BEN     77         Benin   Porto-Novo       13352864.0       12643123.0
# BFA     58  Burkina Faso  Ouagadougou       22673762.0       21522626.0
# BWA    144      Botswana     Gaborone        2630296.0        2546402.0
#
#       2015 Population
# CCA3
# AGO        28127721.0
# BDI        10727148.0
# BEN        10932783.0
# BFA        18718019.0
# BWA         2305171.0

# %%
df4.rename({'Country':'Olke'}, axis='columns').rename({'AGO':'OGA'}, axis='rows')
# Out:
#       Rank          Olke      Capital  2022 Population  2020 Population  \
# CCA3
# OGA     42        Angola       Luanda       35588987.0       33428485.0
# BDI     78       Burundi    Bujumbura       12889576.0       12220227.0
# BEN     77         Benin   Porto-Novo       13352864.0       12643123.0
# BFA     58  Burkina Faso  Ouagadougou       22673762.0       21522626.0
# BWA    144      Botswana     Gaborone        2630296.0        2546402.0
# ...    ...           ...          ...              ...              ...
# PER     44          Peru         Lima       34049588.0       33304756.0
# PRY    109      Paraguay     Asunción        6780744.0        6618695.0
# SUR    170      Suriname   Paramaribo         618040.0         607065.0
# URY    133       Uruguay   Montevideo        3422794.0        3429086.0
# VEN     51     Venezuela      Caracas       28301696.0       28490453.0
#
#       2015 Population
# CCA3
# OGA        28127721.0
# BDI        10727148.0
# ...

# %%
df5 = df2.loc[['AZE', 'ARM', 'GEO'] , ['Country', '2020 Population']]
df5
# Out:
#          Country  2020 Population
# CCA3
# AZE   Azerbaijan              NaN
# ARM      Armenia        2805608.0
# GEO      Georgia        3765912.0

# %%
df5.dropna(axis='columns', how='any').reset_index()
# Out:
#   CCA3     Country
# 0  AZE  Azerbaijan
# 1  ARM     Armenia
# 2  GEO     Georgia

# %%
df2.sort_values?
# Out:
# Signature:
# df2.sort_values(
#     by: 'IndexLabel',
#     *,
#     axis: 'Axis' = 0,
#     ascending: 'bool | list[bool] | tuple[bool, ...]' = True,
#     inplace: 'bool' = False,
#     kind: 'SortKind' = 'quicksort',
#     na_position: 'str' = 'last',
#     ignore_index: 'bool' = False,
#     key: 'ValueKeyFunc | None' = None,
# ) -> 'DataFrame | None'
# Docstring:
# Sort by the values along either axis.
#
# Parameters
# ----------
# by : str or list of str
#     Name or list of names to sort by.
#
#     - if `axis` is 0 or `'index'` then `by` may contain index
#       levels and/or column labels.
#     - if `axis` is 1 or `'columns'` then `by` may contain column
#       levels and/or index labels.
# axis : "{0 or 'index', 1 or 'columns'}", default 0
#      Axis to be sorted.
# ascending : bool or list of bool, default True
#      Sort ascending vs. descending. Specify list for multiple sort
#      orders.  If this is a list of bools, must match the length of
#      the by.
# ...

# %%
df2.sort_values(by=['Continent','Area (km²)'], ascending=[True,False], na_position='first')
# Out:
#       Rank           Country     Capital      Continent  2022 Population  \
# CCA3
# SEN     72           Senegal       Dakar         Africa       17316449.0
# DZA     34           Algeria     Algiers         Africa       44903225.0
# COD     15          DR Congo    Kinshasa         Africa       99010212.0
# SDN     32             Sudan    Khartoum         Africa       46874204.0
# LBY    107             Libya     Tripoli         Africa        6812341.0
# ...    ...               ...         ...            ...              ...
# GUY    164            Guyana  Georgetown  South America         808726.0
# URY    133           Uruguay  Montevideo  South America        3422794.0
# SUR    170          Suriname  Paramaribo  South America         618040.0
# GUF    184     French Guiana     Cayenne  South America         304557.0
# FLK    231  Falkland Islands     Stanley  South America           3780.0
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# CCA3
# ...
