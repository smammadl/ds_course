# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt


blob_centers = np.array([
    [ 0.2,  2.3], 
	[-1.5 ,  2.3], 
	[-2.8,  1.8],
	[-2.8,  2.8], 
	[-2.8,  1.3]
])
blob_std = np.array([0.4, 0.3, 0.1, 0.1, 0.1])
X, y = make_blobs(
    n_samples=2000, 
	centers=blob_centers, 
	cluster_std=blob_std,
    random_state=7
)

plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
y_pred = kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_

plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', c='black')
plt.show()

# %%
kmeans.inertia_
# Out:
# 211.5985372581684

# %%
y_pred
# Out:
# array([4, 0, 1, ..., 2, 1, 0], shape=(2000,), dtype=int32)

# %%
centroids
# Out:
# array([[-2.80389616,  1.80117999],
#        [ 0.20876306,  2.25551336],
#        [-2.79290307,  2.79641063],
#        [-1.46679593,  2.28585348],
#        [-2.80037642,  1.30082566]])

# %%
np.sum(np.linalg.norm(X - centroids[y_pred], axis=1)**2)
# Out:
# np.float64(211.59853725816836)

# %%
kmeans.si

# %%
a,b,c = 0,2,3

np.abs(a-b), np.abs(a-c),
# Out:
# (np.int64(2), np.int64(3))

# %%
arr1 = np.array([2,2,2])
arr2 = np.array([3,3,3])
np.linalg.norm(arr1), np.linalg.norm(arr2)
# Out:
# (np.float64(3.4641016151377544), np.float64(5.196152422706632))

# %%
from sklearn.metrics import silhouette_score

silhouette_score(X, kmeans.labels_)
# Out:
# 0.655517642572828

# %%
kmeans = KMeans(n_clusters=5, )
y_pred = kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_

plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', c='black')
plt.show()

# %%
from sklearn.mixture import GaussianMixture

# %%
gm = GaussianMixture(n_components=5)
y_pred = gm.fit_predict(X)
# centroids = gm.cluster_centers_

plt.scatter(X[:, 0], X[:, 1], c=y_pred)
# plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', c='black')
plt.show()

# %%
from sklearn.cluster import DBSCAN

db = DBSCAN(eps=0.2, min_samples=10)
db.fit(X)
# Out:
# DBSCAN(eps=0.2, min_samples=10)

# %%
db.labels_
# Out:
# array([ 0,  0, -1, ...,  2,  3,  0], shape=(2000,))

# %%
np.unique_counts(db.labels_)
# Out:
# UniqueCountsResult(values=array([-1,  0,  1,  2,  3]), counts=array([ 27, 801, 393, 400, 379]))

# %%
plt.scatter(X[:, 0], X[:, 1], c=db.labels_)
plt.show()
